# %%
# IMPORT 

import csv
from biomart import BiomartServer
import pandas as pd
import openpyxl

# %%
# DATASET

## biomart_server
server = BiomartServer('http://www.ensembl.org/biomart')
dataset = server.datasets['rnorvegicus_gene_ensembl']

# %%
# FUNCTIONS

def gene_dictionary(index,
                    gene_name,
                    gene_list_number,
                    gene_list_id,
                    source,
                    ensembl_gene_id,
                    ensembl_transcript_id,
                    refseq_mrna,
                    hgnc_symbol,
                    organism,
                    alias,
                    direction_string):
    
    dictionary = {
        'Index' : index,
        'Gene_name' : gene_name,
        'Gene_list_number' : gene_list_number,
        'Gene_list_index' : gene_list_id,
        'Source' : source,
        'Ensembl_gene_id' : ensembl_gene_id,
        'Ensembl_transcript_id' : ensembl_transcript_id,
        'RefSeq_mRNA_id' : refseq_mrna,
        'Organism' : organism,
        'HGNC_symbol' : hgnc_symbol,
        'Alias' : alias,
        'Info' : direction_string
    }
    
    return dictionary


  
def biomartParameters(mgi_symbol):

    attributes = ['ensembl_gene_id',
                  'ensembl_transcript_id',
                  'refseq_mrna']

    filters = {'external_gene_name':[mgi_symbol]}               # gene_name = mgi_symbol
    response = dataset.search({'attributes':attributes,'filters':filters})
    

    # response_convertion
    values = [line.split("\t") for line in response.text.split("\n") if line.strip()]
        
    return values  


def biomartHumanOrthologs(mgi_symbol):
    
    attributes = ['hsapiens_homolog_associated_gene_name']
    filters = {'external_gene_name':[mgi_symbol]}
    response = dataset.search({'attributes':attributes,'filters':filters})
    
    # response_convertion
    values = [line.split("\t") for line in response.text.split("\n") if line.strip()]
    
    return values  
    
def biomartParametersbyEnsembl(ensembl_id):

    attributes = ['external_gene_name',
                  'ensembl_transcript_id',
                  'refseq_mrna']

    filters = {'ensembl_gene_id':[ensembl_gene_id]}               # gene_name = mgi_symbol
    response = dataset.search({'attributes':attributes,'filters':filters})
    

    # response_convertion
    values = [line.split("\t") for line in response.text.split("\n") if line.strip()]
        
    return values  

def biomartHumanOrthologsbyEnsembl(ensembl_id):

    attributes = ['hsapiens_homolog_associated_gene_name']

    filters = {'ensembl_gene_id':[ensembl_gene_id]}               # gene_name = mgi_symbol
    response = dataset.search({'attributes':attributes,'filters':filters})
    

    # response_convertion
    values = [line.split("\t") for line in response.text.split("\n") if line.strip()]
        
    return values  




def alias_and_official(ls_notResponse,ls_row_10,ls_row_2):

    ls_response = []
    ls_response2 = []
    
    for notResponse in ls_notResponse:
        word = str(notResponse).lower()

        for i in range(len(ls_row_10)):
            if ls_row_10[i]:
                temp = str(ls_row_10[i]).lower()
                t_strings = temp.split("|")
                if word in t_strings:
                    ls_response.append([word, i, ls_row_1[i]])

    ls_response.insert(0, ['gene_name','alias_index','mgi_id'])         # print(len(ls_response))


    for notResponse in ls_notResponse:
        word = str(notResponse).lower()

        for i in range(len(ls_row_10)):
            if ls_row_10[i]:
                temp = str(ls_row_10[i]).lower()
                if word == temp:
                    ls_response2.append([word, i, ls_row_1[i]])
                    

    ls_response.insert(0, ['gene_name','official_index','mgi_id'])      # print(len(ls_response2))

    ls_response_3 = ls_response
    
    for response in ls_response2:
        if response not in ls_response_3:
            ls_response_3.append(response)
        else: print(response)

    ls_response_3.pop(0)
    ls_response_3.pop(0)
    ls_response.insert(0, ['gene_name','official/alias_index','mgi_id'])
    
    return ls_response_3

def biomartParameters_mgi(mgi_id):

    attributes = ['ensembl_gene_id',
                  'ensembl_transcript_id',
                  'refseq_mrna']
    filters = {'mgi_id':[mgi_id]}                     # gene_name = mgi_id
    response = dataset.search({'attributes':attributes,'filters':filters})
    
    # response_convertion
    values = [line.split("\t") for line in response.text.split("\n") if line.strip()]
    
    return values  


def biomartHumanOrthologs_mgi(mgi_id):
    attributes = ['hsapiens_homolog_associated_gene_name']
    
    filters = {'mgi_id':[mgi_id]}
    response = dataset.search({'attributes':attributes,'filters':filters})
    
    # response_convertion
    values = [line.split("\t") for line in response.text.split("\n") if line.strip()]
    
    return values  


def updateCellswithAlias(mgi_file_path, dictionary_file_path, file_path):
    
    # Load MGI file and open workbook
    wb_mgi = openpyxl.load_workbook(mgi_file_path)
    ws_mgi = wb_mgi.active

    ls_row_alias = [ws_mgi.cell(row=i,column=10).value for i in range(2,ws_mgi.max_row+1)]
    ls_row_g_name = [ws_mgi.cell(row=i,column=2).value for i in range(2,ws_mgi.max_row+1)] 

    # Load dictionary file and open workbook
    workbook = openpyxl.load_workbook(dictionary_file_path)
    sheet = workbook.active

    ls_row_2 = [sheet.cell(row=i,column=2).value for i in range(2,sheet.max_row+1)]
    ls_row_9 = [sheet.cell(row=i,column=11).value for i in range(2,sheet.max_row+1)]

    
    length = len(ls_row_2) + 2

    # Modify the desired cell
    for i in range(length):
        K_cel = 'K' + str(i + 2)

        for k in range(len(ls_row_g_name)):
            try:
                if str(ls_row_g_name[k]).lower() == str(ls_row_2[i]).lower():
                    if ls_row_alias[k] is not None:
                        sheet[K_cel] = ls_row_alias[k]
                    else:
                        continue
            except:
                continue

    # Save the file
    workbook.save(file_path)
    
    
def updateCellswithINFO(source_file_path, source_sheet, alias_file_path, info_file_path):
    
    wb_info = openpyxl.load_workbook(source_file_path)
    ws_info = wb_info[source_sheet]
    ls_row_g_name = [ws_info.cell(row=i, column=3).value for i in range(2, ws_info.max_row + 1)]


    wb_alias = openpyxl.load_workbook(alias_file_path)
    ws_alias = wb_alias.active
    ls_row_2 = [ws_alias.cell(row=i, column=2).value for i in range(2, ws_alias.max_row + 1)]


    matched_indices = set()               # to keep track of matched id

    for j, (g_name, row_2) in enumerate(zip(ls_row_g_name, ls_row_2), start=2):
        if j not in matched_indices and str(g_name).lower() == str(row_2).lower():
            print(str(g_name).lower(), str(row_2).lower())
            L_cel = 'L' + str(j)
            tempInfo = str(ws_alias[L_cel].value)
            matched_indices.add(j)        # add matched index to set - avoid duplicate

### the number and type of items in the INFO column depends on the source publication


            ws_alias[L_cel] = ''
            ws_alias[L_cel] = ('Regulation:' + str(tempInfo).upper() + '|'
                            + 'Log2Ratio:' + str(ws_info['E' + str(j)].value) + '|'
                            + 'tissue:' + str(ws_info['H' + str(j)].value) + '|'
                            + 'cell:' + str(ws_info['I' + str(j)].value) + '|'
                            + 'enviroroment:' + str(ws_info['J' + str(j)].value) + '|'
                            + 'treatment:' + str(ws_info['K' + str(j)].value) + '|'
                            + 'dose:' + str(ws_info['L' + str(j)].value) + '|'
                            + 'time:' + str(ws_info['M' + str(j)].value) + '|'
                            + 'FDR_threshold:' + str(ws_info['N' + str(j)].value) + '|'
                            + 'method:' + str(ws_info['O' + str(j)].value) + '|'
                            + 'FDR:' + str(ws_info['P' + str(j)].value))

    # Save the file
    wb_alias.save(info_file_path)

# %%
# LOAD START FILES

## PUBLICATION SOURCE
wb = openpyxl.load_workbook('../ifpan-GR-database-papers.xlsx')
ws = wb['nervous-cells']

publication_geneName = [ws.cell(row=i,column=3).value for i in range(2,ws.max_row+1)]
direction = [ws.cell(row=i,column=6).value for i in range(2,ws.max_row+1)]
Ensembl_id = [ws.cell(row=i,column=4).value for i in range(2,ws.max_row+1)]


## MGI
wb_1 = openpyxl.load_workbook(r'../MGI_EntrezGene.xlsx')
ws_1 = wb_1.active

ls_row_10 = [ws_1.cell(row=i,column=10).value for i in range(2,ws_1.max_row+1)]
ls_row_2 = [ws_1.cell(row=i,column=2).value for i in range(2,ws_1.max_row+1)]
ls_row_1 = [ws_1.cell(row=i,column=1).value for i in range(2,ws_1.max_row+1)]

# %%
# LISTS

dictionary = {}
ls_geneDictionaries = []
ls_notResponse = []
ls_notResponse_after = []

# %%
# DICTIONARY

for i in range(len(publication_geneName)):
    gene_name = publication_geneName[i]
    direction_string = direction[i]   # => info
    
    # VARIABLES
    index = i + 1
    gene_list_number = 31
    gene_list_id =  'all_sig_genes_24147833'      # => cluster
    source = 'PMID: 24147833'
    organism = 'rat'
    print(direction_string)
    alias = ''
    
    if gene_name == '':
        continue
    
    
### "NA" GENE NAMES

    elif gene_name == 'NA':

        ensembl_gene_id = Ensembl_id[i]
        external_gene_name_temp = []
        ensembl_transcript_id_temp = []
        refseq_mrna_temp = []

        ls_biomartParametersbyEnsembl = biomartParametersbyEnsembl(ensembl_gene_id)
        if not ls_biomartParametersbyEnsembl:
            print('no ensembl')


        for ls in ls_biomartParametersbyEnsembl:
            for j in range(3):
                if len(ls) < (j+1):
                    ls.append('')
            external_gene_name_temp.append(ls[0])
            ensembl_transcript_id_temp.append(ls[1])
            refseq_mrna_temp.append(ls[2])  

        gene_name = '|'.join(list(set(filter(None, external_gene_name_temp))))
        ensembl_transcript_id = '|'.join(list(set(filter(None, ensembl_transcript_id_temp))))
        refseq_mrna = '|'.join(list(set(filter(None, refseq_mrna_temp))))

        print(gene_name)

        # ORTHOLOGS
        ls_biomartHumanOrthologsbyEnsembl = biomartHumanOrthologsbyEnsembl(ensembl_gene_id)
        if not ls_biomartHumanOrthologsbyEnsembl:
            hgnc_symbol = ''
        else:
            hgnc_symbol = ls_biomartHumanOrthologsbyEnsembl[0][0]
        
        temp_gene_dictionary = gene_dictionary(index,
                                       gene_name,
                                       gene_list_number,
                                       gene_list_id,
                                       source,
                                       ensembl_gene_id,
                                       ensembl_transcript_id, 
                                       refseq_mrna,
                                       hgnc_symbol,
                                       organism,
                                       alias,
                                       direction_string)

        ls_geneDictionaries.append(temp_gene_dictionary)
        print(temp_gene_dictionary)    

### GENE NAMES

    else:

        ensembl_gene_id_temp = []
        ensembl_transcript_id_temp = []
        refseq_mrna_temp = []


        ls_biomartParameters = biomartParameters(gene_name)
        if not ls_biomartParameters:
            ls_notResponse.append(gene_name)
            print(ls_notResponse)


        for ls in ls_biomartParameters:
            for j in range(3):
                if len(ls) < (j+1):
                    ls.append('')
            ensembl_gene_id_temp.append(ls[0])
            ensembl_transcript_id_temp.append(ls[1])
            refseq_mrna_temp.append(ls[2])  

        ensembl_gene_id = '|'.join(list(set(filter(None, ensembl_gene_id_temp))))
        ensembl_transcript_id = '|'.join(list(set(filter(None, ensembl_transcript_id_temp))))
        refseq_mrna = '|'.join(list(set(filter(None, refseq_mrna_temp))))


        # ORTHOLOGS
        ls_biomartHumanOrthologs = biomartHumanOrthologs(gene_name)
        if not ls_biomartHumanOrthologs:
            hgnc_symbol = ''
        else:
            hgnc_symbol = ls_biomartHumanOrthologs[0][0]
        
        temp_gene_dictionary = gene_dictionary(index,
                                               gene_name,
                                               gene_list_number,
                                               gene_list_id,
                                               source,
                                               ensembl_gene_id,
                                               ensembl_transcript_id, 
                                               refseq_mrna,
                                               hgnc_symbol,
                                               organism,
                                               alias,
                                               direction_string)

        ls_geneDictionaries.append(temp_gene_dictionary)
        print(temp_gene_dictionary)
# Out:
# up
# {'Index': 1, 'Gene_name': 'HTRA1', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000020533', 'Ensembl_transcript_id': 'ENSRNOT00000111703|ENSRNOT00000027860|ENSRNOT00000115809', 'RefSeq_mRNA_id': 'NM_031721', 'Organism': 'rat', 'HGNC_symbol': 'HTRA1', 'Alias': '', 'Info': 'up'}
# up
# {'Index': 2, 'Gene_name': 'HOPX', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000024689', 'Ensembl_transcript_id': 'ENSRNOT00000049774', 'RefSeq_mRNA_id': 'NM_133621', 'Organism': 'rat', 'HGNC_symbol': 'HOPX', 'Alias': '', 'Info': 'up'}
# up
# {'Index': 3, 'Gene_name': 'ALDOC', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000011452', 'Ensembl_transcript_id': 'ENSRNOT00000015535|ENSRNOT00000046388|ENSRNOT00000086036', 'RefSeq_mRNA_id': 'NM_012497', 'Organism': 'rat', 'HGNC_symbol': 'ALDOC', 'Alias': '', 'Info': 'up'}
# up
# ['MT1A']
# {'Index': 4, 'Gene_name': 'MT1A', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': '', 'Ensembl_transcript_id': '', 'RefSeq_mRNA_id': '', 'Organism': 'rat', 'HGNC_symbol': '', 'Alias': '', 'Info': 'up'}
# down
# ['MT1A', 'RGD1566244_PREDICTED']
# {'Index': 5, 'Gene_name': 'RGD1566244_PREDICTED', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': '', 'Ensembl_transcript_id': '', 'RefSeq_mRNA_id': '', 'Organism': 'rat', 'HGNC_symbol': '', 'Alias': '', 'Info': 'down'}
# up
# {'Index': 6, 'Gene_name': 'SULT1A1', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000019342', 'Ensembl_transcript_id': 'ENSRNOT00000026186', 'RefSeq_mRNA_id': 'NM_031834', 'Organism': 'rat', 'HGNC_symbol': '', 'Alias': '', 'Info': 'up'}
# up
# {'Index': 7, 'Gene_name': 'PHYHD1', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000016794', 'Ensembl_transcript_id': 'ENSRNOT00000112840|ENSRNOT00000095142|ENSRNOT00000022552', 'RefSeq_mRNA_id': 'NM_001013081', 'Organism': 'rat', 'HGNC_symbol': 'PHYHD1', 'Alias': '', 'Info': 'up'}
# up
# {'Index': 8, 'Gene_name': 'CDO1', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000000158', 'Ensembl_transcript_id': 'ENSRNOT00000107879|ENSRNOT00000000172|ENSRNOT00000096478', 'RefSeq_mRNA_id': 'NM_052809', 'Organism': 'rat', 'HGNC_symbol': 'CDO1', 'Alias': '', 'Info': 'up'}
# up
# {'Index': 9, 'Gene_name': 'PAWR', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000005917', 'Ensembl_transcript_id': 'ENSRNOT00000096379|ENSRNOT00000008222|ENSRNOT00000113713', 'RefSeq_mRNA_id': 'NM_033485', 'Organism': 'rat', 'HGNC_symbol': 'PAWR', 'Alias': '', 'Info': 'up'}
# down
# {'Index': 10, 'Gene_name': 'EDNRB', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000010997', 'Ensembl_transcript_id': 'ENSRNOT00000014747', 'RefSeq_mRNA_id': 'NM_017333', 'Organism': 'rat', 'HGNC_symbol': 'EDNRB', 'Alias': '', 'Info': 'down'}
# up
# {'Index': 11, 'Gene_name': 'FKBP5', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000022523', 'Ensembl_transcript_id': 'ENSRNOT00000109678|ENSRNOT00000033119', 'RefSeq_mRNA_id': 'NM_001012174', 'Organism': 'rat', 'HGNC_symbol': 'FKBP5', 'Alias': '', 'Info': 'up'}
# up
# ['MT1A', 'RGD1566244_PREDICTED', 'FBLN1_PREDICTED']
# {'Index': 12, 'Gene_name': 'FBLN1_PREDICTED', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': '', 'Ensembl_transcript_id': '', 'RefSeq_mRNA_id': '', 'Organism': 'rat', 'HGNC_symbol': '', 'Alias': '', 'Info': 'up'}
# up
# ['MT1A', 'RGD1566244_PREDICTED', 'FBLN1_PREDICTED', 'CTGF']
# {'Index': 13, 'Gene_name': 'CTGF', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': '', 'Ensembl_transcript_id': '', 'RefSeq_mRNA_id': '', 'Organism': 'rat', 'HGNC_symbol': '', 'Alias': '', 'Info': 'up'}
# up
# {'Index': 14, 'Gene_name': 'HTRA1', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000020533', 'Ensembl_transcript_id': 'ENSRNOT00000111703|ENSRNOT00000027860|ENSRNOT00000115809', 'RefSeq_mRNA_id': 'NM_031721', 'Organism': 'rat', 'HGNC_symbol': 'HTRA1', 'Alias': '', 'Info': 'up'}
# up
# {'Index': 15, 'Gene_name': 'CTSC', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000016496', 'Ensembl_transcript_id': 'ENSRNOT00000097085|ENSRNOT00000022342|ENSRNOT00000108529', 'RefSeq_mRNA_id': 'NM_017097', 'Organism': 'rat', 'HGNC_symbol': 'CTSC', 'Alias': '', 'Info': 'up'}
# up
# {'Index': 16, 'Gene_name': 'TSC22D3', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000056135', 'Ensembl_transcript_id': 'ENSRNOT00000085118|ENSRNOT00000108889|ENSRNOT00000117710', 'RefSeq_mRNA_id': 'NM_031345', 'Organism': 'rat', 'HGNC_symbol': 'TSC22D3', 'Alias': '', 'Info': 'up'}
# up
# ['MT1A', 'RGD1566244_PREDICTED', 'FBLN1_PREDICTED', 'CTGF', 'EIF1B_PREDICTED']
# {'Index': 17, 'Gene_name': 'EIF1B_PREDICTED', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': '', 'Ensembl_transcript_id': '', 'RefSeq_mRNA_id': '', 'Organism': 'rat', 'HGNC_symbol': '', 'Alias': '', 'Info': 'up'}
# up
# ['MT1A', 'RGD1566244_PREDICTED', 'FBLN1_PREDICTED', 'CTGF', 'EIF1B_PREDICTED', 'SGK']
# {'Index': 18, 'Gene_name': 'SGK', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': '', 'Ensembl_transcript_id': '', 'RefSeq_mRNA_id': '', 'Organism': 'rat', 'HGNC_symbol': '', 'Alias': '', 'Info': 'up'}
# up
# ['MT1A', 'RGD1566244_PREDICTED', 'FBLN1_PREDICTED', 'CTGF', 'EIF1B_PREDICTED', 'SGK', 'LOC311772']
# {'Index': 19, 'Gene_name': 'LOC311772', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': '', 'Ensembl_transcript_id': '', 'RefSeq_mRNA_id': '', 'Organism': 'rat', 'HGNC_symbol': '', 'Alias': '', 'Info': 'up'}
# down
# {'Index': 20, 'Gene_name': 'STMN2', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000011705', 'Ensembl_transcript_id': 'ENSRNOT00000015720|ENSRNOT00000095634', 'RefSeq_mRNA_id': 'NM_053440', 'Organism': 'rat', 'HGNC_symbol': 'STMN2', 'Alias': '', 'Info': 'down'}
# up
# {'Index': 21, 'Gene_name': 'GRINA', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000029941', 'Ensembl_transcript_id': 'ENSRNOT00000059599', 'RefSeq_mRNA_id': 'NM_153308', 'Organism': 'rat', 'HGNC_symbol': 'GRINA', 'Alias': '', 'Info': 'up'}
# down
# {'Index': 22, 'Gene_name': 'PLEKHB1', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000018627', 'Ensembl_transcript_id': 'ENSRNOT00000110941|ENSRNOT00000110726|ENSRNOT00000082697|ENSRNOT00000120073|ENSRNOT00000025245', 'RefSeq_mRNA_id': 'NM_172033', 'Organism': 'rat', 'HGNC_symbol': 'PLEKHB1', 'Alias': '', 'Info': 'down'}
# up
# {'Index': 23, 'Gene_name': 'CRYAB', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000010524', 'Ensembl_transcript_id': 'ENSRNOT00000059127', 'RefSeq_mRNA_id': 'NM_012935', 'Organism': 'rat', 'HGNC_symbol': 'CRYAB', 'Alias': '', 'Info': 'up'}
# up
# {'Index': 24, 'Gene_name': 'DDIT4', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000057078', 'Ensembl_transcript_id': 'ENSRNOT00000085026', 'RefSeq_mRNA_id': 'NM_080906', 'Organism': 'rat', 'HGNC_symbol': 'DDIT4', 'Alias': '', 'Info': 'up'}
# down
# {'Index': 25, 'Gene_name': 'CYP7B1', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000009730', 'Ensembl_transcript_id': 'ENSRNOT00000013116|ENSRNOT00000082084', 'RefSeq_mRNA_id': 'NM_019138', 'Organism': 'rat', 'HGNC_symbol': 'CYP7B1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 26, 'Gene_name': 'TSPAN12', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000059016', 'Ensembl_transcript_id': 'ENSRNOT00000083938|ENSRNOT00000100250', 'RefSeq_mRNA_id': 'NM_001015026', 'Organism': 'rat', 'HGNC_symbol': 'TSPAN12', 'Alias': '', 'Info': 'down'}
# up
# {'Index': 27, 'Gene_name': 'CSAD', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000011573', 'Ensembl_transcript_id': 'ENSRNOT00000016205|ENSRNOT00000113521|ENSRNOT00000102299|ENSRNOT00000079678|ENSRNOT00000117956|ENSRNOT00000110884', 'RefSeq_mRNA_id': 'NM_021750', 'Organism': 'rat', 'HGNC_symbol': 'CSAD', 'Alias': '', 'Info': 'up'}
# up
# {'Index': 28, 'Gene_name': 'RESP18', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000019704', 'Ensembl_transcript_id': 'ENSRNOT00000026753|ENSRNOT00000116091|ENSRNOT00000089555', 'RefSeq_mRNA_id': 'NM_019278', 'Organism': 'rat', 'HGNC_symbol': 'RESP18', 'Alias': '', 'Info': 'up'}
# up
# {'Index': 29, 'Gene_name': 'GDA', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000018282', 'Ensembl_transcript_id': 'ENSRNOT00000107827|ENSRNOT00000024775', 'RefSeq_mRNA_id': 'NM_031776', 'Organism': 'rat', 'HGNC_symbol': 'GDA', 'Alias': '', 'Info': 'up'}
# up
# {'Index': 30, 'Gene_name': 'PRDX6', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000066585', 'Ensembl_transcript_id': 'ENSRNOT00000117915|ENSRNOT00000100083', 'RefSeq_mRNA_id': 'NM_053576', 'Organism': 'rat', 'HGNC_symbol': 'PRDX6', 'Alias': '', 'Info': 'up'}
# up
# {'Index': 31, 'Gene_name': 'AURKB', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000005659', 'Ensembl_transcript_id': 'ENSRNOT00000091016|ENSRNOT00000008492', 'RefSeq_mRNA_id': 'NM_053749', 'Organism': 'rat', 'HGNC_symbol': 'AURKB', 'Alias': '', 'Info': 'up'}
# up
# {'Index': 32, 'Gene_name': 'KLF9', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000014215', 'Ensembl_transcript_id': 'ENSRNOT00000019367', 'RefSeq_mRNA_id': 'NM_057211', 'Organism': 'rat', 'HGNC_symbol': 'KLF9', 'Alias': '', 'Info': 'up'}
# up
# ['MT1A', 'RGD1566244_PREDICTED', 'FBLN1_PREDICTED', 'CTGF', 'EIF1B_PREDICTED', 'SGK', 'LOC311772', 'NUPR1']
# {'Index': 33, 'Gene_name': 'NUPR1', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': '', 'Ensembl_transcript_id': '', 'RefSeq_mRNA_id': '', 'Organism': 'rat', 'HGNC_symbol': '', 'Alias': '', 'Info': 'up'}
# down
# {'Index': 34, 'Gene_name': 'HOPX', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000024689', 'Ensembl_transcript_id': 'ENSRNOT00000049774', 'RefSeq_mRNA_id': 'NM_133621', 'Organism': 'rat', 'HGNC_symbol': 'HOPX', 'Alias': '', 'Info': 'down'}
# up
# {'Index': 35, 'Gene_name': 'OAF', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000009243', 'Ensembl_transcript_id': 'ENSRNOT00000012826', 'RefSeq_mRNA_id': 'NM_001014090', 'Organism': 'rat', 'HGNC_symbol': 'OAF', 'Alias': '', 'Info': 'up'}
# down
# {'Index': 36, 'Gene_name': 'SPP1', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000043451', 'Ensembl_transcript_id': 'ENSRNOT00000067875|ENSRNOT00000075989', 'RefSeq_mRNA_id': 'NM_012881', 'Organism': 'rat', 'HGNC_symbol': 'SPP1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 37, 'Gene_name': 'PNOC', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000014231', 'Ensembl_transcript_id': 'ENSRNOT00000019117', 'RefSeq_mRNA_id': 'NM_013007', 'Organism': 'rat', 'HGNC_symbol': 'PNOC', 'Alias': '', 'Info': 'down'}
# up
# {'Index': 38, 'Gene_name': 'OPLAH', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000011781', 'Ensembl_transcript_id': 'ENSRNOT00000077314|ENSRNOT00000080724|ENSRNOT00000016424|ENSRNOT00000110169', 'RefSeq_mRNA_id': 'NM_053904', 'Organism': 'rat', 'HGNC_symbol': 'OPLAH', 'Alias': '', 'Info': 'up'}
# down
# {'Index': 39, 'Gene_name': 'CXCL1', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000002802', 'Ensembl_transcript_id': 'ENSRNOT00000003778', 'RefSeq_mRNA_id': 'NM_030845', 'Organism': 'rat', 'HGNC_symbol': '', 'Alias': '', 'Info': 'down'}
# up
# ['MT1A', 'RGD1566244_PREDICTED', 'FBLN1_PREDICTED', 'CTGF', 'EIF1B_PREDICTED', 'SGK', 'LOC311772', 'NUPR1', 'RHOB']
# {'Index': 40, 'Gene_name': 'RHOB', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': '', 'Ensembl_transcript_id': '', 'RefSeq_mRNA_id': '', 'Organism': 'rat', 'HGNC_symbol': '', 'Alias': '', 'Info': 'up'}
# up
# {'Index': 41, 'Gene_name': 'ATP1A2', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000007290', 'Ensembl_transcript_id': 'ENSRNOT00000118040|ENSRNOT00000058143|ENSRNOT00000108846', 'RefSeq_mRNA_id': 'NM_012505', 'Organism': 'rat', 'HGNC_symbol': 'ATP1A2', 'Alias': '', 'Info': 'up'}
# down
# ['MT1A', 'RGD1566244_PREDICTED', 'FBLN1_PREDICTED', 'CTGF', 'EIF1B_PREDICTED', 'SGK', 'LOC311772', 'NUPR1', 'RHOB', 'LOC310926']
# {'Index': 42, 'Gene_name': 'LOC310926', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': '', 'Ensembl_transcript_id': '', 'RefSeq_mRNA_id': '', 'Organism': 'rat', 'HGNC_symbol': '', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 43, 'Gene_name': 'SLC7A3', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000004133', 'Ensembl_transcript_id': 'ENSRNOT00000076336', 'RefSeq_mRNA_id': 'NM_017217', 'Organism': 'rat', 'HGNC_symbol': 'SLC7A3', 'Alias': '', 'Info': 'down'}
# up
# {'Index': 44, 'Gene_name': 'HTRA1', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000020533', 'Ensembl_transcript_id': 'ENSRNOT00000111703|ENSRNOT00000027860|ENSRNOT00000115809', 'RefSeq_mRNA_id': 'NM_031721', 'Organism': 'rat', 'HGNC_symbol': 'HTRA1', 'Alias': '', 'Info': 'up'}
# up
# {'Index': 45, 'Gene_name': 'CST3', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000005195', 'Ensembl_transcript_id': 'ENSRNOT00000101785|ENSRNOT00000007175', 'RefSeq_mRNA_id': 'NM_012837', 'Organism': 'rat', 'HGNC_symbol': 'CST3', 'Alias': '', 'Info': 'up'}
# up
# {'Index': 46, 'Gene_name': 'PLCL1', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000032659', 'Ensembl_transcript_id': 'ENSRNOT00000090621', 'RefSeq_mRNA_id': 'NM_053456', 'Organism': 'rat', 'HGNC_symbol': 'PLCL1', 'Alias': '', 'Info': 'up'}
# down
# {'Index': 47, 'Gene_name': 'GAP43', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000001528', 'Ensembl_transcript_id': 'ENSRNOT00000002091', 'RefSeq_mRNA_id': 'NM_017195', 'Organism': 'rat', 'HGNC_symbol': 'GAP43', 'Alias': '', 'Info': 'down'}
# up
# {'Index': 48, 'Gene_name': 'CRYAB', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000010524', 'Ensembl_transcript_id': 'ENSRNOT00000059127', 'RefSeq_mRNA_id': 'NM_012935', 'Organism': 'rat', 'HGNC_symbol': 'CRYAB', 'Alias': '', 'Info': 'up'}
# up
# ['MT1A', 'RGD1566244_PREDICTED', 'FBLN1_PREDICTED', 'CTGF', 'EIF1B_PREDICTED', 'SGK', 'LOC311772', 'NUPR1', 'RHOB', 'LOC310926', 'ARHGAP21_PREDICTED']
# {'Index': 49, 'Gene_name': 'ARHGAP21_PREDICTED', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': '', 'Ensembl_transcript_id': '', 'RefSeq_mRNA_id': '', 'Organism': 'rat', 'HGNC_symbol': '', 'Alias': '', 'Info': 'up'}
# down
# {'Index': 50, 'Gene_name': 'APOE', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000018454', 'Ensembl_transcript_id': 'ENSRNOT00000108411|ENSRNOT00000080453|ENSRNOT00000091574|ENSRNOT00000099048|ENSRNOT00000041891', 'RefSeq_mRNA_id': 'NM_001270684|NM_138828|NM_001270682|NM_001270681|NM_001270683', 'Organism': 'rat', 'HGNC_symbol': 'APOE', 'Alias': '', 'Info': 'down'}
# up
# {'Index': 51, 'Gene_name': 'GPD1', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000056457', 'Ensembl_transcript_id': 'ENSRNOT00000087662|ENSRNOT00000097280', 'RefSeq_mRNA_id': 'NM_022215', 'Organism': 'rat', 'HGNC_symbol': 'GPD1', 'Alias': '', 'Info': 'up'}
# up
# {'Index': 52, 'Gene_name': 'RCAN2', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000010350', 'Ensembl_transcript_id': 'ENSRNOT00000029593|ENSRNOT00000013956', 'RefSeq_mRNA_id': 'NM_175578', 'Organism': 'rat', 'HGNC_symbol': 'RCAN2', 'Alias': '', 'Info': 'up'}
# up
# {'Index': 53, 'Gene_name': 'THTPA', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000018105', 'Ensembl_transcript_id': 'ENSRNOT00000034073|ENSRNOT00000105427|ENSRNOT00000114494|ENSRNOT00000087430', 'RefSeq_mRNA_id': 'NM_001007682', 'Organism': 'rat', 'HGNC_symbol': 'THTPA', 'Alias': '', 'Info': 'up'}
# down
# {'Index': 54, 'Gene_name': 'FCGR3A', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000024382', 'Ensembl_transcript_id': 'ENSRNOT00000086223|ENSRNOT00000047434', 'RefSeq_mRNA_id': 'NM_207603', 'Organism': 'rat', 'HGNC_symbol': 'FCGR3B', 'Alias': '', 'Info': 'down'}
# down
# ['MT1A', 'RGD1566244_PREDICTED', 'FBLN1_PREDICTED', 'CTGF', 'EIF1B_PREDICTED', 'SGK', 'LOC311772', 'NUPR1', 'RHOB', 'LOC310926', 'ARHGAP21_PREDICTED', 'MSR2_PREDICTED']
# {'Index': 55, 'Gene_name': 'MSR2_PREDICTED', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': '', 'Ensembl_transcript_id': '', 'RefSeq_mRNA_id': '', 'Organism': 'rat', 'HGNC_symbol': '', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 56, 'Gene_name': 'CORO1A', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000019430', 'Ensembl_transcript_id': 'ENSRNOT00000106786|ENSRNOT00000026496', 'RefSeq_mRNA_id': 'NM_130411', 'Organism': 'rat', 'HGNC_symbol': 'CORO1A', 'Alias': '', 'Info': 'down'}
# down
# ['MT1A', 'RGD1566244_PREDICTED', 'FBLN1_PREDICTED', 'CTGF', 'EIF1B_PREDICTED', 'SGK', 'LOC311772', 'NUPR1', 'RHOB', 'LOC310926', 'ARHGAP21_PREDICTED', 'MSR2_PREDICTED', 'PFC_MAPPED']
# {'Index': 57, 'Gene_name': 'PFC_MAPPED', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': '', 'Ensembl_transcript_id': '', 'RefSeq_mRNA_id': '', 'Organism': 'rat', 'HGNC_symbol': '', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 58, 'Gene_name': 'RAC2', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000007350', 'Ensembl_transcript_id': 'ENSRNOT00000009994|ENSRNOT00000097718|ENSRNOT00000100644', 'RefSeq_mRNA_id': 'NM_001008384', 'Organism': 'rat', 'HGNC_symbol': 'RAC2', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 59, 'Gene_name': 'LPL', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000012181', 'Ensembl_transcript_id': 'ENSRNOT00000016543', 'RefSeq_mRNA_id': 'NM_012598', 'Organism': 'rat', 'HGNC_symbol': 'LPL', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 60, 'Gene_name': 'APOBEC1', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000015411', 'Ensembl_transcript_id': 'ENSRNOT00000020735|ENSRNOT00000118333|ENSRNOT00000106242|ENSRNOT00000109144', 'RefSeq_mRNA_id': 'NM_012907', 'Organism': 'rat', 'HGNC_symbol': 'APOBEC1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 61, 'Gene_name': 'LAPTM5', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000011054', 'Ensembl_transcript_id': 'ENSRNOT00000015198|ENSRNOT00000083028', 'RefSeq_mRNA_id': 'NM_053538', 'Organism': 'rat', 'HGNC_symbol': 'LAPTM5', 'Alias': '', 'Info': 'down'}
# down
# ['MT1A', 'RGD1566244_PREDICTED', 'FBLN1_PREDICTED', 'CTGF', 'EIF1B_PREDICTED', 'SGK', 'LOC311772', 'NUPR1', 'RHOB', 'LOC310926', 'ARHGAP21_PREDICTED', 'MSR2_PREDICTED', 'PFC_MAPPED', 'TREM2_PREDICTED']
# {'Index': 62, 'Gene_name': 'TREM2_PREDICTED', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': '', 'Ensembl_transcript_id': '', 'RefSeq_mRNA_id': '', 'Organism': 'rat', 'HGNC_symbol': '', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 63, 'Gene_name': 'CTSC', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000016496', 'Ensembl_transcript_id': 'ENSRNOT00000097085|ENSRNOT00000022342|ENSRNOT00000108529', 'RefSeq_mRNA_id': 'NM_017097', 'Organism': 'rat', 'HGNC_symbol': 'CTSC', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 64, 'Gene_name': 'IFI30', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000019387', 'Ensembl_transcript_id': 'ENSRNOT00000097172|ENSRNOT00000026225|ENSRNOT00000108678', 'RefSeq_mRNA_id': 'NM_001030026', 'Organism': 'rat', 'HGNC_symbol': 'IFI30', 'Alias': '', 'Info': 'down'}
# down
# ['MT1A', 'RGD1566244_PREDICTED', 'FBLN1_PREDICTED', 'CTGF', 'EIF1B_PREDICTED', 'SGK', 'LOC311772', 'NUPR1', 'RHOB', 'LOC310926', 'ARHGAP21_PREDICTED', 'MSR2_PREDICTED', 'PFC_MAPPED', 'TREM2_PREDICTED', 'CD83_PREDICTED']
# {'Index': 65, 'Gene_name': 'CD83_PREDICTED', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': '', 'Ensembl_transcript_id': '', 'RefSeq_mRNA_id': '', 'Organism': 'rat', 'HGNC_symbol': '', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 66, 'Gene_name': 'HPRT1', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000031367', 'Ensembl_transcript_id': 'ENSRNOT00000103414|ENSRNOT00000109953|ENSRNOT00000103150|ENSRNOT00000065935|ENSRNOT00000045153', 'RefSeq_mRNA_id': 'NM_012583', 'Organism': 'rat', 'HGNC_symbol': 'HPRT1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 67, 'Gene_name': 'EHD4', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000007584', 'Ensembl_transcript_id': 'ENSRNOT00000010701', 'RefSeq_mRNA_id': 'NM_139324', 'Organism': 'rat', 'HGNC_symbol': 'EHD4', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 68, 'Gene_name': 'LCP1', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000010319', 'Ensembl_transcript_id': 'ENSRNOT00000082191|ENSRNOT00000105314|ENSRNOT00000094863|ENSRNOT00000014502', 'RefSeq_mRNA_id': 'NM_001012044', 'Organism': 'rat', 'HGNC_symbol': 'LCP1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 69, 'Gene_name': 'TMEM176B', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000008465', 'Ensembl_transcript_id': 'ENSRNOT00000011327|ENSRNOT00000078473', 'RefSeq_mRNA_id': 'NM_001270591|NM_001270590|NM_134390|NM_001270589|NM_001270593|NM_001270592|NM_001270594', 'Organism': 'rat', 'HGNC_symbol': 'TMEM176B', 'Alias': '', 'Info': 'down'}
# down
# ['MT1A', 'RGD1566244_PREDICTED', 'FBLN1_PREDICTED', 'CTGF', 'EIF1B_PREDICTED', 'SGK', 'LOC311772', 'NUPR1', 'RHOB', 'LOC310926', 'ARHGAP21_PREDICTED', 'MSR2_PREDICTED', 'PFC_MAPPED', 'TREM2_PREDICTED', 'CD83_PREDICTED', 'PLTP_PREDICTED']
# {'Index': 70, 'Gene_name': 'PLTP_PREDICTED', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': '', 'Ensembl_transcript_id': '', 'RefSeq_mRNA_id': '', 'Organism': 'rat', 'HGNC_symbol': '', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 71, 'Gene_name': 'GMFG', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000019838', 'Ensembl_transcript_id': 'ENSRNOT00000118600|ENSRNOT00000026891|ENSRNOT00000118560', 'RefSeq_mRNA_id': 'NM_181091', 'Organism': 'rat', 'HGNC_symbol': 'GMFG', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 72, 'Gene_name': 'UCP2', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000017854', 'Ensembl_transcript_id': 'ENSRNOT00000024156', 'RefSeq_mRNA_id': 'NM_019354', 'Organism': 'rat', 'HGNC_symbol': 'UCP2', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 73, 'Gene_name': 'RGS10', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000042592', 'Ensembl_transcript_id': 'ENSRNOT00000111253|ENSRNOT00000117000|ENSRNOT00000027375', 'RefSeq_mRNA_id': 'NM_019337', 'Organism': 'rat', 'HGNC_symbol': 'RGS10', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 74, 'Gene_name': 'JAK3', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000018669', 'Ensembl_transcript_id': 'ENSRNOT00000025312', 'RefSeq_mRNA_id': 'NM_012855', 'Organism': 'rat', 'HGNC_symbol': 'JAK3', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 75, 'Gene_name': 'ABCG1', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000001158', 'Ensembl_transcript_id': 'ENSRNOT00000001533|ENSRNOT00000083505|ENSRNOT00000078031', 'RefSeq_mRNA_id': 'NM_053502', 'Organism': 'rat', 'HGNC_symbol': 'ABCG1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 76, 'Gene_name': 'ARHGAP17', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000013836', 'Ensembl_transcript_id': 'ENSRNOT00000031770|ENSRNOT00000117754|ENSRNOT00000097528|ENSRNOT00000105291|ENSRNOT00000019309|ENSRNOT00000019304', 'RefSeq_mRNA_id': 'NM_022244|NM_001270692|NM_001270693|NM_001270694', 'Organism': 'rat', 'HGNC_symbol': 'ARHGAP17', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 77, 'Gene_name': 'PTPN6', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000014294', 'Ensembl_transcript_id': 'ENSRNOT00000079947|ENSRNOT00000065416|ENSRNOT00000117641|ENSRNOT00000082739|ENSRNOT00000102617', 'RefSeq_mRNA_id': 'NM_053908', 'Organism': 'rat', 'HGNC_symbol': 'PTPN6', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 78, 'Gene_name': 'GRN', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000021031', 'Ensembl_transcript_id': 'ENSRNOT00000028557|ENSRNOT00000040472', 'RefSeq_mRNA_id': 'NM_017113|NM_001145842', 'Organism': 'rat', 'HGNC_symbol': 'GRN', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 79, 'Gene_name': 'SIRPA', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000004763', 'Ensembl_transcript_id': 'ENSRNOT00000117905|ENSRNOT00000006408|ENSRNOT00000103247|ENSRNOT00000091935|ENSRNOT00000095684|ENSRNOT00000109073', 'RefSeq_mRNA_id': 'NM_013016', 'Organism': 'rat', 'HGNC_symbol': 'SIRPB1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 80, 'Gene_name': 'PSMB8', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000000456', 'Ensembl_transcript_id': 'ENSRNOT00000000528|ENSRNOT00000082047', 'RefSeq_mRNA_id': 'NM_080767', 'Organism': 'rat', 'HGNC_symbol': 'PSMB8', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 81, 'Gene_name': 'TMEM37', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000047714', 'Ensembl_transcript_id': 'ENSRNOT00000098837|ENSRNOT00000074471', 'RefSeq_mRNA_id': 'NM_139095', 'Organism': 'rat', 'HGNC_symbol': 'TMEM37', 'Alias': '', 'Info': 'down'}
# down
# ['MT1A', 'RGD1566244_PREDICTED', 'FBLN1_PREDICTED', 'CTGF', 'EIF1B_PREDICTED', 'SGK', 'LOC311772', 'NUPR1', 'RHOB', 'LOC310926', 'ARHGAP21_PREDICTED', 'MSR2_PREDICTED', 'PFC_MAPPED', 'TREM2_PREDICTED', 'CD83_PREDICTED', 'PLTP_PREDICTED', 'LOC310926']
# {'Index': 82, 'Gene_name': 'LOC310926', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': '', 'Ensembl_transcript_id': '', 'RefSeq_mRNA_id': '', 'Organism': 'rat', 'HGNC_symbol': '', 'Alias': '', 'Info': 'down'}
# down
# ['MT1A', 'RGD1566244_PREDICTED', 'FBLN1_PREDICTED', 'CTGF', 'EIF1B_PREDICTED', 'SGK', 'LOC311772', 'NUPR1', 'RHOB', 'LOC310926', 'ARHGAP21_PREDICTED', 'MSR2_PREDICTED', 'PFC_MAPPED', 'TREM2_PREDICTED', 'CD83_PREDICTED', 'PLTP_PREDICTED', 'LOC310926', 'ADFP']
# {'Index': 83, 'Gene_name': 'ADFP', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': '', 'Ensembl_transcript_id': '', 'RefSeq_mRNA_id': '', 'Organism': 'rat', 'HGNC_symbol': '', 'Alias': '', 'Info': 'down'}
# down
# ['MT1A', 'RGD1566244_PREDICTED', 'FBLN1_PREDICTED', 'CTGF', 'EIF1B_PREDICTED', 'SGK', 'LOC311772', 'NUPR1', 'RHOB', 'LOC310926', 'ARHGAP21_PREDICTED', 'MSR2_PREDICTED', 'PFC_MAPPED', 'TREM2_PREDICTED', 'CD83_PREDICTED', 'PLTP_PREDICTED', 'LOC310926', 'ADFP', 'HLA-DMB']
# {'Index': 84, 'Gene_name': 'HLA-DMB', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': '', 'Ensembl_transcript_id': '', 'RefSeq_mRNA_id': '', 'Organism': 'rat', 'HGNC_symbol': '', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 85, 'Gene_name': 'RGS2', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000003687', 'Ensembl_transcript_id': 'ENSRNOT00000005156|ENSRNOT00000093882', 'RefSeq_mRNA_id': 'NM_053453', 'Organism': 'rat', 'HGNC_symbol': 'RGS2', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 86, 'Gene_name': 'SCPEP1', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000002358', 'Ensembl_transcript_id': 'ENSRNOT00000104820|ENSRNOT00000110780|ENSRNOT00000003219', 'RefSeq_mRNA_id': 'NM_133383', 'Organism': 'rat', 'HGNC_symbol': 'SCPEP1', 'Alias': '', 'Info': 'down'}
# down
# ['MT1A', 'RGD1566244_PREDICTED', 'FBLN1_PREDICTED', 'CTGF', 'EIF1B_PREDICTED', 'SGK', 'LOC311772', 'NUPR1', 'RHOB', 'LOC310926', 'ARHGAP21_PREDICTED', 'MSR2_PREDICTED', 'PFC_MAPPED', 'TREM2_PREDICTED', 'CD83_PREDICTED', 'PLTP_PREDICTED', 'LOC310926', 'ADFP', 'HLA-DMB', 'PEPD']
# {'Index': 87, 'Gene_name': 'PEPD', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': '', 'Ensembl_transcript_id': '', 'RefSeq_mRNA_id': '', 'Organism': 'rat', 'HGNC_symbol': '', 'Alias': '', 'Info': 'down'}
# down
# ['MT1A', 'RGD1566244_PREDICTED', 'FBLN1_PREDICTED', 'CTGF', 'EIF1B_PREDICTED', 'SGK', 'LOC311772', 'NUPR1', 'RHOB', 'LOC310926', 'ARHGAP21_PREDICTED', 'MSR2_PREDICTED', 'PFC_MAPPED', 'TREM2_PREDICTED', 'CD83_PREDICTED', 'PLTP_PREDICTED', 'LOC310926', 'ADFP', 'HLA-DMB', 'PEPD', 'LY86_PREDICTED']
# {'Index': 88, 'Gene_name': 'LY86_PREDICTED', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': '', 'Ensembl_transcript_id': '', 'RefSeq_mRNA_id': '', 'Organism': 'rat', 'HGNC_symbol': '', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 89, 'Gene_name': 'ARHGDIB', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000005809', 'Ensembl_transcript_id': 'ENSRNOT00000109610|ENSRNOT00000007779', 'RefSeq_mRNA_id': 'NM_001009600', 'Organism': 'rat', 'HGNC_symbol': 'ARHGDIB', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 90, 'Gene_name': 'LYL1', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000002950', 'Ensembl_transcript_id': 'ENSRNOT00000003980', 'RefSeq_mRNA_id': 'NM_001007677', 'Organism': 'rat', 'HGNC_symbol': 'LYL1', 'Alias': '', 'Info': 'down'}
# down
# ['MT1A', 'RGD1566244_PREDICTED', 'FBLN1_PREDICTED', 'CTGF', 'EIF1B_PREDICTED', 'SGK', 'LOC311772', 'NUPR1', 'RHOB', 'LOC310926', 'ARHGAP21_PREDICTED', 'MSR2_PREDICTED', 'PFC_MAPPED', 'TREM2_PREDICTED', 'CD83_PREDICTED', 'PLTP_PREDICTED', 'LOC310926', 'ADFP', 'HLA-DMB', 'PEPD', 'LY86_PREDICTED', 'RT1-A1']
# {'Index': 91, 'Gene_name': 'RT1-A1', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': '', 'Ensembl_transcript_id': '', 'RefSeq_mRNA_id': '', 'Organism': 'rat', 'HGNC_symbol': '', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 92, 'Gene_name': 'PSAP', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000000571', 'Ensembl_transcript_id': 'ENSRNOT00000093802|ENSRNOT00000000696|ENSRNOT00000104593', 'RefSeq_mRNA_id': 'NM_001190238|NM_013013|NM_001190236|NM_001190237', 'Organism': 'rat', 'HGNC_symbol': 'PSAP', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 93, 'Gene_name': 'SPP1', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000043451', 'Ensembl_transcript_id': 'ENSRNOT00000067875|ENSRNOT00000075989', 'RefSeq_mRNA_id': 'NM_012881', 'Organism': 'rat', 'HGNC_symbol': 'SPP1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 94, 'Gene_name': 'NINJ1', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000016587', 'Ensembl_transcript_id': 'ENSRNOT00000022341', 'RefSeq_mRNA_id': 'NM_012867', 'Organism': 'rat', 'HGNC_symbol': 'NINJ1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 95, 'Gene_name': 'CD68', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000037563', 'Ensembl_transcript_id': 'ENSRNOT00000056918|ENSRNOT00000111511', 'RefSeq_mRNA_id': 'NM_001031638', 'Organism': 'rat', 'HGNC_symbol': 'CD68', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 96, 'Gene_name': 'CD302', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000006623', 'Ensembl_transcript_id': 'ENSRNOT00000008987|ENSRNOT00000106977|ENSRNOT00000112941|ENSRNOT00000115034', 'RefSeq_mRNA_id': 'NM_001013916', 'Organism': 'rat', 'HGNC_symbol': 'CD302', 'Alias': '', 'Info': 'down'}
# down
# ['MT1A', 'RGD1566244_PREDICTED', 'FBLN1_PREDICTED', 'CTGF', 'EIF1B_PREDICTED', 'SGK', 'LOC311772', 'NUPR1', 'RHOB', 'LOC310926', 'ARHGAP21_PREDICTED', 'MSR2_PREDICTED', 'PFC_MAPPED', 'TREM2_PREDICTED', 'CD83_PREDICTED', 'PLTP_PREDICTED', 'LOC310926', 'ADFP', 'HLA-DMB', 'PEPD', 'LY86_PREDICTED', 'RT1-A1', 'GNS_PREDICTED']
# {'Index': 97, 'Gene_name': 'GNS_PREDICTED', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': '', 'Ensembl_transcript_id': '', 'RefSeq_mRNA_id': '', 'Organism': 'rat', 'HGNC_symbol': '', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 98, 'Gene_name': 'OPLAH', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000011781', 'Ensembl_transcript_id': 'ENSRNOT00000077314|ENSRNOT00000080724|ENSRNOT00000016424|ENSRNOT00000110169', 'RefSeq_mRNA_id': 'NM_053904', 'Organism': 'rat', 'HGNC_symbol': 'OPLAH', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 99, 'Gene_name': 'TXNIP', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000021201', 'Ensembl_transcript_id': 'ENSRNOT00000115326|ENSRNOT00000028793', 'RefSeq_mRNA_id': 'NM_001008767', 'Organism': 'rat', 'HGNC_symbol': 'TXNIP', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 100, 'Gene_name': 'SP110', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000033747', 'Ensembl_transcript_id': 'ENSRNOT00000056995', 'RefSeq_mRNA_id': 'NM_001034137', 'Organism': 'rat', 'HGNC_symbol': 'SP110', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 101, 'Gene_name': 'PF4', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000028015', 'Ensembl_transcript_id': 'ENSRNOT00000033406', 'RefSeq_mRNA_id': 'NM_001007729', 'Organism': 'rat', 'HGNC_symbol': '', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 102, 'Gene_name': 'ANXA3', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000002045', 'Ensembl_transcript_id': 'ENSRNOT00000068134|ENSRNOT00000096016|ENSRNOT00000119515|ENSRNOT00000046639', 'RefSeq_mRNA_id': 'NM_012823', 'Organism': 'rat', 'HGNC_symbol': 'ANXA3', 'Alias': '', 'Info': 'down'}
# down
# ['MT1A', 'RGD1566244_PREDICTED', 'FBLN1_PREDICTED', 'CTGF', 'EIF1B_PREDICTED', 'SGK', 'LOC311772', 'NUPR1', 'RHOB', 'LOC310926', 'ARHGAP21_PREDICTED', 'MSR2_PREDICTED', 'PFC_MAPPED', 'TREM2_PREDICTED', 'CD83_PREDICTED', 'PLTP_PREDICTED', 'LOC310926', 'ADFP', 'HLA-DMB', 'PEPD', 'LY86_PREDICTED', 'RT1-A1', 'GNS_PREDICTED', 'RGD1303130']
# {'Index': 103, 'Gene_name': 'RGD1303130', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': '', 'Ensembl_transcript_id': '', 'RefSeq_mRNA_id': '', 'Organism': 'rat', 'HGNC_symbol': '', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 104, 'Gene_name': 'DAB2', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000028930', 'Ensembl_transcript_id': 'ENSRNOT00000119991|ENSRNOT00000107382|ENSRNOT00000115810|ENSRNOT00000117029|ENSRNOT00000107345|ENSRNOT00000095085|ENSRNOT00000050655|ENSRNOT00000096270', 'RefSeq_mRNA_id': 'NM_024159', 'Organism': 'rat', 'HGNC_symbol': 'DAB2', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 105, 'Gene_name': 'NNT', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000026842', 'Ensembl_transcript_id': 'ENSRNOT00000108201|ENSRNOT00000107063|ENSRNOT00000103489|ENSRNOT00000112693|ENSRNOT00000033627|ENSRNOT00000116756', 'RefSeq_mRNA_id': 'NM_001013157', 'Organism': 'rat', 'HGNC_symbol': 'NNT', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 106, 'Gene_name': 'LGMN', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000007089', 'Ensembl_transcript_id': 'ENSRNOT00000010101|ENSRNOT00000103783', 'RefSeq_mRNA_id': 'NM_022226', 'Organism': 'rat', 'HGNC_symbol': 'LGMN', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 107, 'Gene_name': 'VAMP8', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000012748', 'Ensembl_transcript_id': 'ENSRNOT00000115330|ENSRNOT00000096938|ENSRNOT00000017301', 'RefSeq_mRNA_id': 'NM_031827', 'Organism': 'rat', 'HGNC_symbol': 'VAMP8', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 108, 'Gene_name': 'SKAP2', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000012228', 'Ensembl_transcript_id': 'ENSRNOT00000097980|ENSRNOT00000106495|ENSRNOT00000016608', 'RefSeq_mRNA_id': 'NM_130413', 'Organism': 'rat', 'HGNC_symbol': 'SKAP2', 'Alias': '', 'Info': 'down'}
# down
# ['MT1A', 'RGD1566244_PREDICTED', 'FBLN1_PREDICTED', 'CTGF', 'EIF1B_PREDICTED', 'SGK', 'LOC311772', 'NUPR1', 'RHOB', 'LOC310926', 'ARHGAP21_PREDICTED', 'MSR2_PREDICTED', 'PFC_MAPPED', 'TREM2_PREDICTED', 'CD83_PREDICTED', 'PLTP_PREDICTED', 'LOC310926', 'ADFP', 'HLA-DMB', 'PEPD', 'LY86_PREDICTED', 'RT1-A1', 'GNS_PREDICTED', 'RGD1303130', 'FBXW4_PREDICTED']
# {'Index': 109, 'Gene_name': 'FBXW4_PREDICTED', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': '', 'Ensembl_transcript_id': '', 'RefSeq_mRNA_id': '', 'Organism': 'rat', 'HGNC_symbol': '', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 110, 'Gene_name': 'PSME1', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000019041', 'Ensembl_transcript_id': 'ENSRNOT00000101716|ENSRNOT00000025887|ENSRNOT00000111999|ENSRNOT00000098373', 'RefSeq_mRNA_id': 'NM_017264', 'Organism': 'rat', 'HGNC_symbol': 'PSME1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 111, 'Gene_name': 'RHOG', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000020393', 'Ensembl_transcript_id': 'ENSRNOT00000027641|ENSRNOT00000117183|ENSRNOT00000101823', 'RefSeq_mRNA_id': 'NM_001037195', 'Organism': 'rat', 'HGNC_symbol': 'RHOG', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 112, 'Gene_name': 'TIFA', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000010941', 'Ensembl_transcript_id': 'ENSRNOT00000097096|ENSRNOT00000014533|ENSRNOT00000102851|ENSRNOT00000112612|ENSRNOT00000083193', 'RefSeq_mRNA_id': 'NM_001014044', 'Organism': 'rat', 'HGNC_symbol': 'TIFA', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 113, 'Gene_name': 'CTSH', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000014064', 'Ensembl_transcript_id': 'ENSRNOT00000019285|ENSRNOT00000080142', 'RefSeq_mRNA_id': 'NM_012939', 'Organism': 'rat', 'HGNC_symbol': 'CTSH', 'Alias': '', 'Info': 'down'}
# down
# ['MT1A', 'RGD1566244_PREDICTED', 'FBLN1_PREDICTED', 'CTGF', 'EIF1B_PREDICTED', 'SGK', 'LOC311772', 'NUPR1', 'RHOB', 'LOC310926', 'ARHGAP21_PREDICTED', 'MSR2_PREDICTED', 'PFC_MAPPED', 'TREM2_PREDICTED', 'CD83_PREDICTED', 'PLTP_PREDICTED', 'LOC310926', 'ADFP', 'HLA-DMB', 'PEPD', 'LY86_PREDICTED', 'RT1-A1', 'GNS_PREDICTED', 'RGD1303130', 'FBXW4_PREDICTED', 'RT1-A3']
# {'Index': 114, 'Gene_name': 'RT1-A3', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': '', 'Ensembl_transcript_id': '', 'RefSeq_mRNA_id': '', 'Organism': 'rat', 'HGNC_symbol': '', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 115, 'Gene_name': 'PPT1', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000012616', 'Ensembl_transcript_id': 'ENSRNOT00000112154|ENSRNOT00000109802|ENSRNOT00000017998|ENSRNOT00000111724', 'RefSeq_mRNA_id': 'NM_022502', 'Organism': 'rat', 'HGNC_symbol': 'PPT1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 116, 'Gene_name': 'ALDH16A1', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000020623', 'Ensembl_transcript_id': 'ENSRNOT00000027992|ENSRNOT00000109143|ENSRNOT00000108838|ENSRNOT00000093319|ENSRNOT00000107469', 'RefSeq_mRNA_id': 'NM_001033706', 'Organism': 'rat', 'HGNC_symbol': 'ALDH16A1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 117, 'Gene_name': 'TPP1', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000019212', 'Ensembl_transcript_id': 'ENSRNOT00000105058|ENSRNOT00000026280', 'RefSeq_mRNA_id': 'NM_031357', 'Organism': 'rat', 'HGNC_symbol': 'TPP1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 118, 'Gene_name': 'CD48', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000004737', 'Ensembl_transcript_id': 'ENSRNOT00000111655|ENSRNOT00000113999|ENSRNOT00000006306', 'RefSeq_mRNA_id': 'NM_139103', 'Organism': 'rat', 'HGNC_symbol': 'CD48', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 119, 'Gene_name': 'UGCG', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000015644', 'Ensembl_transcript_id': 'ENSRNOT00000088872', 'RefSeq_mRNA_id': 'NM_031795', 'Organism': 'rat', 'HGNC_symbol': 'UGCG', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 120, 'Gene_name': 'UNC93B1', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000017703', 'Ensembl_transcript_id': 'ENSRNOT00000024018|ENSRNOT00000083942|ENSRNOT00000112547|ENSRNOT00000110255', 'RefSeq_mRNA_id': 'NM_001108513', 'Organism': 'rat', 'HGNC_symbol': 'UNC93B1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 121, 'Gene_name': 'ITM2C', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000017359', 'Ensembl_transcript_id': 'ENSRNOT00000023535|ENSRNOT00000103926', 'RefSeq_mRNA_id': 'NM_001009674', 'Organism': 'rat', 'HGNC_symbol': 'ITM2C', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 122, 'Gene_name': 'QPRT', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000016980', 'Ensembl_transcript_id': 'ENSRNOT00000023080|ENSRNOT00000097312|ENSRNOT00000108291', 'RefSeq_mRNA_id': 'NM_001009646', 'Organism': 'rat', 'HGNC_symbol': 'QPRT', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 123, 'Gene_name': 'ATP1B1', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000002934', 'Ensembl_transcript_id': 'ENSRNOT00000003932|ENSRNOT00000075948', 'RefSeq_mRNA_id': 'NM_013113', 'Organism': 'rat', 'HGNC_symbol': 'ATP1B1', 'Alias': '', 'Info': 'down'}
# down
# ['MT1A', 'RGD1566244_PREDICTED', 'FBLN1_PREDICTED', 'CTGF', 'EIF1B_PREDICTED', 'SGK', 'LOC311772', 'NUPR1', 'RHOB', 'LOC310926', 'ARHGAP21_PREDICTED', 'MSR2_PREDICTED', 'PFC_MAPPED', 'TREM2_PREDICTED', 'CD83_PREDICTED', 'PLTP_PREDICTED', 'LOC310926', 'ADFP', 'HLA-DMB', 'PEPD', 'LY86_PREDICTED', 'RT1-A1', 'GNS_PREDICTED', 'RGD1303130', 'FBXW4_PREDICTED', 'RT1-A3', 'LOC310946']
# ...
# {'Index': 296, 'Gene_name': 'LOC361912', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': '', 'Ensembl_transcript_id': '', 'RefSeq_mRNA_id': '', 'Organism': 'rat', 'HGNC_symbol': '', 'Alias': '', 'Info': 'up'}
# up
# ['MT1A', 'RGD1566244_PREDICTED', 'FBLN1_PREDICTED', 'CTGF', 'EIF1B_PREDICTED', 'SGK', 'LOC311772', 'NUPR1', 'RHOB', 'LOC310926', 'ARHGAP21_PREDICTED', 'MSR2_PREDICTED', 'PFC_MAPPED', 'TREM2_PREDICTED', 'CD83_PREDICTED', 'PLTP_PREDICTED', 'LOC310926', 'ADFP', 'HLA-DMB', 'PEPD', 'LY86_PREDICTED', 'RT1-A1', 'GNS_PREDICTED', 'RGD1303130', 'FBXW4_PREDICTED', 'RT1-A3', 'LOC310946', 'RGD1311381_PREDICTED', 'PRKCB1', 'FUCA', 'IFI27L', 'HARPB64', 'TMEPAI_PREDICTED', 'FHL3_PREDICTED', 'C2', 'BHLHB3', 'LOC497767', 'LOC306324', 'CREG_PREDICTED', 'AP1S2_PREDICTED', 'IFNGR2_PREDICTED', 'SH3BGRL3_PREDICTED', 'ARPC4_PREDICTED', 'TCFE3_PREDICTED', 'LOC500040', 'RGD1563276_PREDICTED', 'ISG12(B)', 'LOC499775', 'SART2_PREDICTED', 'RGD1560373_PREDICTED', 'TNIP1_PREDICTED', 'RRAGC_PREDICTED', 'MGC72614', 'ARPC3_PREDICTED', 'TMEM55B', 'SNX2_PREDICTED', 'DNASE2A', 'GLRX1', 'MGC94190', 'CERK_PREDICTED', 'RGD1564762_PREDICTED', 'CTTNBP2NL_PREDICTED', 'LOC309557', 'RGD1310868_PREDICTED', 'SWAP70_PREDICTED', 'LOC500788', 'RGD1564451_PREDICTED', 'UBE2S_PREDICTED', 'GPR56', 'LOC500155', 'SNURF', 'RGD1562047_PREDICTED', 'LOC500150', 'NDUFAB1_PREDICTED', 'RGD1560177_PREDICTED', 'RGD1306289_PREDICTED', 'LOC688712', 'MGST2_PREDICTED', 'MYBL1_PREDICTED', 'LOC500495', 'LOC690428', 'LOC500380', 'CTGF', 'LOC499554', 'MGC112883', 'LOC497920', 'LOC501553', 'RGD1308626', 'CSPG2', 'DUSP1', 'LOC498048', 'LOC363492', 'LOC501503', 'LOC361942', 'LOC362543', 'PLA2G12A_PREDICTED', 'LOC498378', 'LOC499560', 'LOC497844', 'LOC500398', 'LOC498799', 'LOC362315', 'RGD1307506_PREDICTED', 'CSDA', 'PRKCDBP', 'LOC500829', 'RGD1306811_PREDICTED', 'LOC499531', 'LOC500867', 'LOC498669', 'LOC498745', 'LOC361885', 'LOC498644', 'LOC498623', 'LOC361117', 'LOC499564', 'LOC500960', 'LOC498076', 'LOC500916', 'LOC500586', 'LOC361912', 'LOC499638']
# {'Index': 297, 'Gene_name': 'LOC499638', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': '', 'Ensembl_transcript_id': '', 'RefSeq_mRNA_id': '', 'Organism': 'rat', 'HGNC_symbol': '', 'Alias': '', 'Info': 'up'}
# up
# {'Index': 298, 'Gene_name': 'GPX3', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000052564', 'Ensembl_transcript_id': 'ENSRNOT00000079830|ENSRNOT00000112041|ENSRNOT00000097778', 'RefSeq_mRNA_id': 'NM_022525', 'Organism': 'rat', 'HGNC_symbol': '', 'Alias': '', 'Info': 'up'}
# up
# ['MT1A', 'RGD1566244_PREDICTED', 'FBLN1_PREDICTED', 'CTGF', 'EIF1B_PREDICTED', 'SGK', 'LOC311772', 'NUPR1', 'RHOB', 'LOC310926', 'ARHGAP21_PREDICTED', 'MSR2_PREDICTED', 'PFC_MAPPED', 'TREM2_PREDICTED', 'CD83_PREDICTED', 'PLTP_PREDICTED', 'LOC310926', 'ADFP', 'HLA-DMB', 'PEPD', 'LY86_PREDICTED', 'RT1-A1', 'GNS_PREDICTED', 'RGD1303130', 'FBXW4_PREDICTED', 'RT1-A3', 'LOC310946', 'RGD1311381_PREDICTED', 'PRKCB1', 'FUCA', 'IFI27L', 'HARPB64', 'TMEPAI_PREDICTED', 'FHL3_PREDICTED', 'C2', 'BHLHB3', 'LOC497767', 'LOC306324', 'CREG_PREDICTED', 'AP1S2_PREDICTED', 'IFNGR2_PREDICTED', 'SH3BGRL3_PREDICTED', 'ARPC4_PREDICTED', 'TCFE3_PREDICTED', 'LOC500040', 'RGD1563276_PREDICTED', 'ISG12(B)', 'LOC499775', 'SART2_PREDICTED', 'RGD1560373_PREDICTED', 'TNIP1_PREDICTED', 'RRAGC_PREDICTED', 'MGC72614', 'ARPC3_PREDICTED', 'TMEM55B', 'SNX2_PREDICTED', 'DNASE2A', 'GLRX1', 'MGC94190', 'CERK_PREDICTED', 'RGD1564762_PREDICTED', 'CTTNBP2NL_PREDICTED', 'LOC309557', 'RGD1310868_PREDICTED', 'SWAP70_PREDICTED', 'LOC500788', 'RGD1564451_PREDICTED', 'UBE2S_PREDICTED', 'GPR56', 'LOC500155', 'SNURF', 'RGD1562047_PREDICTED', 'LOC500150', 'NDUFAB1_PREDICTED', 'RGD1560177_PREDICTED', 'RGD1306289_PREDICTED', 'LOC688712', 'MGST2_PREDICTED', 'MYBL1_PREDICTED', 'LOC500495', 'LOC690428', 'LOC500380', 'CTGF', 'LOC499554', 'MGC112883', 'LOC497920', 'LOC501553', 'RGD1308626', 'CSPG2', 'DUSP1', 'LOC498048', 'LOC363492', 'LOC501503', 'LOC361942', 'LOC362543', 'PLA2G12A_PREDICTED', 'LOC498378', 'LOC499560', 'LOC497844', 'LOC500398', 'LOC498799', 'LOC362315', 'RGD1307506_PREDICTED', 'CSDA', 'PRKCDBP', 'LOC500829', 'RGD1306811_PREDICTED', 'LOC499531', 'LOC500867', 'LOC498669', 'LOC498745', 'LOC361885', 'LOC498644', 'LOC498623', 'LOC361117', 'LOC499564', 'LOC500960', 'LOC498076', 'LOC500916', 'LOC500586', 'LOC361912', 'LOC499638', 'LOC501087']
# {'Index': 299, 'Gene_name': 'LOC501087', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': '', 'Ensembl_transcript_id': '', 'RefSeq_mRNA_id': '', 'Organism': 'rat', 'HGNC_symbol': '', 'Alias': '', 'Info': 'up'}
# up
# ['MT1A', 'RGD1566244_PREDICTED', 'FBLN1_PREDICTED', 'CTGF', 'EIF1B_PREDICTED', 'SGK', 'LOC311772', 'NUPR1', 'RHOB', 'LOC310926', 'ARHGAP21_PREDICTED', 'MSR2_PREDICTED', 'PFC_MAPPED', 'TREM2_PREDICTED', 'CD83_PREDICTED', 'PLTP_PREDICTED', 'LOC310926', 'ADFP', 'HLA-DMB', 'PEPD', 'LY86_PREDICTED', 'RT1-A1', 'GNS_PREDICTED', 'RGD1303130', 'FBXW4_PREDICTED', 'RT1-A3', 'LOC310946', 'RGD1311381_PREDICTED', 'PRKCB1', 'FUCA', 'IFI27L', 'HARPB64', 'TMEPAI_PREDICTED', 'FHL3_PREDICTED', 'C2', 'BHLHB3', 'LOC497767', 'LOC306324', 'CREG_PREDICTED', 'AP1S2_PREDICTED', 'IFNGR2_PREDICTED', 'SH3BGRL3_PREDICTED', 'ARPC4_PREDICTED', 'TCFE3_PREDICTED', 'LOC500040', 'RGD1563276_PREDICTED', 'ISG12(B)', 'LOC499775', 'SART2_PREDICTED', 'RGD1560373_PREDICTED', 'TNIP1_PREDICTED', 'RRAGC_PREDICTED', 'MGC72614', 'ARPC3_PREDICTED', 'TMEM55B', 'SNX2_PREDICTED', 'DNASE2A', 'GLRX1', 'MGC94190', 'CERK_PREDICTED', 'RGD1564762_PREDICTED', 'CTTNBP2NL_PREDICTED', 'LOC309557', 'RGD1310868_PREDICTED', 'SWAP70_PREDICTED', 'LOC500788', 'RGD1564451_PREDICTED', 'UBE2S_PREDICTED', 'GPR56', 'LOC500155', 'SNURF', 'RGD1562047_PREDICTED', 'LOC500150', 'NDUFAB1_PREDICTED', 'RGD1560177_PREDICTED', 'RGD1306289_PREDICTED', 'LOC688712', 'MGST2_PREDICTED', 'MYBL1_PREDICTED', 'LOC500495', 'LOC690428', 'LOC500380', 'CTGF', 'LOC499554', 'MGC112883', 'LOC497920', 'LOC501553', 'RGD1308626', 'CSPG2', 'DUSP1', 'LOC498048', 'LOC363492', 'LOC501503', 'LOC361942', 'LOC362543', 'PLA2G12A_PREDICTED', 'LOC498378', 'LOC499560', 'LOC497844', 'LOC500398', 'LOC498799', 'LOC362315', 'RGD1307506_PREDICTED', 'CSDA', 'PRKCDBP', 'LOC500829', 'RGD1306811_PREDICTED', 'LOC499531', 'LOC500867', 'LOC498669', 'LOC498745', 'LOC361885', 'LOC498644', 'LOC498623', 'LOC361117', 'LOC499564', 'LOC500960', 'LOC498076', 'LOC500916', 'LOC500586', 'LOC361912', 'LOC499638', 'LOC501087', 'LOC498245']
# {'Index': 300, 'Gene_name': 'LOC498245', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': '', 'Ensembl_transcript_id': '', 'RefSeq_mRNA_id': '', 'Organism': 'rat', 'HGNC_symbol': '', 'Alias': '', 'Info': 'up'}
# up
# {'Index': 301, 'Gene_name': 'HTRA1', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000020533', 'Ensembl_transcript_id': 'ENSRNOT00000111703|ENSRNOT00000027860|ENSRNOT00000115809', 'RefSeq_mRNA_id': 'NM_031721', 'Organism': 'rat', 'HGNC_symbol': 'HTRA1', 'Alias': '', 'Info': 'up'}
# up
# ['MT1A', 'RGD1566244_PREDICTED', 'FBLN1_PREDICTED', 'CTGF', 'EIF1B_PREDICTED', 'SGK', 'LOC311772', 'NUPR1', 'RHOB', 'LOC310926', 'ARHGAP21_PREDICTED', 'MSR2_PREDICTED', 'PFC_MAPPED', 'TREM2_PREDICTED', 'CD83_PREDICTED', 'PLTP_PREDICTED', 'LOC310926', 'ADFP', 'HLA-DMB', 'PEPD', 'LY86_PREDICTED', 'RT1-A1', 'GNS_PREDICTED', 'RGD1303130', 'FBXW4_PREDICTED', 'RT1-A3', 'LOC310946', 'RGD1311381_PREDICTED', 'PRKCB1', 'FUCA', 'IFI27L', 'HARPB64', 'TMEPAI_PREDICTED', 'FHL3_PREDICTED', 'C2', 'BHLHB3', 'LOC497767', 'LOC306324', 'CREG_PREDICTED', 'AP1S2_PREDICTED', 'IFNGR2_PREDICTED', 'SH3BGRL3_PREDICTED', 'ARPC4_PREDICTED', 'TCFE3_PREDICTED', 'LOC500040', 'RGD1563276_PREDICTED', 'ISG12(B)', 'LOC499775', 'SART2_PREDICTED', 'RGD1560373_PREDICTED', 'TNIP1_PREDICTED', 'RRAGC_PREDICTED', 'MGC72614', 'ARPC3_PREDICTED', 'TMEM55B', 'SNX2_PREDICTED', 'DNASE2A', 'GLRX1', 'MGC94190', 'CERK_PREDICTED', 'RGD1564762_PREDICTED', 'CTTNBP2NL_PREDICTED', 'LOC309557', 'RGD1310868_PREDICTED', 'SWAP70_PREDICTED', 'LOC500788', 'RGD1564451_PREDICTED', 'UBE2S_PREDICTED', 'GPR56', 'LOC500155', 'SNURF', 'RGD1562047_PREDICTED', 'LOC500150', 'NDUFAB1_PREDICTED', 'RGD1560177_PREDICTED', 'RGD1306289_PREDICTED', 'LOC688712', 'MGST2_PREDICTED', 'MYBL1_PREDICTED', 'LOC500495', 'LOC690428', 'LOC500380', 'CTGF', 'LOC499554', 'MGC112883', 'LOC497920', 'LOC501553', 'RGD1308626', 'CSPG2', 'DUSP1', 'LOC498048', 'LOC363492', 'LOC501503', 'LOC361942', 'LOC362543', 'PLA2G12A_PREDICTED', 'LOC498378', 'LOC499560', 'LOC497844', 'LOC500398', 'LOC498799', 'LOC362315', 'RGD1307506_PREDICTED', 'CSDA', 'PRKCDBP', 'LOC500829', 'RGD1306811_PREDICTED', 'LOC499531', 'LOC500867', 'LOC498669', 'LOC498745', 'LOC361885', 'LOC498644', 'LOC498623', 'LOC361117', 'LOC499564', 'LOC500960', 'LOC498076', 'LOC500916', 'LOC500586', 'LOC361912', 'LOC499638', 'LOC501087', 'LOC498245', 'LOC500285']
# {'Index': 302, 'Gene_name': 'LOC500285', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': '', 'Ensembl_transcript_id': '', 'RefSeq_mRNA_id': '', 'Organism': 'rat', 'HGNC_symbol': '', 'Alias': '', 'Info': 'up'}
# up
# {'Index': 303, 'Gene_name': 'FKBP5', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000022523', 'Ensembl_transcript_id': 'ENSRNOT00000109678|ENSRNOT00000033119', 'RefSeq_mRNA_id': 'NM_001012174', 'Organism': 'rat', 'HGNC_symbol': 'FKBP5', 'Alias': '', 'Info': 'up'}
# up
# ['MT1A', 'RGD1566244_PREDICTED', 'FBLN1_PREDICTED', 'CTGF', 'EIF1B_PREDICTED', 'SGK', 'LOC311772', 'NUPR1', 'RHOB', 'LOC310926', 'ARHGAP21_PREDICTED', 'MSR2_PREDICTED', 'PFC_MAPPED', 'TREM2_PREDICTED', 'CD83_PREDICTED', 'PLTP_PREDICTED', 'LOC310926', 'ADFP', 'HLA-DMB', 'PEPD', 'LY86_PREDICTED', 'RT1-A1', 'GNS_PREDICTED', 'RGD1303130', 'FBXW4_PREDICTED', 'RT1-A3', 'LOC310946', 'RGD1311381_PREDICTED', 'PRKCB1', 'FUCA', 'IFI27L', 'HARPB64', 'TMEPAI_PREDICTED', 'FHL3_PREDICTED', 'C2', 'BHLHB3', 'LOC497767', 'LOC306324', 'CREG_PREDICTED', 'AP1S2_PREDICTED', 'IFNGR2_PREDICTED', 'SH3BGRL3_PREDICTED', 'ARPC4_PREDICTED', 'TCFE3_PREDICTED', 'LOC500040', 'RGD1563276_PREDICTED', 'ISG12(B)', 'LOC499775', 'SART2_PREDICTED', 'RGD1560373_PREDICTED', 'TNIP1_PREDICTED', 'RRAGC_PREDICTED', 'MGC72614', 'ARPC3_PREDICTED', 'TMEM55B', 'SNX2_PREDICTED', 'DNASE2A', 'GLRX1', 'MGC94190', 'CERK_PREDICTED', 'RGD1564762_PREDICTED', 'CTTNBP2NL_PREDICTED', 'LOC309557', 'RGD1310868_PREDICTED', 'SWAP70_PREDICTED', 'LOC500788', 'RGD1564451_PREDICTED', 'UBE2S_PREDICTED', 'GPR56', 'LOC500155', 'SNURF', 'RGD1562047_PREDICTED', 'LOC500150', 'NDUFAB1_PREDICTED', 'RGD1560177_PREDICTED', 'RGD1306289_PREDICTED', 'LOC688712', 'MGST2_PREDICTED', 'MYBL1_PREDICTED', 'LOC500495', 'LOC690428', 'LOC500380', 'CTGF', 'LOC499554', 'MGC112883', 'LOC497920', 'LOC501553', 'RGD1308626', 'CSPG2', 'DUSP1', 'LOC498048', 'LOC363492', 'LOC501503', 'LOC361942', 'LOC362543', 'PLA2G12A_PREDICTED', 'LOC498378', 'LOC499560', 'LOC497844', 'LOC500398', 'LOC498799', 'LOC362315', 'RGD1307506_PREDICTED', 'CSDA', 'PRKCDBP', 'LOC500829', 'RGD1306811_PREDICTED', 'LOC499531', 'LOC500867', 'LOC498669', 'LOC498745', 'LOC361885', 'LOC498644', 'LOC498623', 'LOC361117', 'LOC499564', 'LOC500960', 'LOC498076', 'LOC500916', 'LOC500586', 'LOC361912', 'LOC499638', 'LOC501087', 'LOC498245', 'LOC500285', 'LOC498105']
# {'Index': 304, 'Gene_name': 'LOC498105', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': '', 'Ensembl_transcript_id': '', 'RefSeq_mRNA_id': '', 'Organism': 'rat', 'HGNC_symbol': '', 'Alias': '', 'Info': 'up'}
# up
# {'Index': 305, 'Gene_name': 'HOPX', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000024689', 'Ensembl_transcript_id': 'ENSRNOT00000049774', 'RefSeq_mRNA_id': 'NM_133621', 'Organism': 'rat', 'HGNC_symbol': 'HOPX', 'Alias': '', 'Info': 'up'}
# up
# {'Index': 306, 'Gene_name': 'HSPB1', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000023546', 'Ensembl_transcript_id': 'ENSRNOT00000031555', 'RefSeq_mRNA_id': 'NM_031970', 'Organism': 'rat', 'HGNC_symbol': 'HSPB1', 'Alias': '', 'Info': 'up'}
# up
# ['MT1A', 'RGD1566244_PREDICTED', 'FBLN1_PREDICTED', 'CTGF', 'EIF1B_PREDICTED', 'SGK', 'LOC311772', 'NUPR1', 'RHOB', 'LOC310926', 'ARHGAP21_PREDICTED', 'MSR2_PREDICTED', 'PFC_MAPPED', 'TREM2_PREDICTED', 'CD83_PREDICTED', 'PLTP_PREDICTED', 'LOC310926', 'ADFP', 'HLA-DMB', 'PEPD', 'LY86_PREDICTED', 'RT1-A1', 'GNS_PREDICTED', 'RGD1303130', 'FBXW4_PREDICTED', 'RT1-A3', 'LOC310946', 'RGD1311381_PREDICTED', 'PRKCB1', 'FUCA', 'IFI27L', 'HARPB64', 'TMEPAI_PREDICTED', 'FHL3_PREDICTED', 'C2', 'BHLHB3', 'LOC497767', 'LOC306324', 'CREG_PREDICTED', 'AP1S2_PREDICTED', 'IFNGR2_PREDICTED', 'SH3BGRL3_PREDICTED', 'ARPC4_PREDICTED', 'TCFE3_PREDICTED', 'LOC500040', 'RGD1563276_PREDICTED', 'ISG12(B)', 'LOC499775', 'SART2_PREDICTED', 'RGD1560373_PREDICTED', 'TNIP1_PREDICTED', 'RRAGC_PREDICTED', 'MGC72614', 'ARPC3_PREDICTED', 'TMEM55B', 'SNX2_PREDICTED', 'DNASE2A', 'GLRX1', 'MGC94190', 'CERK_PREDICTED', 'RGD1564762_PREDICTED', 'CTTNBP2NL_PREDICTED', 'LOC309557', 'RGD1310868_PREDICTED', 'SWAP70_PREDICTED', 'LOC500788', 'RGD1564451_PREDICTED', 'UBE2S_PREDICTED', 'GPR56', 'LOC500155', 'SNURF', 'RGD1562047_PREDICTED', 'LOC500150', 'NDUFAB1_PREDICTED', 'RGD1560177_PREDICTED', 'RGD1306289_PREDICTED', 'LOC688712', 'MGST2_PREDICTED', 'MYBL1_PREDICTED', 'LOC500495', 'LOC690428', 'LOC500380', 'CTGF', 'LOC499554', 'MGC112883', 'LOC497920', 'LOC501553', 'RGD1308626', 'CSPG2', 'DUSP1', 'LOC498048', 'LOC363492', 'LOC501503', 'LOC361942', 'LOC362543', 'PLA2G12A_PREDICTED', 'LOC498378', 'LOC499560', 'LOC497844', 'LOC500398', 'LOC498799', 'LOC362315', 'RGD1307506_PREDICTED', 'CSDA', 'PRKCDBP', 'LOC500829', 'RGD1306811_PREDICTED', 'LOC499531', 'LOC500867', 'LOC498669', 'LOC498745', 'LOC361885', 'LOC498644', 'LOC498623', 'LOC361117', 'LOC499564', 'LOC500960', 'LOC498076', 'LOC500916', 'LOC500586', 'LOC361912', 'LOC499638', 'LOC501087', 'LOC498245', 'LOC500285', 'LOC498105', 'MT1A']
# {'Index': 307, 'Gene_name': 'MT1A', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': '', 'Ensembl_transcript_id': '', 'RefSeq_mRNA_id': '', 'Organism': 'rat', 'HGNC_symbol': '', 'Alias': '', 'Info': 'up'}
# up
# {'Index': 308, 'Gene_name': 'NDRG2', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000010389', 'Ensembl_transcript_id': 'ENSRNOT00000094910|ENSRNOT00000040540|ENSRNOT00000099063|ENSRNOT00000085897|ENSRNOT00000042055', 'RefSeq_mRNA_id': 'NM_133583|NM_001270863|NM_001270862|NM_001270864', 'Organism': 'rat', 'HGNC_symbol': 'NDRG2', 'Alias': '', 'Info': 'up'}
# up
# {'Index': 309, 'Gene_name': 'GPD1', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000056457', 'Ensembl_transcript_id': 'ENSRNOT00000087662|ENSRNOT00000097280', 'RefSeq_mRNA_id': 'NM_022215', 'Organism': 'rat', 'HGNC_symbol': 'GPD1', 'Alias': '', 'Info': 'up'}
# up
# {'Index': 310, 'Gene_name': 'ALDOC', 'Gene_list_number': 31, 'Gene_list_index': 'all_sig_genes_24147833', 'Source': 'PMID: 24147833', 'Ensembl_gene_id': 'ENSRNOG00000011452', 'Ensembl_transcript_id': 'ENSRNOT00000015535|ENSRNOT00000046388|ENSRNOT00000086036', 'RefSeq_mRNA_id': 'NM_012497', 'Organism': 'rat', 'HGNC_symbol': 'ALDOC', 'Alias': '', 'Info': 'up'}

# %%
print(ls_notResponse)
# Out:
# ['MT1A', 'RGD1566244_PREDICTED', 'FBLN1_PREDICTED', 'CTGF', 'EIF1B_PREDICTED', 'SGK', 'LOC311772', 'NUPR1', 'RHOB', 'LOC310926', 'ARHGAP21_PREDICTED', 'MSR2_PREDICTED', 'PFC_MAPPED', 'TREM2_PREDICTED', 'CD83_PREDICTED', 'PLTP_PREDICTED', 'LOC310926', 'ADFP', 'HLA-DMB', 'PEPD', 'LY86_PREDICTED', 'RT1-A1', 'GNS_PREDICTED', 'RGD1303130', 'FBXW4_PREDICTED', 'RT1-A3', 'LOC310946', 'RGD1311381_PREDICTED', 'PRKCB1', 'FUCA', 'IFI27L', 'HARPB64', 'TMEPAI_PREDICTED', 'FHL3_PREDICTED', 'C2', 'BHLHB3', 'LOC497767', 'LOC306324', 'CREG_PREDICTED', 'AP1S2_PREDICTED', 'IFNGR2_PREDICTED', 'SH3BGRL3_PREDICTED', 'ARPC4_PREDICTED', 'TCFE3_PREDICTED', 'LOC500040', 'RGD1563276_PREDICTED', 'ISG12(B)', 'LOC499775', 'SART2_PREDICTED', 'RGD1560373_PREDICTED', 'TNIP1_PREDICTED', 'RRAGC_PREDICTED', 'MGC72614', 'ARPC3_PREDICTED', 'TMEM55B', 'SNX2_PREDICTED', 'DNASE2A', 'GLRX1', 'MGC94190', 'CERK_PREDICTED', 'RGD1564762_PREDICTED', 'CTTNBP2NL_PREDICTED', 'LOC309557', 'RGD1310868_PREDICTED', 'SWAP70_PREDICTED', 'LOC500788', 'RGD1564451_PREDICTED', 'UBE2S_PREDICTED', 'GPR56', 'LOC500155', 'SNURF', 'RGD1562047_PREDICTED', 'LOC500150', 'NDUFAB1_PREDICTED', 'RGD1560177_PREDICTED', 'RGD1306289_PREDICTED', 'LOC688712', 'MGST2_PREDICTED', 'MYBL1_PREDICTED', 'LOC500495', 'LOC690428', 'LOC500380', 'CTGF', 'LOC499554', 'MGC112883', 'LOC497920', 'LOC501553', 'RGD1308626', 'CSPG2', 'DUSP1', 'LOC498048', 'LOC363492', 'LOC501503', 'LOC361942', 'LOC362543', 'PLA2G12A_PREDICTED', 'LOC498378', 'LOC499560', 'LOC497844', 'LOC500398', 'LOC498799', 'LOC362315', 'RGD1307506_PREDICTED', 'CSDA', 'PRKCDBP', 'LOC500829', 'RGD1306811_PREDICTED', 'LOC499531', 'LOC500867', 'LOC498669', 'LOC498745', 'LOC361885', 'LOC498644', 'LOC498623', 'LOC361117', 'LOC499564', 'LOC500960', 'LOC498076', 'LOC500916', 'LOC500586', 'LOC361912', 'LOC499638', 'LOC501087', 'LOC498245', 'LOC500285', 'LOC498105', 'MT1A']

# %%
# SCORES 

### from DICTIONARY to file
data = ls_geneDictionaries
df = pd.DataFrame.from_dict(data)
df.to_excel(r'.\Dictionary.xlsx', index=False)

### from ls_notResponse to file
data1 = ls_notResponse
df1 = pd.DataFrame.from_dict(data1)
df1.to_excel(r'.\notResponse.xlsx', index=False)

# LOAD 
# notRESPONSE
wb_2 = openpyxl.load_workbook(r'.\notResponse.xlsx')
ws_2 = wb_2.active
ls_notResponse_v2 = [ws_2.cell(row=i,column=1).value for i in range(2,ws_2.max_row+1)]


### from alias_and_official to file
data2 = alias_and_official(ls_notResponse, ls_row_10, ls_row_2)
df2 = pd.DataFrame.from_dict(data2)
df2.to_excel(r'.\responsewithMGI.xlsx', index=False)


# LOAD responsewithMGI
wb_3 = openpyxl.load_workbook(r'.\responsewithMGI.xlsx')
ws_3 = wb_3.active
mgi_id = [ws_3.cell(row=i,column=3).value for i in range(3,ws_3.max_row+1)]
gene_name_v2 = [ws_3.cell(row=i,column=1).value for i in range(3,ws_3.max_row+1)]
# Out:
# ['sgk', 36747, 'MGI:1340062']
# ['c2', 608914, 'MGI:7119820']
# ['tmem55b', 80264, 'MGI:2448501']

# %%
print (ls_notResponse)
# Out:
# ['MT1A', 'RGD1566244_PREDICTED', 'FBLN1_PREDICTED', 'CTGF', 'EIF1B_PREDICTED', 'SGK', 'LOC311772', 'NUPR1', 'RHOB', 'LOC310926', 'ARHGAP21_PREDICTED', 'MSR2_PREDICTED', 'PFC_MAPPED', 'TREM2_PREDICTED', 'CD83_PREDICTED', 'PLTP_PREDICTED', 'LOC310926', 'ADFP', 'HLA-DMB', 'PEPD', 'LY86_PREDICTED', 'RT1-A1', 'GNS_PREDICTED', 'RGD1303130', 'FBXW4_PREDICTED', 'RT1-A3', 'LOC310946', 'RGD1311381_PREDICTED', 'PRKCB1', 'FUCA', 'IFI27L', 'HARPB64', 'TMEPAI_PREDICTED', 'FHL3_PREDICTED', 'C2', 'BHLHB3', 'LOC497767', 'LOC306324', 'CREG_PREDICTED', 'AP1S2_PREDICTED', 'IFNGR2_PREDICTED', 'SH3BGRL3_PREDICTED', 'ARPC4_PREDICTED', 'TCFE3_PREDICTED', 'LOC500040', 'RGD1563276_PREDICTED', 'ISG12(B)', 'LOC499775', 'SART2_PREDICTED', 'RGD1560373_PREDICTED', 'TNIP1_PREDICTED', 'RRAGC_PREDICTED', 'MGC72614', 'ARPC3_PREDICTED', 'TMEM55B', 'SNX2_PREDICTED', 'DNASE2A', 'GLRX1', 'MGC94190', 'CERK_PREDICTED', 'RGD1564762_PREDICTED', 'CTTNBP2NL_PREDICTED', 'LOC309557', 'RGD1310868_PREDICTED', 'SWAP70_PREDICTED', 'LOC500788', 'RGD1564451_PREDICTED', 'UBE2S_PREDICTED', 'GPR56', 'LOC500155', 'SNURF', 'RGD1562047_PREDICTED', 'LOC500150', 'NDUFAB1_PREDICTED', 'RGD1560177_PREDICTED', 'RGD1306289_PREDICTED', 'LOC688712', 'MGST2_PREDICTED', 'MYBL1_PREDICTED', 'LOC500495', 'LOC690428', 'LOC500380', 'CTGF', 'LOC499554', 'MGC112883', 'LOC497920', 'LOC501553', 'RGD1308626', 'CSPG2', 'DUSP1', 'LOC498048', 'LOC363492', 'LOC501503', 'LOC361942', 'LOC362543', 'PLA2G12A_PREDICTED', 'LOC498378', 'LOC499560', 'LOC497844', 'LOC500398', 'LOC498799', 'LOC362315', 'RGD1307506_PREDICTED', 'CSDA', 'PRKCDBP', 'LOC500829', 'RGD1306811_PREDICTED', 'LOC499531', 'LOC500867', 'LOC498669', 'LOC498745', 'LOC361885', 'LOC498644', 'LOC498623', 'LOC361117', 'LOC499564', 'LOC500960', 'LOC498076', 'LOC500916', 'LOC500586', 'LOC361912', 'LOC499638', 'LOC501087', 'LOC498245', 'LOC500285', 'LOC498105', 'MT1A']

# %%
# SECOND DICTIONARY

for i in range(len(mgi_id)):
    mgi_ID = mgi_id[i]
    gene_name = gene_name_v2[i]
    print(mgi_ID)
    
    if gene_name != '':

        # variables
        alias = ''

        ensembl_gene_id_temp = []
        ensembl_transcript_id_temp = []
        refseq_mrna_temp = []
        

        ls_biomartParameters_mgi = biomartParameters_mgi(mgi_ID)
        
        print(ls_biomartParameters)
        
        if not ls_biomartParameters:
            ls_notResponse_after.append(mgi_ID)


        for ls in ls_biomartParameters:
            for j in range(3):
                if len(ls) < (j+1):
                    ls.append('')
            ensembl_gene_id_temp.append(ls[0])
            ensembl_transcript_id_temp.append(ls[1])
            refseq_mrna_temp.append(ls[2])  

        ensembl_gene_id = '|'.join(list(set(filter(None, ensembl_gene_id_temp))))
        ensembl_transcript_id = '|'.join(list(set(filter(None, ensembl_transcript_id_temp))))
        refseq_mrna = '|'.join(list(set(filter(None, refseq_mrna_temp))))
         
        
        ls_biomartHumanOrthologs = biomartHumanOrthologs_mgi(mgi_ID)
        if not ls_biomartHumanOrthologs:
            hgnc_symbol = ''
        else:
            hgnc_symbol = ls_biomartHumanOrthologs[0][0]       
        
        
        for k in range(len(ls_geneDictionaries)):
            temp = str(ls_geneDictionaries[k]['Gene_name']).lower()

            if temp == gene_name:
                print('response')
                ls_geneDictionaries[k]['Ensembl_gene_id'] = ensembl_gene_id
                ls_geneDictionaries[k]['Ensembl_transcript_id'] = ensembl_transcript_id
                ls_geneDictionaries[k]['RefSeq_mRNA_id'] = refseq_mrna
                ls_geneDictionaries[k]['HGNC_symbol'] = hgnc_symbol
# Out:
# MGI:102725
# [['ENSRNOG00000011452', 'ENSRNOT00000015535', 'NM_012497'], ['ENSRNOG00000011452', 'ENSRNOT00000046388', ''], ['ENSRNOG00000011452', 'ENSRNOT00000086036', '']]
# response
# response
# MGI:95537
# [['ENSRNOG00000011452', 'ENSRNOT00000015535', 'NM_012497'], ['ENSRNOG00000011452', 'ENSRNOT00000046388', ''], ['ENSRNOG00000011452', 'ENSRNOT00000086036', '']]
# response
# response
# MGI:1340062
# [['ENSRNOG00000011452', 'ENSRNOT00000015535', 'NM_012497'], ['ENSRNOG00000011452', 'ENSRNOT00000046388', ''], ['ENSRNOG00000011452', 'ENSRNOT00000086036', '']]
# response
# MGI:87920
# [['ENSRNOG00000011452', 'ENSRNOT00000015535', 'NM_012497'], ['ENSRNOG00000011452', 'ENSRNOT00000046388', ''], ['ENSRNOG00000011452', 'ENSRNOT00000086036', '']]
# response
# MGI:97596
# [['ENSRNOG00000011452', 'ENSRNOT00000015535', 'NM_012497'], ['ENSRNOG00000011452', 'ENSRNOT00000046388', ''], ['ENSRNOG00000011452', 'ENSRNOT00000086036', '']]
# response
# MGI:1347005
# [['ENSRNOG00000011452', 'ENSRNOT00000015535', 'NM_012497'], ['ENSRNOG00000011452', 'ENSRNOT00000046388', ''], ['ENSRNOG00000011452', 'ENSRNOT00000086036', '']]
# response
# MGI:7119820
# [['ENSRNOG00000011452', 'ENSRNOT00000015535', 'NM_012497'], ['ENSRNOG00000011452', 'ENSRNOT00000046388', ''], ['ENSRNOG00000011452', 'ENSRNOT00000086036', '']]
# response
# MGI:1930704
# [['ENSRNOG00000011452', 'ENSRNOT00000015535', 'NM_012497'], ['ENSRNOG00000011452', 'ENSRNOT00000046388', ''], ['ENSRNOG00000011452', 'ENSRNOT00000086036', '']]
# response
# MGI:2448501
# [['ENSRNOG00000011452', 'ENSRNOT00000015535', 'NM_012497'], ['ENSRNOG00000011452', 'ENSRNOT00000046388', ''], ['ENSRNOG00000011452', 'ENSRNOT00000086036', '']]
# response
# MGI:1340051
# [['ENSRNOG00000011452', 'ENSRNOT00000015535', 'NM_012497'], ['ENSRNOG00000011452', 'ENSRNOT00000046388', ''], ['ENSRNOG00000011452', 'ENSRNOT00000086036', '']]
# response
# MGI:95537
# [['ENSRNOG00000011452', 'ENSRNOT00000015535', 'NM_012497'], ['ENSRNOG00000011452', 'ENSRNOT00000046388', ''], ['ENSRNOG00000011452', 'ENSRNOT00000086036', '']]
# response
# response
# MGI:102889
# [['ENSRNOG00000011452', 'ENSRNOT00000015535', 'NM_012497'], ['ENSRNOG00000011452', 'ENSRNOT00000046388', ''], ['ENSRNOG00000011452', 'ENSRNOT00000086036', '']]
# response
# MGI:2137670
# [['ENSRNOG00000011452', 'ENSRNOT00000015535', 'NM_012497'], ['ENSRNOG00000011452', 'ENSRNOT00000046388', ''], ['ENSRNOG00000011452', 'ENSRNOT00000086036', '']]
# response
# MGI:1923422
# [['ENSRNOG00000011452', 'ENSRNOT00000015535', 'NM_012497'], ['ENSRNOG00000011452', 'ENSRNOT00000046388', ''], ['ENSRNOG00000011452', 'ENSRNOT00000086036', '']]
# response
# MGI:102725
# [['ENSRNOG00000011452', 'ENSRNOT00000015535', 'NM_012497'], ['ENSRNOG00000011452', 'ENSRNOT00000046388', ''], ['ENSRNOG00000011452', 'ENSRNOT00000086036', '']]
# response
# response

# %%
# SCORES 

### from SECOND DICTIONARY to file

data3 = ls_geneDictionaries
df3 = pd.DataFrame.from_dict(data3)
df3.to_excel(r'.\secondDictionary.xlsx', index=False)
df3.to_csv(r'.\secondDictionary.tsv', sep="\t")

data4 = ls_notResponse_after
df4 = pd.DataFrame.from_dict(data4)
df4.to_excel(r'.\ls_notResponse_after.xlsx', index=False)

# %%
# Add ALIAS

mgi_file_path = r'..\MGI_EntrezGene.xlsx'
dictionary_file_path = r'.\secondDictionary.xlsx'
save_file_path = r'.\withAlias.xlsx'


updateCellswithAlias(mgi_file_path, dictionary_file_path, save_file_path)

# %%
# Add INFO

source_file_path = r'..\ifpan-GR-database-papers.xlsx'
source_sheet = 'nervous-cells'
alias_file_path = '.\withAlias.xlsx'
info_file_path = r'.\withINFO.xlsx'

updateCellswithINFO(source_file_path, source_sheet, alias_file_path, info_file_path)
# Out:
# htra1 htra1
# hopx hopx
# aldoc aldoc
# mt1a mt1a
# rgd1566244_predicted rgd1566244_predicted
# sult1a1 sult1a1
# phyhd1 phyhd1
# cdo1 cdo1
# pawr pawr
# ednrb ednrb
# fkbp5 fkbp5
# fbln1_predicted fbln1_predicted
# ctgf ctgf
# htra1 htra1
# ctsc ctsc
# tsc22d3 tsc22d3
# eif1b_predicted eif1b_predicted
# sgk sgk
# loc311772 loc311772
# stmn2 stmn2
# grina grina
# plekhb1 plekhb1
# cryab cryab
# ddit4 ddit4
# cyp7b1 cyp7b1
# tspan12 tspan12
# csad csad
# resp18 resp18
# gda gda
# prdx6 prdx6
# aurkb aurkb
# klf9 klf9
# nupr1 nupr1
# hopx hopx
# oaf oaf
# spp1 spp1
# pnoc pnoc
# oplah oplah
# cxcl1 cxcl1
# rhob rhob
# atp1a2 atp1a2
# loc310926 loc310926
# slc7a3 slc7a3
# htra1 htra1
# cst3 cst3
# plcl1 plcl1
# gap43 gap43
# cryab cryab
# arhgap21_predicted arhgap21_predicted
# apoe apoe
# gpd1 gpd1
# rcan2 rcan2
# thtpa thtpa
# fcgr3a fcgr3a
# msr2_predicted msr2_predicted
# coro1a coro1a
# pfc_mapped pfc_mapped
# rac2 rac2
# lpl lpl
# apobec1 apobec1
# laptm5 laptm5
# trem2_predicted trem2_predicted
# ctsc ctsc
# ifi30 ifi30
# cd83_predicted cd83_predicted
# hprt1 hprt1
# ehd4 ehd4
# lcp1 lcp1
# tmem176b tmem176b
# pltp_predicted pltp_predicted
# gmfg gmfg
# ucp2 ucp2
# rgs10 rgs10
# jak3 jak3
# abcg1 abcg1
# arhgap17 arhgap17
# ptpn6 ptpn6
# grn grn
# sirpa sirpa
# psmb8 psmb8
# tmem37 tmem37
# loc310926 loc310926
# adfp adfp
# hla-dmb hla-dmb
# rgs2 rgs2
# scpep1 scpep1
# pepd pepd
# ly86_predicted ly86_predicted
# arhgdib arhgdib
# lyl1 lyl1
# rt1-a1 rt1-a1
# psap psap
# spp1 spp1
# ninj1 ninj1
# cd68 cd68
# cd302 cd302
# gns_predicted gns_predicted
# oplah oplah
# txnip txnip
# sp110 sp110
# pf4 pf4
# anxa3 anxa3
# rgd1303130 rgd1303130
# dab2 dab2
# nnt nnt
# lgmn lgmn
# vamp8 vamp8
# skap2 skap2
# fbxw4_predicted fbxw4_predicted
# psme1 psme1
# rhog rhog
# tifa tifa
# ctsh ctsh
# rt1-a3 rt1-a3
# ppt1 ppt1
# aldh16a1 aldh16a1
# tpp1 tpp1
# cd48 cd48
# ugcg ugcg
# unc93b1 unc93b1
# itm2c itm2c
# qprt qprt
# atp1b1 atp1b1
# loc310946 loc310946
# rgd1311381_predicted rgd1311381_predicted
# prkcb1 prkcb1
# fuca fuca
# flot1 flot1
# ifi27l ifi27l
# rarres1 rarres1
# harpb64 harpb64
# p2rx4 p2rx4
# tmepai_predicted tmepai_predicted
# metrnl metrnl
# ptpro ptpro
# fhl3_predicted fhl3_predicted
# c2 c2
# bhlhb3 bhlhb3
# pgd pgd
# loc497767 loc497767
# anxa4 anxa4
# itm2b itm2b
# loc306324 loc306324
# prdx5 prdx5
# anxa11 anxa11
# creg_predicted creg_predicted
# ap1s2_predicted ap1s2_predicted
# pld3 pld3
# arpc1b arpc1b
# ifngr2_predicted ifngr2_predicted
# rilpl2 rilpl2
# lta4h lta4h
# parp1 parp1
# leprot leprot
# sh3bgrl3_predicted sh3bgrl3_predicted
# aph1a aph1a
# arpc4_predicted arpc4_predicted
# tcfe3_predicted tcfe3_predicted
# cib1 cib1
# erp29 erp29
# loc500040 loc500040
# rgd1563276_predicted rgd1563276_predicted
# scamp2 scamp2
# pnrc1 pnrc1
# isg12(b) isg12(b)
# atp2b1 atp2b1
# loc499775 loc499775
# acp2 acp2
# atp1b3 atp1b3
# sart2_predicted sart2_predicted
# rgd1560373_predicted rgd1560373_predicted
# tnip1_predicted tnip1_predicted
# slc7a3 slc7a3
# rragc_predicted rragc_predicted
# tep1 tep1
# mgc72614 mgc72614
# clta clta
# arpc3_predicted arpc3_predicted
# tmem55b tmem55b
# snx2_predicted snx2_predicted
# nfe2l2 nfe2l2
# dnase2a dnase2a
# glrx1 glrx1
# cept1 cept1
# mgc94190 mgc94190
# cerk_predicted cerk_predicted
# rcan1 rcan1
# rgd1564762_predicted rgd1564762_predicted
# cttnbp2nl_predicted cttnbp2nl_predicted
# cklf cklf
# loc309557 loc309557
# rgd1310868_predicted rgd1310868_predicted
# swap70_predicted swap70_predicted
# rnf114 rnf114
# mknk2 mknk2
# rt1-m6-2 rt1-m6-2
# loc500788 loc500788
# fxyd6 fxyd6
# pfn2 pfn2
# gria2 gria2
# rgd1564451_predicted rgd1564451_predicted
# ube2s_predicted ube2s_predicted
# psph psph
# dynlt1 dynlt1
# hsd17b12 hsd17b12
# gpr56 gpr56
# loc500155 loc500155
# snurf snurf
# fbxo2 fbxo2
# rgd1562047_predicted rgd1562047_predicted
# stmn1 stmn1
# resp18 resp18
# loc500150 loc500150
# hdgf hdgf
# ndufab1_predicted ndufab1_predicted
# rgd1560177_predicted rgd1560177_predicted
# arpc1a arpc1a
# rgd1306289_predicted rgd1306289_predicted
# spon1 spon1
# loc688712 loc688712
# rdx rdx
# fez1 fez1
# dag1 dag1
# slc1a1 slc1a1
# mgst2_predicted mgst2_predicted
# thra thra
# mybl1_predicted mybl1_predicted
# loc500495 loc500495
# timm8b timm8b
# fermt2 fermt2
# loc690428 loc690428
# loc500380 loc500380
# pim3 pim3
# ctgf ctgf
# olig1 olig1
# igfbp3 igfbp3
# sulf2 sulf2
# loc499554 loc499554
# tagln tagln
# mgc112883 mgc112883
# schip1 schip1
# loc497920 loc497920
# loc501553 loc501553
# rgd1308626 rgd1308626
# cspg2 cspg2
# snrpn snrpn
# dusp1 dusp1
# loc498048 loc498048
# sparc sparc
# loc363492 loc363492
# csad csad
# loc501503 loc501503
# loc361942 loc361942
# stmn3 stmn3
# loc362543 loc362543
# npdc1 npdc1
# pla2g12a_predicted pla2g12a_predicted
# loc498378 loc498378
# loc499560 loc499560
# acot1 acot1
# loc497844 loc497844
# loc500398 loc500398
# loc498799 loc498799
# loc362315 loc362315
# scrg1 scrg1
# rgd1307506_predicted rgd1307506_predicted
# csda csda
# ncald ncald
# prkcdbp prkcdbp
# loc500829 loc500829
# rgd1306811_predicted rgd1306811_predicted
# lgals1 lgals1
# prnp prnp
# fstl1 fstl1
# tpm1 tpm1
# loc499531 loc499531
# loc500867 loc500867
# tgfa tgfa
# loc498669 loc498669
# rtkn rtkn
# omg omg
# loc498745 loc498745
# loc361885 loc361885
# atp1a2 atp1a2
# loc498644 loc498644
# loc498623 loc498623
# mt3 mt3
# loc361117 loc361117
# loc499564 loc499564
# loc500960 loc500960
# s100a11 s100a11
# loc498076 loc498076
# loc500916 loc500916
# cryab cryab
# loc500586 loc500586
# loc361912 loc361912
# loc499638 loc499638
# gpx3 gpx3
# loc501087 loc501087
# loc498245 loc498245
# htra1 htra1
# loc500285 loc500285
# fkbp5 fkbp5
# loc498105 loc498105
# hopx hopx
# hspb1 hspb1
# mt1a mt1a
# ndrg2 ndrg2
# gpd1 gpd1
# aldoc aldoc

# %%
                                ''' + '|'
                                 + '|'
                                +'TTEST.NEURO.ALD:' + str(ws_mgi[S_cel].value) + '|'
                                +'TTEST.NEURO.DHT:' + str(ws_mgi[T_cel].value) + '|'
                                +'TTEST.NEURO.PRG:' + str(ws_mgi[U_cel].value) + '|'
                                +'TTEST.NEURO.ESR:' + str(ws_mgi[V_cel].value) + '|'
                                +'FDR_TTEST.ASTRO.DEX:' + str(ws_mgi[W_cel].value) + '|'
                                +'FDR_TTEST.ASTRO.ALD:' + str(ws_mgi[X_cel].value) + '|'
                                +'FDR_TTEST.ASTRO.DHT:' + str(ws_mgi[Y_cel].value) + '|'
                                +'FDR_TTEST.ASTRO.PRG:' + str(ws_mgi[Z_cel].value) + '|'
                                +'FDR_TTEST.ASTRO.ESR:' + str(ws_mgi[AA_cel].value) + '|'
                                +'FDR_TTEST.NEURO.DEX:' + str(ws_mgi[AB_cel].value) + '|'
                                +'FDR_TTEST.NEURO.ALD:' + str(ws_mgi[AC_cel].value) + '|'
                                +'FDR_TTEST.NEURO.DHT:' + str(ws_mgi[AD_cel].value) + '|'
                                +'FDR_TTEST.NEURO.PRG:' + str(ws_mgi[AE_cel].value) + '|'
                                +'FDR_TTEST.NEURO.ESR:' + str(ws_mgi[AF_cel].value) + '|'
                                +'FOLD.ASTRO.DEX:' + str(ws_mgi[AG_cel].value) + '|'
                                +'FOLD.ASTRO.ALD:' + str(ws_mgi[AH_cel].value) + '|'
                                +'FOLD.ASTRO.DHT:' + str(ws_mgi[AI_cel].value) + '|'
                                +'FOLD.ASTRO.PRG:' + str(ws_mgi[AJ_cel].value) + '|'
                                +'FOLD.ASTRO.ESR:' + str(ws_mgi[AK_cel].value) + '|'
                                +'FOLD.NEURO.DEX:' + str(ws_mgi[AL_cel].value) + '|'
                                +'FOLD.NEURO.ALD:' + str(ws_mgi[AM_cel].value) + '|'
                                +'FOLD.NEURO.DHT:' + str(ws_mgi[AN_cel].value) + '|'
                                +'FOLD.NEURO.PRG:' + str(ws_mgi[AO_cel].value) + '|'
                                +'FOLD.NEURO.ESR:' + str(ws_mgi[AP_cel].value))'''
