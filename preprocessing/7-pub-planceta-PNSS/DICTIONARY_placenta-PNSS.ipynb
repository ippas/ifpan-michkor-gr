# %%
# IMPORT 

import csv
from biomart import BiomartServer
import pandas as pd
import openpyxl

# %%
# DATASET

## biomart_server
server = BiomartServer('http://www.ensembl.org/biomart')
dataset = server.datasets['hsapiens_gene_ensembl']

# %%
# FUNCTIONS

def gene_dictionary(index,
                    gene_name,
                    gene_list_number,
                    gene_list_id,
                    source,
                    ensembl_gene_id,
                    ensembl_transcript_id,
                    refseq_mrna,
                    hgnc_symbol,
                    organism,
                    alias,
                    direction_string):
    
    dictionary = {
        'Index' : index,
        'Gene_name' : gene_name,
        'Gene_list_number' : gene_list_number,
        'Gene_list_index' : gene_list_id,
        'Source' : source,
        'Ensembl_gene_id' : ensembl_gene_id,
        'Ensembl_transcript_id' : ensembl_transcript_id,
        'RefSeq_mRNA_id' : refseq_mrna,
        'Organism' : organism,
        'HGNC_symbol' : hgnc_symbol,
        'Alias' : alias,
        'Info' : direction_string
    }
    
    return dictionary


  
def biomartParameters(mgi_symbol):

    attributes = ['ensembl_gene_id',
                  'ensembl_transcript_id',
                  'refseq_mrna']

    filters = {'external_gene_name':[mgi_symbol]}               # gene_name = mgi_symbol
    response = dataset.search({'attributes':attributes,'filters':filters})
    

    # response_convertion
    lines = response.text.split("\n")
    lines = list(filter(lambda l: l != "",lines))
    values = []
    for l in lines:
        temp = []
        raw_values = l.split("\t")
        values.append(raw_values)
        
    return values  



def alias_and_official(ls_notResponse,ls_row_10,ls_row_2):

    ls_response = []
    ls_response2 = []
    
    for notResponse in ls_notResponse:
        word = str(notResponse).lower()

        for i in range(len(ls_row_10)):
            if ls_row_10[i]:
                temp = str(ls_row_10[i]).lower()
                t_strings = temp.split("|")
                if word in t_strings:
                    ls_response.append([word, i, ls_row_1[i]])

    ls_response.insert(0, ['gene_name','alias_index','mgi_id'])         # print(len(ls_response))


    for notResponse in ls_notResponse:
        word = str(notResponse).lower()

        for i in range(len(ls_row_10)):
            if ls_row_10[i]:
                temp = str(ls_row_10[i]).lower()
                if word == temp:
                    ls_response2.append([word, i, ls_row_1[i]])
                    

    ls_response.insert(0, ['gene_name','official_index','mgi_id'])      # print(len(ls_response2))

    ls_response_3 = ls_response
    
    for response in ls_response2:
        if response not in ls_response_3:
            ls_response_3.append(response)
        else: print(response)

    ls_response_3.pop(0)
    ls_response_3.pop(0)
    ls_response.insert(0, ['gene_name','official/alias_index','mgi_id'])
    
    return ls_response_3

def biomartParameters_mgi(gene_name):

    attributes = ['ensembl_gene_id',
                  'ensembl_transcript_id',
                  'refseq_mrna']
    filters = {'uniprot_gn_symbol':[gene_name]}                     # gene_name = mgi_id
    response = dataset.search({'attributes':attributes,'filters':filters})
    
    # response_convertion
    lines = response.text.split("\n")
    lines = list(filter(lambda l: l != "",lines))
    values = []
    for l in lines:
        temp = []
        raw_values = l.split("\t")
        values.append(raw_values)

    return values  


def updateCellswithAlias(mgi_file_path, dictionary_file_path, file_path):
    
    # Load MGI file and open workbook
    wb_mgi = openpyxl.load_workbook(mgi_file_path)
    ws_mgi = wb_mgi.active

    ls_row_alias = [ws_mgi.cell(row=i,column=10).value for i in range(2,ws_mgi.max_row+1)]
    ls_row_g_name = [ws_mgi.cell(row=i,column=2).value for i in range(2,ws_mgi.max_row+1)] 

    # Load dictionary file and open workbook
    workbook = openpyxl.load_workbook(dictionary_file_path)
    sheet = workbook.active

    ls_row_2 = [sheet.cell(row=i,column=2).value for i in range(2,sheet.max_row+1)]
    ls_row_9 = [sheet.cell(row=i,column=11).value for i in range(2,sheet.max_row+1)]

    
    length = len(ls_row_2) + 2

    # Modify the desired cell
    for i in range(length):
        K_cel = 'K' + str(i + 2)

        for k in range(len(ls_row_g_name)):
            try:
                if str(ls_row_g_name[k]).lower() == str(ls_row_2[i]).lower():
                    if ls_row_alias[k] is not None:
                        sheet[K_cel] = ls_row_alias[k]
                    else:
                        continue
            except:
                continue

    # Save the file
    workbook.save(file_path)

# %%
# LOAD START FILES

## PUBLICATION SOURCE
wb = openpyxl.load_workbook('../ifpan-GR-database-papers.xlsx')
ws = wb['placenta-PNSS']

publication_geneName = [ws.cell(row=i,column=3).value for i in range(2,ws.max_row+1)]
direction = [ws.cell(row=i,column=6).value for i in range(2,ws.max_row+1)]

## MGI
wb_1 = openpyxl.load_workbook(r'../MGI_EntrezGene.xlsx')
ws_1 = wb_1.active

ls_row_10 = [ws_1.cell(row=i,column=10).value for i in range(2,ws_1.max_row+1)]
ls_row_2 = [ws_1.cell(row=i,column=2).value for i in range(2,ws_1.max_row+1)]
ls_row_1 = [ws_1.cell(row=i,column=1).value for i in range(2,ws_1.max_row+1)]

# %%
# LISTS

dictionary = {}
ls_geneDictionaries = []
ls_notResponse = []
ls_notResponse_after = []

# %%
# DICTIONARY

for i in range(len(publication_geneName)):
    gene_name = publication_geneName[i]
    direction_string = direction[i]   # => info
    hgnc_symbol = gene_name
    
    if gene_name != '':

        # VARIABLES
        index = i + 1
        gene_list_number = 28
        gene_list_id =  'all_sig_genes_33981007'      # => cluster
        source = 'PMID: 33981007'
        organism = 'human'
        print(direction_string)
        alias = ''


        ensembl_gene_id_temp = []
        ensembl_transcript_id_temp = []
        refseq_mrna_temp = []

        ls_biomartParameters = biomartParameters(gene_name)
        if not ls_biomartParameters:
            ls_notResponse.append(gene_name)
            print(ls_notResponse)


        for ls in ls_biomartParameters:
            for j in range(3):
                if len(ls) < (j+1):
                    ls.append('')
            ensembl_gene_id_temp.append(ls[0])
            ensembl_transcript_id_temp.append(ls[1])
            refseq_mrna_temp.append(ls[2])  

        ensembl_gene_id = '|'.join(list(set(filter(None, ensembl_gene_id_temp))))
        ensembl_transcript_id = '|'.join(list(set(filter(None, ensembl_transcript_id_temp))))
        refseq_mrna = '|'.join(list(set(filter(None, refseq_mrna_temp))))
        
      
        
        temp_gene_dictionary = gene_dictionary(index,
                                               gene_name,
                                               gene_list_number,
                                               gene_list_id,
                                               source,
                                               ensembl_gene_id,
                                               ensembl_transcript_id, 
                                               refseq_mrna,
                                               hgnc_symbol,
                                               organism,
                                               alias,
                                               direction_string)

        ls_geneDictionaries.append(temp_gene_dictionary)
        print(temp_gene_dictionary)
# Out:
# down
# {'Index': 1, 'Gene_name': 'RN7SL4P', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000263740', 'Ensembl_transcript_id': 'ENST00000584058', 'RefSeq_mRNA_id': '', 'Organism': 'human', 'HGNC_symbol': 'RN7SL4P', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 2, 'Gene_name': 'LINC01816', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000231327', 'Ensembl_transcript_id': 'ENST00000414141|ENST00000691543', 'RefSeq_mRNA_id': '', 'Organism': 'human', 'HGNC_symbol': 'LINC01816', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 3, 'Gene_name': 'FBLN1', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000077942', 'Ensembl_transcript_id': 'ENST00000454279|ENST00000476366|ENST00000327858|ENST00000455233|ENST00000442170|ENST00000262722|ENST00000340923|ENST00000411478|ENST00000439835|ENST00000465578|ENST00000450975|ENST00000445110|ENST00000460538|ENST00000460300|ENST00000437711|ENST00000484531|ENST00000402984|ENST00000451475', 'RefSeq_mRNA_id': 'NM_001996|NM_006485|NM_006486|NM_006487', 'Organism': 'human', 'HGNC_symbol': 'FBLN1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 4, 'Gene_name': 'ANKRD33', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000167612', 'Ensembl_transcript_id': 'ENST00000548383|ENST00000301190|ENST00000549751|ENST00000547119|ENST00000549316|ENST00000550652|ENST00000340970|ENST00000548526', 'RefSeq_mRNA_id': 'NM_182608|NM_001304460|NM_001130015|NM_001304459', 'Organism': 'human', 'HGNC_symbol': 'ANKRD33', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 5, 'Gene_name': 'CGB3', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000104827', 'Ensembl_transcript_id': 'ENST00000357383', 'RefSeq_mRNA_id': 'NM_000737', 'Organism': 'human', 'HGNC_symbol': 'CGB3', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 6, 'Gene_name': 'MRGPRE', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000184350', 'Ensembl_transcript_id': 'ENST00000389832', 'RefSeq_mRNA_id': 'NM_001039165', 'Organism': 'human', 'HGNC_symbol': 'MRGPRE', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 7, 'Gene_name': 'MUC15', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000169550', 'Ensembl_transcript_id': 'ENST00000455601|ENST00000529533|ENST00000281268|ENST00000436318|ENST00000648230|ENST00000527569', 'RefSeq_mRNA_id': 'NM_001135092|NM_145650|NM_001135091', 'Organism': 'human', 'HGNC_symbol': 'MUC15', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 8, 'Gene_name': 'PSCA', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000167653', 'Ensembl_transcript_id': 'ENST00000505305|ENST00000301258|ENST00000513264|ENST00000510969', 'RefSeq_mRNA_id': 'NM_005672', 'Organism': 'human', 'HGNC_symbol': 'PSCA', 'Alias': '', 'Info': 'down'}
# up
# {'Index': 9, 'Gene_name': 'CA1', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000133742', 'Ensembl_transcript_id': 'ENST00000521679|ENST00000517429|ENST00000521846|ENST00000520990|ENST00000431316|ENST00000523712|ENST00000522662|ENST00000523858|ENST00000519991|ENST00000517590|ENST00000523022|ENST00000517618|ENST00000523953|ENST00000524324|ENST00000522389|ENST00000522814|ENST00000518233|ENST00000522579|ENST00000520692|ENST00000520093|ENST00000519129|ENST00000626824|ENST00000520663|ENST00000518341|ENST00000542576', 'RefSeq_mRNA_id': 'NM_001291967|NM_001128829|NM_001128830|NM_001164830|NM_001738|NM_001291968|NM_001128831', 'Organism': 'human', 'HGNC_symbol': 'CA1', 'Alias': '', 'Info': 'up'}
# down
# {'Index': 10, 'Gene_name': 'PPP1R14C', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000198729', 'Ensembl_transcript_id': 'ENST00000361131', 'RefSeq_mRNA_id': 'NM_030949', 'Organism': 'human', 'HGNC_symbol': 'PPP1R14C', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 11, 'Gene_name': 'RN7SL3', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000278771', 'Ensembl_transcript_id': 'ENST00000610674', 'RefSeq_mRNA_id': '', 'Organism': 'human', 'HGNC_symbol': 'RN7SL3', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 12, 'Gene_name': 'ADHFE1', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000147576', 'Ensembl_transcript_id': 'ENST00000426810|ENST00000396621|ENST00000422166|ENST00000443372|ENST00000419955|ENST00000466739|ENST00000449512|ENST00000424777|ENST00000415254|ENST00000396623|ENST00000431959|ENST00000463261|ENST00000276576|ENST00000518781|ENST00000496501|ENST00000466920', 'RefSeq_mRNA_id': 'NM_144650', 'Organism': 'human', 'HGNC_symbol': 'ADHFE1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 13, 'Gene_name': 'KRT34', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000131737|ENSG00000262045', 'Ensembl_transcript_id': 'ENST00000571312|ENST00000394001', 'RefSeq_mRNA_id': 'NM_001386014', 'Organism': 'human', 'HGNC_symbol': 'KRT34', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 14, 'Gene_name': 'CPXM2', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000121898', 'Ensembl_transcript_id': 'ENST00000615851|ENST00000368854|ENST00000481775|ENST00000241305', 'RefSeq_mRNA_id': 'NM_198148', 'Organism': 'human', 'HGNC_symbol': 'CPXM2', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 15, 'Gene_name': 'SIK1', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000142178', 'Ensembl_transcript_id': 'ENST00000644871|ENST00000644276|ENST00000644689|ENST00000270162|ENST00000644750|ENST00000478426', 'RefSeq_mRNA_id': 'NM_173354', 'Organism': 'human', 'HGNC_symbol': 'SIK1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 16, 'Gene_name': 'CGB7', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000196337', 'Ensembl_transcript_id': 'ENST00000597853|ENST00000598442|ENST00000596965|ENST00000684222', 'RefSeq_mRNA_id': 'NM_001385261|NM_033142', 'Organism': 'human', 'HGNC_symbol': 'CGB7', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 17, 'Gene_name': 'RAB6B', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000154917', 'Ensembl_transcript_id': 'ENST00000460865|ENST00000477759|ENST00000285208|ENST00000486858|ENST00000543906|ENST00000488969|ENST00000469959', 'RefSeq_mRNA_id': 'NM_016577|NM_001363953', 'Organism': 'human', 'HGNC_symbol': 'RAB6B', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 18, 'Gene_name': 'PLAC1', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000170965', 'Ensembl_transcript_id': 'ENST00000476971|ENST00000473897|ENST00000359237|ENST00000466797', 'RefSeq_mRNA_id': 'NM_021796|NM_001316889|NM_001316887|NM_001316888', 'Organism': 'human', 'HGNC_symbol': 'PLAC1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 19, 'Gene_name': 'MUC5B', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000117983', 'Ensembl_transcript_id': 'ENST00000531082|ENST00000525715|ENST00000529681|ENST00000527802|ENST00000526859', 'RefSeq_mRNA_id': 'NM_002458', 'Organism': 'human', 'HGNC_symbol': 'MUC5B', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 20, 'Gene_name': 'SMKR1', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000240204', 'Ensembl_transcript_id': 'ENST00000462322|ENST00000488846', 'RefSeq_mRNA_id': 'NM_001195243', 'Organism': 'human', 'HGNC_symbol': 'SMKR1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 21, 'Gene_name': 'ALPP', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000163283', 'Ensembl_transcript_id': 'ENST00000392027|ENST00000485563|ENST00000474529', 'RefSeq_mRNA_id': 'NM_001632', 'Organism': 'human', 'HGNC_symbol': 'ALPP', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 22, 'Gene_name': 'CITED4', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000179862', 'Ensembl_transcript_id': 'ENST00000372638', 'RefSeq_mRNA_id': 'NM_133467', 'Organism': 'human', 'HGNC_symbol': 'CITED4', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 23, 'Gene_name': 'PSG8', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000124467', 'Ensembl_transcript_id': 'ENST00000478387|ENST00000306511|ENST00000593692|ENST00000469260|ENST00000406636|ENST00000600709|ENST00000404209|ENST00000466163', 'RefSeq_mRNA_id': 'NM_001130168|NM_182707|NM_001130167', 'Organism': 'human', 'HGNC_symbol': 'PSG8', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 24, 'Gene_name': 'EPHB6', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000106123|ENSG00000275482', 'Ensembl_transcript_id': 'ENST00000634205|ENST00000422643|ENST00000497095|ENST00000632889|ENST00000633684|ENST00000615824|ENST00000486511|ENST00000614832|ENST00000634148|ENST00000476059|ENST00000632037|ENST00000652003|ENST00000631900|ENST00000471581|ENST00000631924|ENST00000611578|ENST00000634005|ENST00000618483|ENST00000616380|ENST00000619012|ENST00000617632|ENST00000411471|ENST00000632242', 'RefSeq_mRNA_id': 'NM_001280795|NM_004445|NM_001280794', 'Organism': 'human', 'HGNC_symbol': 'EPHB6', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 25, 'Gene_name': 'LRRN1', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000175928', 'Ensembl_transcript_id': 'ENST00000319331|ENST00000496115|ENST00000472075', 'RefSeq_mRNA_id': 'NM_001324188|NM_001324189|NM_020873', 'Organism': 'human', 'HGNC_symbol': 'LRRN1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 26, 'Gene_name': 'ARMS2', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000254636', 'Ensembl_transcript_id': 'ENST00000528446', 'RefSeq_mRNA_id': 'NM_001099667', 'Organism': 'human', 'HGNC_symbol': 'ARMS2', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 27, 'Gene_name': 'HSD17B1', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000108786', 'Ensembl_transcript_id': 'ENST00000593215|ENST00000590299|ENST00000585807|ENST00000225929|ENST00000587280', 'RefSeq_mRNA_id': 'NM_000413|NM_001330219', 'Organism': 'human', 'HGNC_symbol': 'HSD17B1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 28, 'Gene_name': 'ACOXL', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000153093', 'Ensembl_transcript_id': 'ENST00000461340|ENST00000433706|ENST00000676595|ENST00000448863|ENST00000443586|ENST00000389811|ENST00000441974|ENST00000496981|ENST00000439055|ENST00000417074|ENST00000340561', 'RefSeq_mRNA_id': 'NM_001365487|NM_001142807|NM_001371254', 'Organism': 'human', 'HGNC_symbol': 'ACOXL', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 29, 'Gene_name': 'ZNF554', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000172006', 'Ensembl_transcript_id': 'ENST00000591265|ENST00000588534|ENST00000317243|ENST00000590116', 'RefSeq_mRNA_id': 'NM_001102651', 'Organism': 'human', 'HGNC_symbol': 'ZNF554', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 30, 'Gene_name': 'ALDH3B2', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000132746', 'Ensembl_transcript_id': 'ENST00000673808|ENST00000534425|ENST00000531248|ENST00000673966|ENST00000528756|ENST00000674110|ENST00000673873|ENST00000530069|ENST00000349015|ENST00000525827|ENST00000533962|ENST00000531881', 'RefSeq_mRNA_id': 'NM_001393400|NM_001354345|NM_001393401|NM_001393402|NM_001031615', 'Organism': 'human', 'HGNC_symbol': 'ALDH3B2', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 31, 'Gene_name': 'PKD1P5', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000254681', 'Ensembl_transcript_id': 'ENST00000532415', 'RefSeq_mRNA_id': '', 'Organism': 'human', 'HGNC_symbol': 'PKD1P5', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 32, 'Gene_name': 'STX1B', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000099365', 'Ensembl_transcript_id': 'ENST00000215095|ENST00000565419|ENST00000566211', 'RefSeq_mRNA_id': 'NM_052874', 'Organism': 'human', 'HGNC_symbol': 'STX1B', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 33, 'Gene_name': 'ABHD17C', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000136379', 'Ensembl_transcript_id': 'ENST00000559506|ENST00000258884|ENST00000560609|ENST00000558464|ENST00000560126', 'RefSeq_mRNA_id': 'NM_021214', 'Organism': 'human', 'HGNC_symbol': 'ABHD17C', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 34, 'Gene_name': 'DUOX2', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000140279', 'Ensembl_transcript_id': 'ENST00000558416|ENST00000558383|ENST00000389039|ENST00000560797|ENST00000603300', 'RefSeq_mRNA_id': 'NM_014080|NM_001363711', 'Organism': 'human', 'HGNC_symbol': 'DUOX2', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 35, 'Gene_name': 'PSG1', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000231924', 'Ensembl_transcript_id': 'ENST00000595356|ENST00000597058|ENST00000403380|ENST00000436291|ENST00000602039|ENST00000312439|ENST00000595930|ENST00000595124|ENST00000601073|ENST00000244296|ENST00000601456', 'RefSeq_mRNA_id': 'NM_001297773|NM_001184826|NM_006905|NM_001184825|NM_001330524', 'Organism': 'human', 'HGNC_symbol': 'PSG1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 36, 'Gene_name': 'GDF15', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000130513', 'Ensembl_transcript_id': 'ENST00000604609|ENST00000594925|ENST00000252809|ENST00000595973|ENST00000597765', 'RefSeq_mRNA_id': 'NM_004864', 'Organism': 'human', 'HGNC_symbol': 'GDF15', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 37, 'Gene_name': 'ANK3', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000151150', 'Ensembl_transcript_id': 'ENST00000613207|ENST00000373820|ENST00000373827|ENST00000465749|ENST00000469721|ENST00000508449|ENST00000486349|ENST00000506635|ENST00000480699|ENST00000373815|ENST00000280772|ENST00000511043|ENST00000489505|ENST00000612776|ENST00000503925|ENST00000502769|ENST00000459732|ENST00000617800|ENST00000467420|ENST00000610901|ENST00000618080|ENST00000503366|ENST00000514197|ENST00000622427|ENST00000510382|ENST00000616444|ENST00000460468|ENST00000610321|ENST00000474360|ENST00000621739|ENST00000355288|ENST00000513049', 'RefSeq_mRNA_id': 'NM_020987|NM_001204403|NM_001320874|NM_001149|NM_001204404', 'Organism': 'human', 'HGNC_symbol': 'ANK3', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 38, 'Gene_name': 'NECTIN3', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000177707', 'Ensembl_transcript_id': 'ENST00000485303|ENST00000478327|ENST00000461477|ENST00000481766|ENST00000319792|ENST00000470618|ENST00000485506|ENST00000491525|ENST00000488016|ENST00000486596|ENST00000493615', 'RefSeq_mRNA_id': 'NM_015480|NM_001243288|NM_001243286', 'Organism': 'human', 'HGNC_symbol': 'NECTIN3', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 39, 'Gene_name': 'SYT12', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000173227', 'Ensembl_transcript_id': 'ENST00000533427|ENST00000393946|ENST00000527043|ENST00000531392|ENST00000525457|ENST00000526281|ENST00000525149', 'RefSeq_mRNA_id': 'NM_001318775|NM_001318773|NM_177963|NM_001177880', 'Organism': 'human', 'HGNC_symbol': 'SYT12', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 40, 'Gene_name': 'SLC7A2', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000003989', 'Ensembl_transcript_id': 'ENST00000522656|ENST00000494857|ENST00000640220|ENST00000004531|ENST00000470360|ENST00000398090', 'RefSeq_mRNA_id': 'NM_003046|NM_001370338|NM_001008539|NM_001370337|NM_001164771', 'Organism': 'human', 'HGNC_symbol': 'SLC7A2', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 41, 'Gene_name': 'KISS1', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000170498', 'Ensembl_transcript_id': 'ENST00000367194', 'RefSeq_mRNA_id': 'NM_002256', 'Organism': 'human', 'HGNC_symbol': 'KISS1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 42, 'Gene_name': 'LCAL1', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000286042', 'Ensembl_transcript_id': 'ENST00000651663|ENST00000651762|ENST00000651107', 'RefSeq_mRNA_id': '', 'Organism': 'human', 'HGNC_symbol': 'LCAL1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 43, 'Gene_name': 'LINC01554', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000236882', 'Ensembl_transcript_id': 'ENST00000620167|ENST00000436592|ENST00000702482|ENST00000357880|ENST00000656444', 'RefSeq_mRNA_id': '', 'Organism': 'human', 'HGNC_symbol': 'LINC01554', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 44, 'Gene_name': 'MISP3', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000141854|ENSG00000288191', 'Ensembl_transcript_id': 'ENST00000672970|ENST00000590772|ENST00000269720|ENST00000671837|ENST00000591982|ENST00000672245|ENST00000672552|ENST00000587086', 'RefSeq_mRNA_id': 'NM_001393577|NM_001291291', 'Organism': 'human', 'HGNC_symbol': 'MISP3', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 45, 'Gene_name': 'PGF', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000119630', 'Ensembl_transcript_id': 'ENST00000557748|ENST00000555567|ENST00000553716|ENST00000555234|ENST00000405431|ENST00000238607|ENST00000555253|ENST00000556939', 'RefSeq_mRNA_id': 'NM_002632|NM_001293643|NM_001207012', 'Organism': 'human', 'HGNC_symbol': 'PGF', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 46, 'Gene_name': 'TPRXL', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000180438', 'Ensembl_transcript_id': 'ENST00000529129|ENST00000532924|ENST00000326972|ENST00000528067|ENST00000528040|ENST00000532753|ENST00000528312|ENST00000524375|ENST00000429201|ENST00000530586|ENST00000424053|ENST00000636198|ENST00000532880|ENST00000637756', 'RefSeq_mRNA_id': '', 'Organism': 'human', 'HGNC_symbol': 'TPRXL', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 47, 'Gene_name': 'GDA', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000119125', 'Ensembl_transcript_id': 'ENST00000489618|ENST00000414671|ENST00000238018|ENST00000358399|ENST00000376986|ENST00000477618|ENST00000475764|ENST00000436438|ENST00000545168', 'RefSeq_mRNA_id': 'NM_001351571|NM_001242506|NM_001351573|NM_001242507|NM_001242505|NM_004293|NM_001351572', 'Organism': 'human', 'HGNC_symbol': 'GDA', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 48, 'Gene_name': 'TC2N', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000276776|ENSG00000165929', 'Ensembl_transcript_id': 'ENST00000620359|ENST00000340892|ENST00000631910|ENST00000556590|ENST00000632584|ENST00000360594|ENST00000556018|ENST00000555302|ENST00000435962|ENST00000554424|ENST00000634120|ENST00000610758|ENST00000633527', 'RefSeq_mRNA_id': 'NM_001289134|NM_152332|NM_001128596|NM_001128595', 'Organism': 'human', 'HGNC_symbol': 'TC2N', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 49, 'Gene_name': 'CAB39P1', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000251303', 'Ensembl_transcript_id': 'ENST00000502277', 'RefSeq_mRNA_id': '', 'Organism': 'human', 'HGNC_symbol': 'CAB39P1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 50, 'Gene_name': 'MUC4', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000278303|ENSG00000273984|ENSG00000276613|ENSG00000277585|ENSG00000145113|ENSG00000275164|ENSG00000278468|ENSG00000273822', 'Ensembl_transcript_id': 'ENST00000626248|ENST00000631081|ENST00000613615|ENST00000629390|ENST00000308466|ENST00000629873|ENST00000628062|ENST00000631146|ENST00000629826|ENST00000628526|ENST00000479406|ENST00000626390|ENST00000415455|ENST00000615271|ENST00000629929|ENST00000627153|ENST00000618211|ENST00000626727|ENST00000626664|ENST00000612020|ENST00000629031|ENST00000627430|ENST00000478156|ENST00000620159|ENST00000631201|ENST00000630325|ENST00000625430|ENST00000346145|ENST00000464234|ENST00000626905|ENST00000627236|ENST00000620934|ENST00000627603|ENST00000625407|ENST00000626054|ENST00000392407|ENST00000462323|ENST00000630616|ENST00000626146|ENST00000628045|ENST00000617794|ENST00000619402|ENST00000477756|ENST00000626679|ENST00000626035|ENST00000466475|ENST00000630459|ENST00000628058|ENST00000627334|ENST00000627791|ENST00000621966|ENST00000627007|ENST00000626364|ENST00000627218|ENST00000628685|ENST00000629001|ENST00000631279|ENST00000613841|ENST00000610962|ENST00000467235|ENST00000625520|ENST00000630820|ENST00000629775|ENST00000631078|ENST00000630579|ENST00000612476|ENST00000627411|ENST00000463781|ENST00000627203|ENST00000627017|ENST00000629947|ENST00000626318|ENST00000627276|ENST00000628987|ENST00000630966|ENST00000626878|ENST00000629076|ENST00000628289|ENST00000470451|ENST00000631334|ENST00000478685|ENST00000628366|ENST00000625840|ENST00000630037|ENST00000629163|ENST00000626427|ENST00000475231|ENST00000629801|ENST00000469992|ENST00000627391|ENST00000625238|ENST00000630917|ENST00000626947|ENST00000631360|ENST00000628300|ENST00000619175|ENST00000626305|ENST00000625485|ENST00000626164|ENST00000486425|ENST00000630258|ENST00000631127|ENST00000639126|ENST00000630769|ENST00000626242|ENST00000629594|ENST00000448861|ENST00000631351|ENST00000629790|ENST00000626113|ENST00000625575|ENST00000631225|ENST00000627557|ENST00000627476|ENST00000628818|ENST00000614666|ENST00000627089|ENST00000630183|ENST00000628843|ENST00000349607|ENST00000612796|ENST00000631180|ENST00000627537|ENST00000627295|ENST00000628806|ENST00000629757|ENST00000627893|ENST00000630118|ENST00000617056|ENST00000626514|ENST00000627165|ENST00000626403|ENST00000628327|ENST00000631097|ENST00000625421|ENST00000631069|ENST00000630127|ENST00000629793|ENST00000630081|ENST00000627062|ENST00000629154|ENST00000631008|ENST00000629882|ENST00000630880|ENST00000628330|ENST00000477086|ENST00000630176|ENST00000630643|ENST00000339251|ENST00000618077|ENST00000629006|ENST00000480843|ENST00000627146|ENST00000628970|ENST00000626914|ENST00000630304|ENST00000629021|ENST00000628456|ENST00000628931|ENST00000627577', 'RefSeq_mRNA_id': 'NM_001322468|NM_138297|NM_018406|NM_004532', 'Organism': 'human', 'HGNC_symbol': 'MUC4', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 51, 'Gene_name': 'LAD1', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000159166', 'Ensembl_transcript_id': 'ENST00000633953|ENST00000631576|ENST00000367313|ENST00000632743|ENST00000475136|ENST00000488842|ENST00000391967', 'RefSeq_mRNA_id': 'NM_005558', 'Organism': 'human', 'HGNC_symbol': 'LAD1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 52, 'Gene_name': 'SH3TC2', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000169247', 'Ensembl_transcript_id': 'ENST00000511949|ENST00000513340|ENST00000676367|ENST00000504091|ENST00000515229|ENST00000515425|ENST00000643113|ENST00000504517|ENST00000323829|ENST00000675793|ENST00000511307|ENST00000502274|ENST00000676056|ENST00000674983|ENST00000503071|ENST00000504690|ENST00000510779|ENST00000512049|ENST00000674655|ENST00000510350|ENST00000513604', 'RefSeq_mRNA_id': 'NM_024577', 'Organism': 'human', 'HGNC_symbol': 'SH3TC2', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 53, 'Gene_name': 'NCF4-AS1', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000183822|ENSG00000281093', 'Ensembl_transcript_id': 'ENST00000619915|ENST00000625405|ENST00000629623|ENST00000431290', 'RefSeq_mRNA_id': '', 'Organism': 'human', 'HGNC_symbol': 'NCF4-AS1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 54, 'Gene_name': 'CRYBG2', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000176092', 'Ensembl_transcript_id': 'ENST00000640960|ENST00000308182|ENST00000374211|ENST00000429942|ENST00000374208|ENST00000475866|ENST00000520372|ENST00000522993|ENST00000374207|ENST00000522923', 'RefSeq_mRNA_id': 'NM_001039775', 'Organism': 'human', 'HGNC_symbol': 'CRYBG2', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 55, 'Gene_name': 'FTCD', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000281775|ENSG00000160282', 'Ensembl_transcript_id': 'ENST00000498355|ENST00000397746|ENST00000628730|ENST00000629394|ENST00000483568|ENST00000494498|ENST00000628009|ENST00000397743|ENST00000628259|ENST00000625428|ENST00000628700|ENST00000626208|ENST00000631005|ENST00000446405|ENST00000488577|ENST00000625714|ENST00000480950|ENST00000291670|ENST00000625846|ENST00000397748|ENST00000460011|ENST00000469240', 'RefSeq_mRNA_id': 'NM_001320412|NM_206965|NM_006657', 'Organism': 'human', 'HGNC_symbol': 'FTCD', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 56, 'Gene_name': 'PHYHIPL', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000165443', 'Ensembl_transcript_id': 'ENST00000486074|ENST00000373880|ENST00000373878|ENST00000472199', 'RefSeq_mRNA_id': 'NM_032439|NM_001143774', 'Organism': 'human', 'HGNC_symbol': 'PHYHIPL', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 57, 'Gene_name': 'NAV2-AS4', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000254622', 'Ensembl_transcript_id': 'ENST00000532874', 'RefSeq_mRNA_id': '', 'Organism': 'human', 'HGNC_symbol': 'NAV2-AS4', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 58, 'Gene_name': 'CSH1', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000136488', 'Ensembl_transcript_id': 'ENST00000453363|ENST00000610991|ENST00000329882|ENST00000558284|ENST00000558661|ENST00000316193', 'RefSeq_mRNA_id': 'NM_001317', 'Organism': 'human', 'HGNC_symbol': 'CSH1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 59, 'Gene_name': 'GH2', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000136487', 'Ensembl_transcript_id': 'ENST00000449787|ENST00000456543|ENST00000332800|ENST00000622506|ENST00000423893', 'RefSeq_mRNA_id': 'NM_022556|NM_002059|NM_022558|NM_022557', 'Organism': 'human', 'HGNC_symbol': 'GH2', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 60, 'Gene_name': 'HSD11B2', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000176387', 'Ensembl_transcript_id': 'ENST00000569303|ENST00000566606|ENST00000567684|ENST00000326152', 'RefSeq_mRNA_id': 'NM_000196', 'Organism': 'human', 'HGNC_symbol': 'HSD11B2', 'Alias': '', 'Info': 'down'}
# up
# {'Index': 61, 'Gene_name': 'CPNE7', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000178773', 'Ensembl_transcript_id': 'ENST00000526232|ENST00000532500|ENST00000268720|ENST00000566398|ENST00000564421|ENST00000529800|ENST00000568977|ENST00000319518|ENST00000525982', 'RefSeq_mRNA_id': 'NM_014427|NM_153636', 'Organism': 'human', 'HGNC_symbol': 'CPNE7', 'Alias': '', 'Info': 'up'}
# down
# {'Index': 62, 'Gene_name': 'CYP19A1', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000137869', 'Ensembl_transcript_id': 'ENST00000478421|ENST00000559653|ENST00000557934|ENST00000561075|ENST00000561066|ENST00000559980|ENST00000405913|ENST00000453807|ENST00000557858|ENST00000405011|ENST00000396402|ENST00000559646|ENST00000559878|ENST00000396404|ENST00000439712|ENST00000558066|ENST00000558328|ENST00000492852|ENST00000490076', 'RefSeq_mRNA_id': 'NM_001347248|NM_001347249|NM_001347256|NM_001347255|NM_031226|NM_001347250|NM_001347254|NM_000103|NM_001347253|NM_001347251|NM_001347252', 'Organism': 'human', 'HGNC_symbol': 'CYP19A1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 63, 'Gene_name': 'SEMA3B', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000012171', 'Ensembl_transcript_id': 'ENST00000616701|ENST00000439487|ENST00000456210|ENST00000619119|ENST00000612509|ENST00000418576|ENST00000416295|ENST00000618865|ENST00000611067|ENST00000433753|ENST00000456560|ENST00000419007|ENST00000621029|ENST00000434030|ENST00000441915', 'RefSeq_mRNA_id': 'NM_001290061|NM_001005914|NM_001290062|NM_001290063|NM_004636|NM_001290060', 'Organism': 'human', 'HGNC_symbol': 'SEMA3B', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 64, 'Gene_name': 'P2RX2', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000187848', 'Ensembl_transcript_id': 'ENST00000351222|ENST00000348800|ENST00000449132|ENST00000343948|ENST00000542301|ENST00000350048|ENST00000643471|ENST00000352418', 'RefSeq_mRNA_id': 'NM_174872|NM_170682|NM_012226|NM_001282164|NM_170683|NM_174873|NM_001282165|NM_016318', 'Organism': 'human', 'HGNC_symbol': 'P2RX2', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 65, 'Gene_name': 'OPTC', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000188770', 'Ensembl_transcript_id': 'ENST00000448911|ENST00000367222', 'RefSeq_mRNA_id': 'NM_014359', 'Organism': 'human', 'HGNC_symbol': 'OPTC', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 66, 'Gene_name': 'PSG6', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000170848', 'Ensembl_transcript_id': 'ENST00000599753|ENST00000402456|ENST00000484292|ENST00000601833|ENST00000595062|ENST00000402603|ENST00000187910|ENST00000292125|ENST00000594375', 'RefSeq_mRNA_id': 'NM_001031850|NM_002782', 'Organism': 'human', 'HGNC_symbol': 'PSG6', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 67, 'Gene_name': 'HSD3B1', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000203857', 'Ensembl_transcript_id': 'ENST00000531340|ENST00000369413|ENST00000487520|ENST00000492140|ENST00000528909', 'RefSeq_mRNA_id': 'NM_000862|NM_001328615', 'Organism': 'human', 'HGNC_symbol': 'HSD3B1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 68, 'Gene_name': 'ERV3-1', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000213462', 'Ensembl_transcript_id': 'ENST00000394323|ENST00000528878|ENST00000535538', 'RefSeq_mRNA_id': 'NM_001396062|NM_001007253', 'Organism': 'human', 'HGNC_symbol': 'ERV3-1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 69, 'Gene_name': 'HS3ST3B1', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000125430', 'Ensembl_transcript_id': 'ENST00000466596|ENST00000360954', 'RefSeq_mRNA_id': 'NM_006041', 'Organism': 'human', 'HGNC_symbol': 'HS3ST3B1', 'Alias': '', 'Info': 'down'}
# up
# {'Index': 70, 'Gene_name': 'SLAMF7', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000026751', 'Ensembl_transcript_id': 'ENST00000368042|ENST00000359331|ENST00000444090|ENST00000484221|ENST00000458104|ENST00000441662|ENST00000495334|ENST00000621377|ENST00000488819|ENST00000368043|ENST00000458602', 'RefSeq_mRNA_id': 'NM_001282592|NM_001282594|NM_021181|NM_001282595|NM_001282590|NM_001282593|NM_001282588|NM_001282589|NM_001282591|NM_001282596', 'Organism': 'human', 'HGNC_symbol': 'SLAMF7', 'Alias': '', 'Info': 'up'}
# down
# {'Index': 71, 'Gene_name': 'CCDC33', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000140481|ENSG00000288407', 'Ensembl_transcript_id': 'ENST00000635913|ENST00000558659|ENST00000268082|ENST00000673367|ENST00000560148|ENST00000672359|ENST00000560565|ENST00000672175|ENST00000558821|ENST00000671751|ENST00000673517|ENST00000561332|ENST00000672882|ENST00000673091|ENST00000672087|ENST00000559243|ENST00000398814|ENST00000558645|ENST00000673214|ENST00000321374|ENST00000672048|ENST00000671722|ENST00000563951|ENST00000672263', 'RefSeq_mRNA_id': 'NM_025055|NM_001287181|NM_182791', 'Organism': 'human', 'HGNC_symbol': 'CCDC33', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 72, 'Gene_name': 'DHRS2', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000100867', 'Ensembl_transcript_id': 'ENST00000556550|ENST00000250383|ENST00000611765|ENST00000344777|ENST00000556701|ENST00000553896|ENST00000432832|ENST00000553600|ENST00000556729|ENST00000557535', 'RefSeq_mRNA_id': 'NM_005794|NM_182908|NM_001318835', 'Organism': 'human', 'HGNC_symbol': 'DHRS2', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 73, 'Gene_name': 'AKR1B15', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000227471', 'Ensembl_transcript_id': 'ENST00000457545|ENST00000467156|ENST00000423958|ENST00000652743', 'RefSeq_mRNA_id': 'NM_001367820|NM_001367821|NM_001080538', 'Organism': 'human', 'HGNC_symbol': 'AKR1B15', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 74, 'Gene_name': 'TREML2', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000112195', 'Ensembl_transcript_id': 'ENST00000483722', 'RefSeq_mRNA_id': 'NM_024807', 'Organism': 'human', 'HGNC_symbol': 'TREML2', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 75, 'Gene_name': 'GABRB1', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000163288', 'Ensembl_transcript_id': 'ENST00000510909|ENST00000513567|ENST00000509366|ENST00000381582|ENST00000295454', 'RefSeq_mRNA_id': 'NM_000812', 'Organism': 'human', 'HGNC_symbol': 'GABRB1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 76, 'Gene_name': 'PSG4', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000243137', 'Ensembl_transcript_id': 'ENST00000244295|ENST00000490769|ENST00000597374|ENST00000599371|ENST00000495316|ENST00000405312|ENST00000597349|ENST00000596199|ENST00000597912|ENST00000600572|ENST00000601041|ENST00000599391|ENST00000595949|ENST00000451895|ENST00000596907|ENST00000433626|ENST00000599746', 'RefSeq_mRNA_id': 'NM_001316339|NM_002780|NM_001276495|NM_213633', 'Organism': 'human', 'HGNC_symbol': 'PSG4', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 77, 'Gene_name': 'EPHA1-AS1', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000285468|ENSG00000229153', 'Ensembl_transcript_id': 'ENST00000703017|ENST00000646518|ENST00000429289|ENST00000692812|ENST00000642718|ENST00000690912|ENST00000421648', 'RefSeq_mRNA_id': '', 'Organism': 'human', 'HGNC_symbol': 'EPHA1-AS1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 78, 'Gene_name': 'RBP4', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000138207', 'Ensembl_transcript_id': 'ENST00000371467|ENST00000371464|ENST00000371469', 'RefSeq_mRNA_id': 'NM_001323517|NM_001323518|NM_006744', 'Organism': 'human', 'HGNC_symbol': 'RBP4', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 79, 'Gene_name': 'KIAA0319', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000137261', 'Ensembl_transcript_id': 'ENST00000616673|ENST00000430948|ENST00000378214|ENST00000537886|ENST00000535378', 'RefSeq_mRNA_id': 'NM_001350409|NM_001350404|NM_001350406|NM_001168374|NM_001168376|NM_014809|NM_001168375|NM_001168377|NM_001350410|NM_001350403|NM_001350405|NM_001252328|NM_001350407|NM_001350408', 'Organism': 'human', 'HGNC_symbol': 'KIAA0319', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 80, 'Gene_name': 'TMEM54', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000121900', 'Ensembl_transcript_id': 'ENST00000482771|ENST00000463914|ENST00000373463|ENST00000474144|ENST00000329151|ENST00000475208', 'RefSeq_mRNA_id': 'NM_001329724|NM_033504|NM_001329725|NM_001329722|NM_001329723', 'Organism': 'human', 'HGNC_symbol': 'TMEM54', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 81, 'Gene_name': 'CLC', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000105205', 'Ensembl_transcript_id': 'ENST00000221804', 'RefSeq_mRNA_id': 'NM_001828', 'Organism': 'human', 'HGNC_symbol': 'CLC', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 82, 'Gene_name': 'SDC1', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000115884', 'Ensembl_transcript_id': 'ENST00000403076|ENST00000482879|ENST00000381150|ENST00000429035|ENST00000254351|ENST00000447124', 'RefSeq_mRNA_id': 'NM_001006946|NM_002997', 'Organism': 'human', 'HGNC_symbol': 'SDC1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 83, 'Gene_name': 'NPFFR2', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000056291', 'Ensembl_transcript_id': 'ENST00000506359|ENST00000358749|ENST00000344413|ENST00000308744|ENST00000395999', 'RefSeq_mRNA_id': 'NM_004885|NM_001144756|NM_053036', 'Organism': 'human', 'HGNC_symbol': 'NPFFR2', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 84, 'Gene_name': 'LRRC8E', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000171017', 'Ensembl_transcript_id': 'ENST00000599367|ENST00000600345|ENST00000618098|ENST00000306708|ENST00000598224|ENST00000593511', 'RefSeq_mRNA_id': 'NM_001268285|NM_001268284|NM_025061', 'Organism': 'human', 'HGNC_symbol': 'LRRC8E', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 85, 'Gene_name': 'LY6G6C', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000204421|ENSG00000235925|ENSG00000206398|ENSG00000235452|ENSG00000228250|ENSG00000236183|ENSG00000228859', 'Ensembl_transcript_id': 'ENST00000448386|ENST00000428498|ENST00000383413|ENST00000479794|ENST00000497123|ENST00000470946|ENST00000470881|ENST00000480025|ENST00000419939|ENST00000428121|ENST00000495859|ENST00000434915|ENST00000467714|ENST00000375819', 'RefSeq_mRNA_id': 'NM_025261', 'Organism': 'human', 'HGNC_symbol': 'LY6G6C', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 86, 'Gene_name': 'SRRM4', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000139767', 'Ensembl_transcript_id': 'ENST00000641899|ENST00000537597|ENST00000267260|ENST00000651431|ENST00000545224|ENST00000641910|ENST00000534886', 'RefSeq_mRNA_id': 'NM_194286', 'Organism': 'human', 'HGNC_symbol': 'SRRM4', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 87, 'Gene_name': 'SYNPO2L', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000166317', 'Ensembl_transcript_id': 'ENST00000372873|ENST00000394810|ENST00000606523', 'RefSeq_mRNA_id': 'NM_001114133|NM_024875', 'Organism': 'human', 'HGNC_symbol': 'SYNPO2L', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 88, 'Gene_name': 'LYPD5', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000159871', 'Ensembl_transcript_id': 'ENST00000601224|ENST00000599397|ENST00000651184|ENST00000594049|ENST00000595666|ENST00000414615|ENST00000594013|ENST00000602179|ENST00000377950', 'RefSeq_mRNA_id': 'NM_182573|NM_001288763|NM_001031749', 'Organism': 'human', 'HGNC_symbol': 'LYPD5', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 89, 'Gene_name': 'STYK1', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000060140', 'Ensembl_transcript_id': 'ENST00000542562|ENST00000542924|ENST00000075503|ENST00000538867|ENST00000541561|ENST00000535345', 'RefSeq_mRNA_id': 'NM_018423', 'Organism': 'human', 'HGNC_symbol': 'STYK1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 90, 'Gene_name': 'HLF', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000108924', 'Ensembl_transcript_id': 'ENST00000570962|ENST00000430986|ENST00000572002|ENST00000573020|ENST00000572234|ENST00000575868|ENST00000226067|ENST00000573422|ENST00000573945|ENST00000575307|ENST00000575345', 'RefSeq_mRNA_id': 'NM_002126|NM_001330375', 'Organism': 'human', 'HGNC_symbol': 'HLF', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 91, 'Gene_name': 'NECTIN3-AS1', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000242242', 'Ensembl_transcript_id': 'ENST00000476301|ENST00000474769|ENST00000691789|ENST00000491709|ENST00000690883|ENST00000485473|ENST00000467426|ENST00000383686|ENST00000463025', 'RefSeq_mRNA_id': '', 'Organism': 'human', 'HGNC_symbol': 'NECTIN3-AS1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 92, 'Gene_name': 'UPK3B', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000276184|ENSG00000243566', 'Ensembl_transcript_id': 'ENST00000448265|ENST00000634060|ENST00000633712|ENST00000469114|ENST00000615976|ENST00000631529|ENST00000334348|ENST00000394849|ENST00000490360|ENST00000257632', 'RefSeq_mRNA_id': 'NM_182684|NM_030570|NM_001347684|NM_182683', 'Organism': 'human', 'HGNC_symbol': 'UPK3B', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 93, 'Gene_name': 'S100A2', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000196754', 'Ensembl_transcript_id': 'ENST00000368710|ENST00000368709|ENST00000368708|ENST00000368707|ENST00000497140|ENST00000487430', 'RefSeq_mRNA_id': 'NM_001366406|NM_005978|NM_001366407', 'Organism': 'human', 'HGNC_symbol': 'S100A2', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 94, 'Gene_name': 'CGA', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000135346', 'Ensembl_transcript_id': 'ENST00000625577|ENST00000610310|ENST00000630630|ENST00000627148|ENST00000627552|ENST00000369582', 'RefSeq_mRNA_id': 'NM_000735|NM_001252383', 'Organism': 'human', 'HGNC_symbol': 'CGA', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 95, 'Gene_name': 'NCCRP1', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000188505', 'Ensembl_transcript_id': 'ENST00000339852', 'RefSeq_mRNA_id': 'NM_001001414', 'Organism': 'human', 'HGNC_symbol': 'NCCRP1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 96, 'Gene_name': 'AICDA', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000111732', 'Ensembl_transcript_id': 'ENST00000545576|ENST00000696272|ENST00000543081|ENST00000544516|ENST00000229335|ENST00000696246|ENST00000696273|ENST00000537228|ENST00000696271', 'RefSeq_mRNA_id': 'NM_020661|NM_001410970|NM_001330343', 'Organism': 'human', 'HGNC_symbol': 'AICDA', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 97, 'Gene_name': 'SLC26A7', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000147606', 'Ensembl_transcript_id': 'ENST00000617078|ENST00000522862|ENST00000309536|ENST00000523719|ENST00000520818|ENST00000522181|ENST00000276609|ENST00000517930|ENST00000520249|ENST00000617233', 'RefSeq_mRNA_id': 'NM_052832|NM_134266|NM_001282356|NM_001282357', 'Organism': 'human', 'HGNC_symbol': 'SLC26A7', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 98, 'Gene_name': 'REN', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000143839', 'Ensembl_transcript_id': 'ENST00000272190|ENST00000638118', 'RefSeq_mRNA_id': 'NM_000537', 'Organism': 'human', 'HGNC_symbol': 'REN', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 99, 'Gene_name': 'SLC7A4', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000099960', 'Ensembl_transcript_id': 'ENST00000426145|ENST00000382932|ENST00000403586', 'RefSeq_mRNA_id': 'NM_004173', 'Organism': 'human', 'HGNC_symbol': 'SLC7A4', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 100, 'Gene_name': 'LCMT1-AS2', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000260034', 'Ensembl_transcript_id': 'ENST00000562280|ENST00000565214', 'RefSeq_mRNA_id': '', 'Organism': 'human', 'HGNC_symbol': 'LCMT1-AS2', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 101, 'Gene_name': 'TRPV6', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000165125|ENSG00000276971', 'Ensembl_transcript_id': 'ENST00000489123|ENST00000615386|ENST00000619250|ENST00000632330|ENST00000359396|ENST00000474388|ENST00000431833|ENST00000632381|ENST00000633826|ENST00000611485|ENST00000631384|ENST00000633318|ENST00000485138|ENST00000436401|ENST00000632149|ENST00000632455|ENST00000634074', 'RefSeq_mRNA_id': 'NM_018646', 'Organism': 'human', 'HGNC_symbol': 'TRPV6', 'Alias': '', 'Info': 'down'}
# down
# ...
# down
# {'Index': 171, 'Gene_name': 'OLAH', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000152463', 'Ensembl_transcript_id': 'ENST00000378228|ENST00000378217|ENST00000413672|ENST00000428897|ENST00000485251|ENST00000493912|ENST00000429028|ENST00000378225', 'RefSeq_mRNA_id': 'NM_018324|NM_001039702', 'Organism': 'human', 'HGNC_symbol': 'OLAH', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 172, 'Gene_name': 'ADAM12', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000148848', 'Ensembl_transcript_id': 'ENST00000494661|ENST00000482291|ENST00000368679|ENST00000448723|ENST00000467145|ENST00000368676|ENST00000485388', 'RefSeq_mRNA_id': 'NM_001288975|NM_001288973|NM_003474|NM_001288974|NM_021641', 'Organism': 'human', 'HGNC_symbol': 'ADAM12', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 173, 'Gene_name': 'FBXW11P1', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000230870', 'Ensembl_transcript_id': 'ENST00000393804', 'RefSeq_mRNA_id': '', 'Organism': 'human', 'HGNC_symbol': 'FBXW11P1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 174, 'Gene_name': 'SLC7A10', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000130876', 'Ensembl_transcript_id': 'ENST00000590490|ENST00000253188|ENST00000592596|ENST00000590036|ENST00000587064', 'RefSeq_mRNA_id': 'NM_019849', 'Organism': 'human', 'HGNC_symbol': 'SLC7A10', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 175, 'Gene_name': 'TCL6', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000187621', 'Ensembl_transcript_id': 'ENST00000484207|ENST00000357168|ENST00000483087|ENST00000460130|ENST00000497248|ENST00000495696|ENST00000702257|ENST00000486671|ENST00000467865|ENST00000465501|ENST00000352367|ENST00000619182|ENST00000459662', 'RefSeq_mRNA_id': '', 'Organism': 'human', 'HGNC_symbol': 'TCL6', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 176, 'Gene_name': 'CALHM3', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000183128', 'Ensembl_transcript_id': 'ENST00000369783', 'RefSeq_mRNA_id': 'NM_001129742', 'Organism': 'human', 'HGNC_symbol': 'CALHM3', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 177, 'Gene_name': 'ALOXE3', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000179148', 'Ensembl_transcript_id': 'ENST00000583808|ENST00000380149|ENST00000318227|ENST00000448843', 'RefSeq_mRNA_id': 'NM_021628|NM_001165960|NM_001369446', 'Organism': 'human', 'HGNC_symbol': 'ALOXE3', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 178, 'Gene_name': 'LGALS14', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000006659', 'Ensembl_transcript_id': 'ENST00000392052|ENST00000601802|ENST00000360675', 'RefSeq_mRNA_id': 'NM_020129|NM_203471', 'Organism': 'human', 'HGNC_symbol': 'LGALS14', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 179, 'Gene_name': 'SCIN', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000006747', 'Ensembl_transcript_id': 'ENST00000341757|ENST00000519209|ENST00000518849|ENST00000486980|ENST00000436854|ENST00000473722|ENST00000417018|ENST00000297029|ENST00000523729|ENST00000476649', 'RefSeq_mRNA_id': 'NM_001112706|NM_033128', 'Organism': 'human', 'HGNC_symbol': 'SCIN', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 180, 'Gene_name': 'PSG3', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000221826', 'Ensembl_transcript_id': 'ENST00000595140|ENST00000594378|ENST00000614582|ENST00000597009|ENST00000490592|ENST00000327495', 'RefSeq_mRNA_id': 'NM_021016', 'Organism': 'human', 'HGNC_symbol': 'PSG3', 'Alias': '', 'Info': 'down'}
# up
# {'Index': 181, 'Gene_name': 'CXCL10', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000169245', 'Ensembl_transcript_id': 'ENST00000306602', 'RefSeq_mRNA_id': 'NM_001565', 'Organism': 'human', 'HGNC_symbol': 'CXCL10', 'Alias': '', 'Info': 'up'}
# up
# {'Index': 182, 'Gene_name': 'GYPA', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000170180', 'Ensembl_transcript_id': 'ENST00000324022|ENST00000643148|ENST00000535709|ENST00000360771|ENST00000646447|ENST00000642713|ENST00000512789|ENST00000509346|ENST00000512064|ENST00000642738|ENST00000643254|ENST00000504786|ENST00000644398|ENST00000508337|ENST00000510771|ENST00000642295|ENST00000616983|ENST00000514603|ENST00000503627|ENST00000641688', 'RefSeq_mRNA_id': 'NM_001308190|NM_002099|NM_001308187', 'Organism': 'human', 'HGNC_symbol': 'GYPA', 'Alias': '', 'Info': 'up'}
# down
# {'Index': 183, 'Gene_name': 'COX20P1', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000213025', 'Ensembl_transcript_id': 'ENST00000366529', 'RefSeq_mRNA_id': '', 'Organism': 'human', 'HGNC_symbol': 'COX20P1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 184, 'Gene_name': 'PSG10P', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000248257', 'Ensembl_transcript_id': 'ENST00000501199', 'RefSeq_mRNA_id': '', 'Organism': 'human', 'HGNC_symbol': 'PSG10P', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 185, 'Gene_name': 'RN7SL268P', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000277187|ENSG00000244425', 'Ensembl_transcript_id': 'ENST00000611500|ENST00000491172', 'RefSeq_mRNA_id': '', 'Organism': 'human', 'HGNC_symbol': 'RN7SL268P', 'Alias': '', 'Info': 'down'}
# up
# {'Index': 186, 'Gene_name': 'PNMA5', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000198883', 'Ensembl_transcript_id': 'ENST00000439251|ENST00000452693|ENST00000361887|ENST00000535214', 'RefSeq_mRNA_id': 'NM_001184924|NM_001103151|NM_052926|NM_001103150', 'Organism': 'human', 'HGNC_symbol': 'PNMA5', 'Alias': '', 'Info': 'up'}
# down
# {'Index': 187, 'Gene_name': 'EVPL', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000167880', 'Ensembl_transcript_id': 'ENST00000587569|ENST00000593037|ENST00000589231|ENST00000586740|ENST00000301607', 'RefSeq_mRNA_id': 'NM_001988|NM_001320747', 'Organism': 'human', 'HGNC_symbol': 'EVPL', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 188, 'Gene_name': 'IGHG4', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000277016|ENSG00000211892', 'Ensembl_transcript_id': 'ENST00000618981|ENST00000641978|ENST00000390543', 'RefSeq_mRNA_id': '', 'Organism': 'human', 'HGNC_symbol': 'IGHG4', 'Alias': '', 'Info': 'down'}
# up
# {'Index': 189, 'Gene_name': 'PDCD1', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000188389|ENSG00000276977', 'Ensembl_transcript_id': 'ENST00000334409|ENST00000630230|ENST00000343705|ENST00000618185|ENST00000630560|ENST00000418831', 'RefSeq_mRNA_id': 'NM_005018', 'Organism': 'human', 'HGNC_symbol': 'PDCD1', 'Alias': '', 'Info': 'up'}
# down
# {'Index': 190, 'Gene_name': 'PLA2G2F', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000158786', 'Ensembl_transcript_id': 'ENST00000465062|ENST00000375102', 'RefSeq_mRNA_id': 'NM_022819|NM_001360869', 'Organism': 'human', 'HGNC_symbol': 'PLA2G2F', 'Alias': '', 'Info': 'down'}
# down
# ['LINC00514', 'SPERT', 'HIST3H2BB']
# {'Index': 191, 'Gene_name': 'HIST3H2BB', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': '', 'Ensembl_transcript_id': '', 'RefSeq_mRNA_id': '', 'Organism': 'human', 'HGNC_symbol': 'HIST3H2BB', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 192, 'Gene_name': 'PSG9', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000183668', 'Ensembl_transcript_id': 'ENST00000596730|ENST00000621109|ENST00000270077|ENST00000418820|ENST00000291752|ENST00000443718|ENST00000593948|ENST00000244293|ENST00000595404', 'RefSeq_mRNA_id': 'NM_001301709|NM_001301707|NM_001411075|NM_001301708|NM_002784', 'Organism': 'human', 'HGNC_symbol': 'PSG9', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 193, 'Gene_name': 'TFPI2', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000105825', 'Ensembl_transcript_id': 'ENST00000461482|ENST00000222543|ENST00000650573|ENST00000647793|ENST00000649913|ENST00000451238', 'RefSeq_mRNA_id': 'NM_001271003|NM_001271004|NM_006528', 'Organism': 'human', 'HGNC_symbol': 'TFPI2', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 194, 'Gene_name': 'GALNT17', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000185274', 'Ensembl_transcript_id': 'ENST00000467723|ENST00000618959|ENST00000333538|ENST00000447516|ENST00000498380', 'RefSeq_mRNA_id': 'NM_022479', 'Organism': 'human', 'HGNC_symbol': 'GALNT17', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 195, 'Gene_name': 'LINC02291', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000197176', 'Ensembl_transcript_id': 'ENST00000355909|ENST00000554197|ENST00000556163', 'RefSeq_mRNA_id': '', 'Organism': 'human', 'HGNC_symbol': 'LINC02291', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 196, 'Gene_name': 'SH2D5', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000189410', 'Ensembl_transcript_id': 'ENST00000460804|ENST00000444387|ENST00000518294|ENST00000375031|ENST00000517430|ENST00000447746|ENST00000519434', 'RefSeq_mRNA_id': 'NM_001103161|NM_001103160', 'Organism': 'human', 'HGNC_symbol': 'SH2D5', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 197, 'Gene_name': 'ACOXL-AS1', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000204581', 'Ensembl_transcript_id': 'ENST00000670010|ENST00000376593|ENST00000418615', 'RefSeq_mRNA_id': '', 'Organism': 'human', 'HGNC_symbol': 'ACOXL-AS1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 198, 'Gene_name': 'CA10', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000154975', 'Ensembl_transcript_id': 'ENST00000571371|ENST00000442502|ENST00000575097|ENST00000285273|ENST00000573294|ENST00000451037|ENST00000570565|ENST00000571918|ENST00000575181', 'RefSeq_mRNA_id': 'NM_001082534|NM_001082533|NM_020178', 'Organism': 'human', 'HGNC_symbol': 'CA10', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 199, 'Gene_name': 'MAGEA4', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000147381', 'Ensembl_transcript_id': 'ENST00000431971|ENST00000682728|ENST00000393921|ENST00000683901|ENST00000360243|ENST00000448295|ENST00000441865|ENST00000457310|ENST00000370335|ENST00000276344|ENST00000431963|ENST00000416020|ENST00000393920|ENST00000370340|ENST00000682265|ENST00000425182|ENST00000684668|ENST00000430273', 'RefSeq_mRNA_id': 'NM_001386196|NM_001011550|NM_002362|NM_001386200|NM_001386199|NM_001386202|NM_001386203|NM_001011548|NM_001386198|NM_001386197|NM_001011549', 'Organism': 'human', 'HGNC_symbol': 'MAGEA4', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 200, 'Gene_name': 'RHOT1P1', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000266145', 'Ensembl_transcript_id': 'ENST00000582468', 'RefSeq_mRNA_id': '', 'Organism': 'human', 'HGNC_symbol': 'RHOT1P1', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 201, 'Gene_name': 'PLAC4', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000280109', 'Ensembl_transcript_id': 'ENST00000440221|ENST00000430327|ENST00000414699|ENST00000623119|ENST00000645185', 'RefSeq_mRNA_id': '', 'Organism': 'human', 'HGNC_symbol': 'PLAC4', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 202, 'Gene_name': 'IGHE', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000211891|ENSG00000276192', 'Ensembl_transcript_id': 'ENST00000390541|ENST00000641420|ENST00000610670', 'RefSeq_mRNA_id': '', 'Organism': 'human', 'HGNC_symbol': 'IGHE', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 203, 'Gene_name': 'CCK', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000187094', 'Ensembl_transcript_id': 'ENST00000484359|ENST00000434608|ENST00000396169|ENST00000334681', 'RefSeq_mRNA_id': 'NM_000729|NM_001174138', 'Organism': 'human', 'HGNC_symbol': 'CCK', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 204, 'Gene_name': 'KCNA7', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000104848', 'Ensembl_transcript_id': 'ENST00000221444', 'RefSeq_mRNA_id': 'NM_031886', 'Organism': 'human', 'HGNC_symbol': 'KCNA7', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 205, 'Gene_name': 'SAR1AP2', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000213170', 'Ensembl_transcript_id': 'ENST00000392696', 'RefSeq_mRNA_id': '', 'Organism': 'human', 'HGNC_symbol': 'SAR1AP2', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 206, 'Gene_name': 'ALDH1A2', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000128918', 'Ensembl_transcript_id': 'ENST00000560863|ENST00000557967|ENST00000558603|ENST00000558073|ENST00000559517|ENST00000537372|ENST00000558504|ENST00000560923|ENST00000249750|ENST00000559297|ENST00000558231|ENST00000558946|ENST00000560122|ENST00000560312|ENST00000558595|ENST00000561098|ENST00000558384|ENST00000347587|ENST00000559579|ENST00000430119|ENST00000559266|ENST00000558524|ENST00000558239|ENST00000559625|ENST00000561070', 'RefSeq_mRNA_id': 'NM_003888|NM_170696|NM_170697|NM_001206897', 'Organism': 'human', 'HGNC_symbol': 'ALDH1A2', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 207, 'Gene_name': 'HNRNPA1P27', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000233680', 'Ensembl_transcript_id': 'ENST00000412087', 'RefSeq_mRNA_id': '', 'Organism': 'human', 'HGNC_symbol': 'HNRNPA1P27', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 208, 'Gene_name': 'PAPPA-AS2', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000226604', 'Ensembl_transcript_id': 'ENST00000438048', 'RefSeq_mRNA_id': '', 'Organism': 'human', 'HGNC_symbol': 'PAPPA-AS2', 'Alias': '', 'Info': 'down'}
# down
# {'Index': 209, 'Gene_name': 'OR5H5P', 'Gene_list_number': 28, 'Gene_list_index': 'all_sig_genes_33981007', 'Source': 'PMID: 33981007', 'Ensembl_gene_id': 'ENSG00000249321', 'Ensembl_transcript_id': 'ENST00000503164', 'RefSeq_mRNA_id': '', 'Organism': 'human', 'HGNC_symbol': 'OR5H5P', 'Alias': '', 'Info': 'down'}

# %%
print(ls_notResponse)
# Out:
# ['LINC00514', 'SPERT', 'HIST3H2BB']

# %%
# SCORES 

### from DICTIONARY to file
data = ls_geneDictionaries
df = pd.DataFrame.from_dict(data)
df.to_excel(r'.\Dictionary.xlsx', index=False)

### from ls_notResponse to file
data1 = ls_notResponse
df1 = pd.DataFrame.from_dict(data1)
df1.to_excel(r'.\notResponse.xlsx', index=False)

# LOAD 
# notRESPONSE
wb_2 = openpyxl.load_workbook(r'.\notResponse.xlsx')
ws_2 = wb_2.active
ls_notResponse_v2 = [ws_2.cell(row=i,column=1).value for i in range(2,ws_2.max_row+1)]


### from alias_and_official to file
data2 = alias_and_official(ls_notResponse, ls_row_10, ls_row_2)
df2 = pd.DataFrame.from_dict(data2)
df2.to_excel(r'.\responsewithMGI.xlsx', index=False)


# LOAD responsewithMGI
wb_3 = openpyxl.load_workbook(r'.\responsewithMGI.xlsx')
ws_3 = wb_3.active
gene_name_v2 = [ws_3.cell(row=i,column=1).value for i in range(3,ws_3.max_row+1)]

# %%
print (ls_notResponse)
# Out:
# ['LINC00514', 'SPERT', 'HIST3H2BB']

# %%
print (gene_name_v2)
# Out:
# ['spert']

# %%
# SECOND DICTIONARY

for i in range(len(gene_name_v2)):
    gene_name = gene_name_v2[i]
    print(gene_name)
    hgnc_symbol = gene_name
    
    if gene_name != '':

        # variables
        alias = ''

        ensembl_gene_id_temp = []
        ensembl_transcript_id_temp = []
        refseq_mrna_temp = []
        

        ls_biomartParameters_mgi = biomartParameters_mgi(gene_name)
        
        print(ls_biomartParameters_mgi)
        
        if not ls_biomartParameters_mgi:
            ls_notResponse_after.append(gene_name)


        for ls in ls_biomartParameters_mgi:
            for j in range(3):
                if len(ls) < (j+1):
                    ls.append('')
            ensembl_gene_id_temp.append(ls[0])
            ensembl_transcript_id_temp.append(ls[1])
            refseq_mrna_temp.append(ls[2])  

        ensembl_gene_id = '|'.join(list(set(filter(None, ensembl_gene_id_temp))))
        ensembl_transcript_id = '|'.join(list(set(filter(None, ensembl_transcript_id_temp))))
        refseq_mrna = '|'.join(list(set(filter(None, refseq_mrna_temp))))
        
        
        
        for k in range(len(ls_geneDictionaries)):
            temp = str(ls_geneDictionaries[k]['Gene_name']).lower()

            if temp == gene_name:
                print('response')
                ls_geneDictionaries[k]['Ensembl_gene_id'] = ensembl_gene_id
                ls_geneDictionaries[k]['Ensembl_transcript_id'] = ensembl_transcript_id
                ls_geneDictionaries[k]['RefSeq_mRNA_id'] = refseq_mrna
                ls_geneDictionaries[k]['HGNC_symbol'] = hgnc_symbol
# Out:
# spert
# []
# response

# %%
# SCORES 

### from SECOND DICTIONARY to file

data3 = ls_geneDictionaries
df3 = pd.DataFrame.from_dict(data3)
df3.to_excel(r'.\secondDictionary.xlsx', index=False)
df3.to_csv(r'.\secondDictionary.tsv', sep="\t")

data4 = ls_notResponse_after
df4 = pd.DataFrame.from_dict(data4)
df4.to_excel(r'.\ls_notResponse_after.xlsx', index=False)

# %%
# Add ALIAS

mgi_file_path = r'..\MGI_EntrezGene.xlsx'
dictionary_file_path = r'.\secondDictionary.xlsx'
save_file_path = r'.\withAlias.xlsx'


updateCellswithAlias(mgi_file_path, dictionary_file_path, save_file_path)

# %%
# Add INFO

def updateCellswithINFO(source_file_path, source_sheet, alias_file_path, info_file_path):
    
    wb_info = openpyxl.load_workbook(source_file_path)
    ws_info = wb_info[source_sheet]
    ls_row_g_name = [ws_info.cell(row=i, column=3).value for i in range(2, ws_info.max_row + 1)]


    wb_alias = openpyxl.load_workbook(alias_file_path)
    ws_alias = wb_alias.active
    ls_row_2 = [ws_alias.cell(row=i, column=2).value for i in range(2, ws_alias.max_row + 1)]


    matched_indices = set()               # to keep track of matched id

    for j, (g_name, row_2) in enumerate(zip(ls_row_g_name, ls_row_2), start=2):
        if j not in matched_indices and str(g_name).lower() == str(row_2).lower():
            print(str(g_name).lower(), str(row_2).lower())
            L_cel = 'L' + str(j)
            tempInfo = str(ws_alias[L_cel].value)
            matched_indices.add(j)        # add matched index to set - avoid duplicate

### the number and type of items in the INFO column depends on the source publication


            ws_alias[L_cel] = ''
            ws_alias[L_cel] = ('Regulation:' + str(tempInfo).upper() + '|'
                            + 'Log2Ratio:' + str(ws_info['E' + str(j)].value) + '|'
                            + 'tissue:' + str(ws_info['H' + str(j)].value) + '|'
                            + 'cell:' + str(ws_info['I' + str(j)].value) + '|'
                            + 'enviroroment:' + str(ws_info['J' + str(j)].value) + '|'
                            + 'treatment:' + str(ws_info['K' + str(j)].value) + '|'
                            + 'dose:' + str(ws_info['L' + str(j)].value) + '|'
                            + 'time:' + str(ws_info['M' + str(j)].value) + '|'
                            + 'FDR_threshold:' + str(ws_info['N' + str(j)].value) + '|'
                            + 'method:' + str(ws_info['O' + str(j)].value) + '|'
                            + 'genome_element' + str(ws_info['P' + str(j)].value) + '|'
                            + 'FDR:' + str(ws_info['Q' + str(j)].value) + '|'
                            + 'comparison:' + str(ws_info['R' + str(j)].value) + '|'                             
                            + 'statistics:' + str(ws_info['S' + str(j)].value))

        
        


    # Save the file
    wb_alias.save(info_file_path)



source_file_path = r'..\ifpan-GR-database-papers.xlsx'
source_sheet = 'placenta-PNSS'
alias_file_path = '.\withAlias.xlsx'
info_file_path = r'.\withINFO.xlsx'

updateCellswithINFO(source_file_path, source_sheet, alias_file_path, info_file_path)
# Out:
# rn7sl4p rn7sl4p
# linc01816 linc01816
# fbln1 fbln1
# ankrd33 ankrd33
# cgb3 cgb3
# mrgpre mrgpre
# muc15 muc15
# psca psca
# ca1 ca1
# ppp1r14c ppp1r14c
# rn7sl3 rn7sl3
# adhfe1 adhfe1
# krt34 krt34
# cpxm2 cpxm2
# sik1 sik1
# cgb7 cgb7
# rab6b rab6b
# plac1 plac1
# muc5b muc5b
# smkr1 smkr1
# alpp alpp
# cited4 cited4
# psg8 psg8
# ephb6 ephb6
# lrrn1 lrrn1
# arms2 arms2
# hsd17b1 hsd17b1
# acoxl acoxl
# znf554 znf554
# aldh3b2 aldh3b2
# pkd1p5 pkd1p5
# stx1b stx1b
# abhd17c abhd17c
# duox2 duox2
# psg1 psg1
# gdf15 gdf15
# ank3 ank3
# nectin3 nectin3
# syt12 syt12
# slc7a2 slc7a2
# kiss1 kiss1
# lcal1 lcal1
# linc01554 linc01554
# misp3 misp3
# pgf pgf
# tprxl tprxl
# gda gda
# tc2n tc2n
# cab39p1 cab39p1
# muc4 muc4
# lad1 lad1
# sh3tc2 sh3tc2
# ncf4-as1 ncf4-as1
# crybg2 crybg2
# ftcd ftcd
# phyhipl phyhipl
# nav2-as4 nav2-as4
# csh1 csh1
# gh2 gh2
# hsd11b2 hsd11b2
# cpne7 cpne7
# cyp19a1 cyp19a1
# sema3b sema3b
# p2rx2 p2rx2
# optc optc
# psg6 psg6
# hsd3b1 hsd3b1
# erv3-1 erv3-1
# hs3st3b1 hs3st3b1
# slamf7 slamf7
# ccdc33 ccdc33
# dhrs2 dhrs2
# akr1b15 akr1b15
# treml2 treml2
# gabrb1 gabrb1
# psg4 psg4
# epha1-as1 epha1-as1
# rbp4 rbp4
# kiaa0319 kiaa0319
# tmem54 tmem54
# clc clc
# sdc1 sdc1
# npffr2 npffr2
# lrrc8e lrrc8e
# ly6g6c ly6g6c
# srrm4 srrm4
# synpo2l synpo2l
# lypd5 lypd5
# styk1 styk1
# hlf hlf
# nectin3-as1 nectin3-as1
# upk3b upk3b
# s100a2 s100a2
# cga cga
# nccrp1 nccrp1
# aicda aicda
# slc26a7 slc26a7
# ren ren
# slc7a4 slc7a4
# lcmt1-as2 lcmt1-as2
# trpv6 trpv6
# linc01119 linc01119
# tchh tchh
# uca1 uca1
# linc02527 linc02527
# mfsd2a mfsd2a
# linc02365 linc02365
# linc02518 linc02518
# ankrd20a5p ankrd20a5p
# tubb3 tubb3
# saxo2 saxo2
# tmem88b tmem88b
# frmpd1 frmpd1
# ankrd22 ankrd22
# tob2p1 tob2p1
# psg5 psg5
# blacat1 blacat1
# depdc1b depdc1b
# hsd17b1p1 hsd17b1p1
# sult2b1 sult2b1
# sh2d7 sh2d7
# linc00475 linc00475
# lgals13 lgals13
# trim40 trim40
# asb2 asb2
# gapdhp32 gapdhp32
# cgb5 cgb5
# serpinb2 serpinb2
# ncmap ncmap
# psg2 psg2
# sh3tc2-dt sh3tc2-dt
# palm3 palm3
# cblc cblc
# hopx hopx
# dpep2nb dpep2nb
# morn3 morn3
# psg11 psg11
# linc02533 linc02533
# pappa pappa
# ildr2 ildr2
# cyp4f35p cyp4f35p
# asxl3 asxl3
# endou endou
# ervv-2 ervv-2
# krt86 krt86
# linc00514 linc00514
# csh2 csh2
# ebi3 ebi3
# erve-1 erve-1
# exph5 exph5
# catip catip
# nkain1 nkain1
# spert spert
# slc30a2 slc30a2
# mmp11 mmp11
# cnga1 cnga1
# sptlc3 sptlc3
# crct1 crct1
# rab3b rab3b
# ly6d ly6d
# magea11 magea11
# xkrx xkrx
# linc01118 linc01118
# syngr3 syngr3
# krt81 krt81
# linc00482 linc00482
# oprk1 oprk1
# fgfbp1 fgfbp1
# hbd hbd
# nipal1 nipal1
# olah olah
# adam12 adam12
# fbxw11p1 fbxw11p1
# slc7a10 slc7a10
# tcl6 tcl6
# calhm3 calhm3
# aloxe3 aloxe3
# lgals14 lgals14
# scin scin
# psg3 psg3
# cxcl10 cxcl10
# gypa gypa
# cox20p1 cox20p1
# psg10p psg10p
# rn7sl268p rn7sl268p
# pnma5 pnma5
# evpl evpl
# ighg4 ighg4
# pdcd1 pdcd1
# pla2g2f pla2g2f
# hist3h2bb hist3h2bb
# psg9 psg9
# tfpi2 tfpi2
# galnt17 galnt17
# linc02291 linc02291
# sh2d5 sh2d5
# acoxl-as1 acoxl-as1
# ca10 ca10
# magea4 magea4
# rhot1p1 rhot1p1
# plac4 plac4
# ighe ighe
# cck cck
# kcna7 kcna7
# sar1ap2 sar1ap2
# aldh1a2 aldh1a2
# hnrnpa1p27 hnrnpa1p27
# pappa-as2 pappa-as2
# or5h5p or5h5p

# %%
                                ''' + '|'
                                 + '|'
                                +'TTEST.NEURO.ALD:' + str(ws_mgi[S_cel].value) + '|'
                                +'TTEST.NEURO.DHT:' + str(ws_mgi[T_cel].value) + '|'
                                +'TTEST.NEURO.PRG:' + str(ws_mgi[U_cel].value) + '|'
                                +'TTEST.NEURO.ESR:' + str(ws_mgi[V_cel].value) + '|'
                                +'FDR_TTEST.ASTRO.DEX:' + str(ws_mgi[W_cel].value) + '|'
                                +'FDR_TTEST.ASTRO.ALD:' + str(ws_mgi[X_cel].value) + '|'
                                +'FDR_TTEST.ASTRO.DHT:' + str(ws_mgi[Y_cel].value) + '|'
                                +'FDR_TTEST.ASTRO.PRG:' + str(ws_mgi[Z_cel].value) + '|'
                                +'FDR_TTEST.ASTRO.ESR:' + str(ws_mgi[AA_cel].value) + '|'
                                +'FDR_TTEST.NEURO.DEX:' + str(ws_mgi[AB_cel].value) + '|'
                                +'FDR_TTEST.NEURO.ALD:' + str(ws_mgi[AC_cel].value) + '|'
                                +'FDR_TTEST.NEURO.DHT:' + str(ws_mgi[AD_cel].value) + '|'
                                +'FDR_TTEST.NEURO.PRG:' + str(ws_mgi[AE_cel].value) + '|'
                                +'FDR_TTEST.NEURO.ESR:' + str(ws_mgi[AF_cel].value) + '|'
                                +'FOLD.ASTRO.DEX:' + str(ws_mgi[AG_cel].value) + '|'
                                +'FOLD.ASTRO.ALD:' + str(ws_mgi[AH_cel].value) + '|'
                                +'FOLD.ASTRO.DHT:' + str(ws_mgi[AI_cel].value) + '|'
                                +'FOLD.ASTRO.PRG:' + str(ws_mgi[AJ_cel].value) + '|'
                                +'FOLD.ASTRO.ESR:' + str(ws_mgi[AK_cel].value) + '|'
                                +'FOLD.NEURO.DEX:' + str(ws_mgi[AL_cel].value) + '|'
                                +'FOLD.NEURO.ALD:' + str(ws_mgi[AM_cel].value) + '|'
                                +'FOLD.NEURO.DHT:' + str(ws_mgi[AN_cel].value) + '|'
                                +'FOLD.NEURO.PRG:' + str(ws_mgi[AO_cel].value) + '|'
                                +'FOLD.NEURO.ESR:' + str(ws_mgi[AP_cel].value))'''
