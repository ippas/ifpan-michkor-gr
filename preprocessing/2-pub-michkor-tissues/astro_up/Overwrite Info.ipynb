# %%
import openpyxl

# %%
# load MGI file and open workbook

wb_mgi = openpyxl.load_workbook(r'C:\Users\Adrian\Asia_GIT\geneBase\2_pub\FINAL_DICTIONARIES\12868_2017_352_MOESM1_ESM_02.xlsx')
ws_mgi = wb_mgi['results']

ls_row_g_name = [ws_mgi.cell(row=i,column=4).value for i in range(2,ws_mgi.max_row+1)]

# %%
# load file file and open workbook
workbook = openpyxl.load_workbook(r'C:\Users\Adrian\Asia_GIT\geneBase\2_pub\FINAL_DICTIONARIES\Dictionary\astro_up\astrocytes_dex_up_withAlias — kopia.xlsx')
sheet = workbook.active

ls_row_2 = [sheet.cell(row=i,column=2).value for i in range(2,sheet.max_row+1)]
ls_row_10 = [sheet.cell(row=i,column=10).value for i in range(2,sheet.max_row+1)]

length = len(ls_row_2)+2

# %%
fr = sheet['B5'].value
print(fr)
# Out:
# Acsl3

# %%
print(ls_row_g_name[5])
# Out:
# Pdk4

# %%
#modify the desired cell
for j in range(0,length):
    J_cel = 'J'+str(j+2)
    
    for i in range(len(ls_row_g_name)):
        A_cel = 'A'+str(i+2)
        B_cel = 'B'+str(i+2)
        C_cel = 'C'+str(i+2)
        D_cel = 'D'+str(i+2)
        E_cel = 'E'+str(i+2)
        F_cel = 'F'+str(i+2)
        G_cel = 'G'+str(i+2)
        H_cel = 'H'+str(i+2)
        I_cel = 'I'+str(i+2)
        J2_cel = 'J'+str(i+2)
        K_cel = 'K'+str(i+2)
        L_cel = 'L'+str(i+2)
        M_cel = 'M'+str(i+2)
        N_cel = 'N'+str(i+2)
        O_cel = 'O'+str(i+2)
        P_cel = 'P'+str(i+2)
        Q_cel = 'Q'+str(i+2)
        R_cel = 'R'+str(i+2)
        S_cel = 'S'+str(i+2)
        T_cel = 'T'+str(i+2)
        U_cel = 'U'+str(i+2)
        V_cel = 'V'+str(i+2)
        W_cel = 'W'+str(i+2)
        X_cel = 'X'+str(i+2)
        Y_cel = 'Y'+str(i+2)
        Z_cel = 'Z'+str(i+2)
        AA_cel = 'AA'+str(i+2)
        AB_cel = 'AB'+str(i+2)
        AC_cel = 'AC'+str(i+2)
        AD_cel = 'AD'+str(i+2)
        AE_cel = 'AE'+str(i+2)
        AF_cel = 'AF'+str(i+2)
        AG_cel = 'AG'+str(i+2)
        AH_cel = 'AH'+str(i+2)
        AI_cel = 'AI'+str(i+2)
        AJ_cel = 'AJ'+str(i+2)
        AK_cel = 'AK'+str(i+2)
        AL_cel = 'AL'+str(i+2)
        AM_cel = 'AM'+str(i+2)
        AN_cel = 'AN'+str(i+2)
        AO_cel = 'AO'+str(i+2)
        AP_cel = 'AP'+str(i+2)
        try:
            if str(ls_row_g_name[i]).lower() == str(ls_row_2[j]).lower():
                print(str(ls_row_g_name[i]).lower(),str(ls_row_2[j]).lower())
#               if ls_row_alias[k] is not None:
                sheet[J_cel] = ''
                sheet[J_cel] =  ('Regulation: UP'+'|'
                                +'Probe.Set:'+ str(ws_mgi[A_cel].value) + '|'
                                +'Identifier:' + str(ws_mgi[B_cel].value) + '|'
                                +'FirstOfLocuslink:' + str(ws_mgi[C_cel].value) +'|'
                                +'FirstOfName:' + str(ws_mgi[D_cel].value) + '|'
                                +'FirstOfFunction:' + str(ws_mgi[E_cel].value) + '|'
                                +'Description:' + str(ws_mgi[F_cel].value) + '|'
                                +'ANOVA.TREAT:' + str(ws_mgi[G_cel].value) + '|'
                                +'ANOVA.CELL:' + str(ws_mgi[H_cel].value) + '|'
                                +'ANOVA.INT:' + str(ws_mgi[I_cel].value) + '|'
                                +'FDR_ANOVA.TREAT:' + str(ws_mgi[J2_cel].value) + '|'
                                +'FDR_ANOVA.CELL:' + str(ws_mgi[K_cel].value) + '|'
                                +'FDR_ANOVA.INT:' + str(ws_mgi[L_cel].value) + '|'
                                +'TTEST.ASTRO.DEX:' + str(ws_mgi[M_cel].value) + '|'
                                +'TTEST.ASTRO.ALD:' + str(ws_mgi[N_cel].value) + '|'
                                +'TTEST.ASTRO.DHT:' + str(ws_mgi[O_cel].value) + '|'
                                +'TTEST.ASTRO.PRG:' + str(ws_mgi[P_cel].value) + '|'
                                +'TTEST.ASTRO.ESR:' + str(ws_mgi[Q_cel].value) + '|'
                                +'TTEST.NEURO.DEX:' + str(ws_mgi[R_cel].value) + '|'
                                +'TTEST.NEURO.ALD:' + str(ws_mgi[S_cel].value) + '|'
                                +'TTEST.NEURO.DHT:' + str(ws_mgi[T_cel].value) + '|'
                                +'TTEST.NEURO.PRG:' + str(ws_mgi[U_cel].value) + '|'
                                +'TTEST.NEURO.ESR:' + str(ws_mgi[V_cel].value) + '|'
                                +'FDR_TTEST.ASTRO.DEX:' + str(ws_mgi[W_cel].value) + '|'
                                +'FDR_TTEST.ASTRO.ALD:' + str(ws_mgi[X_cel].value) + '|'
                                +'FDR_TTEST.ASTRO.DHT:' + str(ws_mgi[Y_cel].value) + '|'
                                +'FDR_TTEST.ASTRO.PRG:' + str(ws_mgi[Z_cel].value) + '|'
                                +'FDR_TTEST.ASTRO.ESR:' + str(ws_mgi[AA_cel].value) + '|'
                                +'FDR_TTEST.NEURO.DEX:' + str(ws_mgi[AB_cel].value) + '|'
                                +'FDR_TTEST.NEURO.ALD:' + str(ws_mgi[AC_cel].value) + '|'
                                +'FDR_TTEST.NEURO.DHT:' + str(ws_mgi[AD_cel].value) + '|'
                                +'FDR_TTEST.NEURO.PRG:' + str(ws_mgi[AE_cel].value) + '|'
                                +'FDR_TTEST.NEURO.ESR:' + str(ws_mgi[AF_cel].value) + '|'
                                +'FOLD.ASTRO.DEX:' + str(ws_mgi[AG_cel].value) + '|'
                                +'FOLD.ASTRO.ALD:' + str(ws_mgi[AH_cel].value) + '|'
                                +'FOLD.ASTRO.DHT:' + str(ws_mgi[AI_cel].value) + '|'
                                +'FOLD.ASTRO.PRG:' + str(ws_mgi[AJ_cel].value) + '|'
                                +'FOLD.ASTRO.ESR:' + str(ws_mgi[AK_cel].value) + '|'
                                +'FOLD.NEURO.DEX:' + str(ws_mgi[AL_cel].value) + '|'
                                +'FOLD.NEURO.ALD:' + str(ws_mgi[AM_cel].value) + '|'
                                +'FOLD.NEURO.DHT:' + str(ws_mgi[AN_cel].value) + '|'
                                +'FOLD.NEURO.PRG:' + str(ws_mgi[AO_cel].value) + '|'
                                +'FOLD.NEURO.ESR:' + str(ws_mgi[AP_cel].value))
            else:
                continue
        except:
            continue

#save the file
workbook.save(r'C:\Users\Adrian\Asia_GIT\geneBase\2_pub\FINAL_DICTIONARIES\Dictionary\astro_up\astrocytes_dex_up_all.xlsx')
# Out:
# slc10a6 slc10a6
# slc10a6 slc10a6
# mapk4 mapk4
# slc25a33 slc25a33
# acsl3 acsl3
# fkbp5 fkbp5
# gjb6 gjb6
# prodh prodh
# prodh prodh
# mfsd2 mfsd2
# amica1 amica1
# bcat1 bcat1
# retsat retsat
# retsat retsat
# mthfd2 mthfd2
# mthfd2 mthfd2
# mycl1 mycl1
# slc45a3 slc45a3
# loc382058 loc382058
# tsc22d3 tsc22d3
# tsc22d3 tsc22d3
# ramp2 ramp2
# per1 per1
# per1 per1
# pdk4 pdk4
# gadd45g gadd45g
# gadd45g gadd45g
# tsc22d3 tsc22d3
# tsc22d3 tsc22d3
# sult1a1 sult1a1
# ipas ipas
# errfi1 errfi1
# s3-12 s3-12
# spsb1 spsb1
# 9530081n05rik 9530081n05rik
# map3k6 map3k6
# map3k6 map3k6
# fam107a fam107a
# rgs17 rgs17
# rgs17 rgs17
# ddit4 ddit4
# loc385644 loc385644
# fosl2 fosl2
# mertk mertk
# mertk mertk
# b4galt1 b4galt1
# loc270152 loc270152
# folh1 folh1
# per1 per1
# per1 per1
# mbd1 mbd1
# mbd1 mbd1
# mbd1 mbd1
# mbd1 mbd1
# 4631426j05rik 4631426j05rik
# 4631426j05rik 4631426j05rik
# cdkn1a cdkn1a
# cdkn1a cdkn1a
# cdkn1a cdkn1a
# htra1 htra1
# htra1 htra1
# c030009j22rik c030009j22rik
# 4631416l12rik 4631416l12rik
# fgfbp1 fgfbp1
# sphk1 sphk1
# htra1 htra1
# htra1 htra1
# lpin3 lpin3
# 2810410a03rik 2810410a03rik
# klf9 klf9
# tob2 tob2
# tns1 tns1
# klf13 klf13
# axud1 axud1
# pex11a pex11a
# pex11a pex11a
# pex11a pex11a
# pex11a pex11a
# ppp1r1b ppp1r1b
# ppp1r1b ppp1r1b
# eln eln
# e230024b12rik e230024b12rik
# cdc37l1 cdc37l1
# cdc37l1 cdc37l1
# cdc37l1 cdc37l1
# pex11a pex11a
# pex11a pex11a
# pex11a pex11a
# pex11a pex11a
# lpin1 lpin1
# lpin1 lpin1
# s100a7a s100a7a
# tilz3c tilz3c
# mbd1 mbd1
# mbd1 mbd1
# mbd1 mbd1
# mbd1 mbd1
# agfg2 agfg2
# 9530064j02 9530064j02
# smox smox
# smox smox
# smox smox
# smox smox
# smox smox
# pex11a pex11a
# pex11a pex11a
# pex11a pex11a
# pex11a pex11a
# cyp2d22 cyp2d22
# gm129 gm129
# gm129 gm129
# gm129 gm129
# galntl4 galntl4
# lrg1 lrg1
# mat2a mat2a
# mat2a mat2a
# mat2a mat2a
# bc023892 bc023892
# pim3 pim3
# hspb1 hspb1
# cdkn1a cdkn1a
# cdkn1a cdkn1a
# cdkn1a cdkn1a
# pik3r1 pik3r1
# pik3r1 pik3r1
# gm22 gm22
# hs3st3b1 hs3st3b1
# tro tro
# tro tro
# tro tro
# aff1 aff1
# aff1 aff1
# adarb1 adarb1
# bcl2l1 bcl2l1
# bcl2l1 bcl2l1
# bcl2l1 bcl2l1
# rgs17 rgs17
# rgs17 rgs17
# acot11 acot11
# acot11 acot11
# acot11 acot11
# crispld2 crispld2
# loc100044968 loc100044968
# klhl29 klhl29
# loc100046232 loc100046232
# 2310051e17rik 2310051e17rik
# rhou rhou
# ctsl ctsl
# ihpk2 ihpk2
# ihpk2 ihpk2
# ihpk2 ihpk2
# lyve1 lyve1
# e330035h20rik e330035h20rik
# sgk1 sgk1
# smox smox
# smox smox
# smox smox
# smox smox
# smox smox
# cytip cytip
# 1810032o08rik 1810032o08rik
# lcn2 lcn2
# map3k6 map3k6
# map3k6 map3k6
# e030024c07rik e030024c07rik
# dleu2 dleu2
# mknk2 mknk2
# smox smox
# smox smox
# smox smox
# smox smox
# smox smox
# 9430029l20rik 9430029l20rik
# mbd1 mbd1
# mbd1 mbd1
# mbd1 mbd1
# mbd1 mbd1
# lims2 lims2
# lims2 lims2
# lims2 lims2
# sesn1 sesn1
# sesn1 sesn1
# sesn1 sesn1
# cables1 cables1
# loc100046741 loc100046741
# rbpms rbpms
# rbpms rbpms
# rbpms rbpms
# dpep1 dpep1
# 4631426j05rik 4631426j05rik
# 4631426j05rik 4631426j05rik
# foxo3 foxo3
# ehd3 ehd3
# nudt9 nudt9
# phca phca
# phca phca
# snta1 snta1
# snta1 snta1
# vasn vasn
# txnip txnip
# txnip txnip
# car14 car14
# car14 car14
# plekhf1 plekhf1
# plekhf1 plekhf1
# cacna1d cacna1d
# foxo1 foxo1
# lims2 lims2
# lims2 lims2
# lims2 lims2
# pnpla2 pnpla2
# cstf3 cstf3
# rbpms rbpms
# rbpms rbpms
# rbpms rbpms
# adora2b adora2b
# arhgap8 arhgap8
# arhgap8 arhgap8
# car14 car14
# car14 car14
# 1810011o10rik 1810011o10rik
# usp53 usp53
# hspb8 hspb8
# hspb8 hspb8
# ms4a6d ms4a6d
# ms4a6d ms4a6d
# rnf185 rnf185
# rnf185 rnf185
# man2a1 man2a1
# spire1 spire1
# stk32a stk32a
# stk32a stk32a
# pappa pappa
# ankrd54 ankrd54
# ankrd54 ankrd54
# cntfr cntfr
# papss2 papss2
# papss2 papss2
# 2900002g04rik 2900002g04rik
# amigo2 amigo2
# amigo2 amigo2
# accn1 accn1
# accn1 accn1
# arhgap8 arhgap8
# arhgap8 arhgap8
# rasl12 rasl12
# nt5e nt5e
# gadd45g gadd45g
# gadd45g gadd45g
# nedd9 nedd9
# nedd9 nedd9
# amigo2 amigo2
# amigo2 amigo2
# prodh prodh
# prodh prodh
# eef1d eef1d
# eef1d eef1d
# tro tro
# tro tro
# tro tro
# gpx3 gpx3
# ai607873 ai607873
# ccdc3 ccdc3
# rin2 rin2
# rin2 rin2
# nuak1 nuak1
# nuak1 nuak1
# rassf4 rassf4
# crip3 crip3
# fam178a fam178a
# fam178a fam178a
# cdc37l1 cdc37l1
# cdc37l1 cdc37l1
# cdc37l1 cdc37l1
# ppp1r1b ppp1r1b
# ppp1r1b ppp1r1b
# tns3 tns3
# sap30 sap30
# nde1 nde1
# nde1 nde1
# nde1 nde1
# nde1 nde1
# ihpk2 ihpk2
# ihpk2 ihpk2
# ihpk2 ihpk2
# ccng1 ccng1
# ccng1 ccng1
# rin2 rin2
# rin2 rin2
# p2rx5 p2rx5
# gm129 gm129
# gm129 gm129
# gm129 gm129
# chka chka
# chka chka
# loc331139 loc331139
# txnip txnip
# txnip txnip
# e430031d18rik e430031d18rik
# ptplb ptplb
# als2cr13 als2cr13
# cebpb cebpb
# smox smox
# smox smox
# smox smox
# smox smox
# smox smox
# nt5dc2 nt5dc2
# loc669001 loc669001
# camk2d camk2d
# wasf2 wasf2
# napepld napepld
# trp63 trp63
# stab1 stab1
# kcnk1 kcnk1
# kcnk1 kcnk1
# rilpl1 rilpl1
# rilpl1 rilpl1
# tmem204 tmem204
# fgfr3 fgfr3
# hr hr
# hr hr
# slc10a6 slc10a6
# slc10a6 slc10a6
# lims2 lims2
# lims2 lims2
# lims2 lims2
# rims2 rims2
# lin7a lin7a
# rasgef1c rasgef1c
# rasgef1c rasgef1c
# kcnk6 kcnk6
# kcnk6 kcnk6
# 6330442e10rik 6330442e10rik
# gpld1 gpld1
# gpld1 gpld1
# slc38a2 slc38a2
# slc38a2 slc38a2
# punc punc
# stim1 stim1
# stim1 stim1
# mobkl2a mobkl2a
# adrb2 adrb2
# ab112350 ab112350
# edn1 edn1
# gm1698 gm1698
# slc24a4 slc24a4
# zfp36 zfp36
# nde1 nde1
# nde1 nde1
# nde1 nde1
# nde1 nde1
# sesn1 sesn1
# sesn1 sesn1
# sesn1 sesn1
# tapt1 tapt1
# lrrc52 lrrc52
# b430216n15rik b430216n15rik
# aph1a aph1a
# arfl4 arfl4
# bcl2l1 bcl2l1
# bcl2l1 bcl2l1
# bcl2l1 bcl2l1
# 1600032l17rik 1600032l17rik
# ttpal ttpal
# mthfd2 mthfd2
# mthfd2 mthfd2
# rasgrf1 rasgrf1
# crybb1 crybb1
# atad4 atad4
# atad4 atad4
# 9330162l04rik 9330162l04rik
# plekhf1 plekhf1
# plekhf1 plekhf1
# usp2 usp2
# usp2 usp2
# usp2 usp2
# nxn nxn
# gli2 gli2
# ada ada
# cryba4 cryba4
# smox smox
# smox smox
# smox smox
# smox smox
# smox smox
# nfkbia nfkbia
# kcnt1 kcnt1
# kcnt1 kcnt1
# rilpl1 rilpl1
# rilpl1 rilpl1
# pik3r1 pik3r1
# pik3r1 pik3r1
# 1300007l22rik 1300007l22rik
# d16h22s680e d16h22s680e
# gab3 gab3
# gab3 gab3
# gab3 gab3
# agxt2l1 agxt2l1
# mrc1 mrc1
# il6ra il6ra
# dok1 dok1
# dok1 dok1
# lrrc8a lrrc8a
# 1110038d17rik 1110038d17rik
# rnf185 rnf185
# rnf185 rnf185
# chk chk
# mfhas1 mfhas1
# azin1 azin1
# pnpla7 pnpla7
# tmod1 tmod1
# klf4 klf4
# klf4 klf4
# klf4 klf4
# dok1 dok1
# dok1 dok1
# hspa1a hspa1a
# igfbp3 igfbp3
# loc100038993 loc100038993
# got1l1 got1l1
# tox tox
# tro tro
# tro tro
# tro tro
# r74862 r74862
# slc38a2 slc38a2
# slc38a2 slc38a2
# a630082k20rik a630082k20rik
# arrdc2 arrdc2
# arrdc2 arrdc2
# nedd9 nedd9
# nedd9 nedd9
# serpina3h serpina3h
# tagap tagap
# c230098o21rik c230098o21rik
# loc100041516 loc100041516
# rora rora
# 9030024j15rik 9030024j15rik
# nuak1 nuak1
# nuak1 nuak1
# rbpms rbpms
# rbpms rbpms
# rbpms rbpms
# defb1 defb1
# dcun1d3 dcun1d3
# mxd4 mxd4
# rtp1 rtp1
# pex11a pex11a
# pex11a pex11a
# pex11a pex11a
# pex11a pex11a
# zbtb16 zbtb16
# tlr7 tlr7
# kcnt1 kcnt1
# kcnt1 kcnt1
# bcl2l1 bcl2l1
# bcl2l1 bcl2l1
# bcl2l1 bcl2l1
# b230312e02rik b230312e02rik
# hr hr
# hr hr
# lmod1 lmod1
# sla sla
# tle3 tle3
# tle3 tle3
# tle3 tle3
# tle3 tle3
# ppm1k ppm1k
# bc030335 bc030335
# sept8 sept8
# cited2 cited2
# rab4a rab4a
# retsat retsat
# retsat retsat
# 2410081m15rik 2410081m15rik
# st6galnac2 st6galnac2
# lrrc8 lrrc8
# timp4 timp4
# mnat1 mnat1
# kcnk1 kcnk1
# kcnk1 kcnk1
# klf6 klf6
# 2310076l09rik 2310076l09rik
# 2310076l09rik 2310076l09rik
# kcnk6 kcnk6
# kcnk6 kcnk6
# klrg2 klrg2
# 2310043i08rik 2310043i08rik
# igsf11 igsf11
# ccbl1 ccbl1
# ccbl1 ccbl1
# arrdc2 arrdc2
# arrdc2 arrdc2
# loc381019 loc381019
# fbxo18 fbxo18
# tmem166 tmem166
# hmgcs2 hmgcs2
# stim1 stim1
# stim1 stim1
# cd109 cd109
# cd109 cd109
# loc100045947 loc100045947
# cbs cbs
# cbs cbs
# mbnl2 mbnl2
# klf15 klf15
# ms4a6d ms4a6d
# ms4a6d ms4a6d
# 2900057k09rik 2900057k09rik
# tcfcp2l1 tcfcp2l1
# sh3rf1 sh3rf1
# ai593442 ai593442
# klf4 klf4
# klf4 klf4
# klf4 klf4
# gpld1 gpld1
# gpld1 gpld1
# bcl6 bcl6
# march1 march1
# gm129 gm129
# gm129 gm129
# gm129 gm129
# trpv4 trpv4
# dgka dgka
# dgka dgka
# gab3 gab3
# gab3 gab3
# gab3 gab3
# e230029f23rik e230029f23rik
# 1500005n04rik 1500005n04rik
# nmb nmb
# setdb2 setdb2
# agt agt
# zhx3 zhx3
# sesn1 sesn1
# sesn1 sesn1
# sesn1 sesn1
# ctgf ctgf
# 2810032g03rik 2810032g03rik
# itpk1 itpk1
# ptpn22 ptpn22
# acot11 acot11
# acot11 acot11
# acot11 acot11
# 6430598a04rik 6430598a04rik
# lhfp lhfp
# per2 per2
# per2 per2
# ppapdc2 ppapdc2
# ppapdc2 ppapdc2
# ssfa2 ssfa2
# arrdc3 arrdc3
# scl0003781.1_22 scl0003781.1_22
# ptpn14 ptpn14
# pitpnm2 pitpnm2
# otud7b otud7b
# loc676704 loc676704
# cmya5 cmya5
# klf7 klf7
# klf7 klf7
# cd109 cd109
# cd109 cd109
# mt2 mt2
# stard10 stard10
# stard10 stard10
# adamts1 adamts1
# amotl2 amotl2
# pp11r pp11r
# nkd2 nkd2
# chst2 chst2
# ihpk2 ihpk2
# ihpk2 ihpk2
# ihpk2 ihpk2
# ppp1r10 ppp1r10
# myrip myrip
# dlk2 dlk2
# rasgef1c rasgef1c
# rasgef1c rasgef1c
# 9930012k11rik 9930012k11rik
# 1110067d22rik 1110067d22rik
# tle3 tle3
# tle3 tle3
# tle3 tle3
# tle3 tle3
# mat2a mat2a
# mat2a mat2a
# mat2a mat2a
# tle3 tle3
# tle3 tle3
# tle3 tle3
# tle3 tle3
# tm6sf1 tm6sf1
# ifngr1 ifngr1
# cdkn1a cdkn1a
# cdkn1a cdkn1a
# cdkn1a cdkn1a
# usp2 usp2
# usp2 usp2
# usp2 usp2
# rapgef3 rapgef3
# loc100045882 loc100045882
# camk2n1 camk2n1
# camk2n1 camk2n1
# ccbl1 ccbl1
# ccbl1 ccbl1
# gfpt2 gfpt2
# shank3 shank3
# stk32a stk32a
# stk32a stk32a
# chka chka
# chka chka
# smarcd2 smarcd2
# pmaip1 pmaip1
# tbc1d9b tbc1d9b
# adamtsl4 adamtsl4
# ranbp9 ranbp9
# 4933426m11rik 4933426m11rik
# dbt dbt
# megf9 megf9
# bc053440 bc053440
# dclre1b dclre1b
# tenc1 tenc1
# lpin1 lpin1
# lpin1 lpin1
# 2010107h07rik 2010107h07rik
# d15mit260 d15mit260
# 6720458d17rik 6720458d17rik
# pxmp2 pxmp2
# adora1 adora1
# accn1 accn1
# accn1 accn1
# egfr egfr
# p4ha2 p4ha2
# ankrd54 ankrd54
# ankrd54 ankrd54
# fam178a fam178a
# fam178a fam178a
# 2610528o22rik 2610528o22rik
# mcc mcc
# frmpd1 frmpd1
# 2210419d22rik 2210419d22rik
# megf10 megf10
# gab3 gab3
# gab3 gab3
# gab3 gab3
# cldn1 cldn1
# doc2b doc2b
# e130203b14rik e130203b14rik
# 2310076l09rik 2310076l09rik
# 2310076l09rik 2310076l09rik
# 9330159f19rik 9330159f19rik
# loc192758 loc192758
# 1700019d03rik 1700019d03rik
# nrap nrap
# snta1 snta1
# snta1 snta1
# slitrk5 slitrk5
# camk2n1 camk2n1
# camk2n1 camk2n1
# cbs cbs
# cbs cbs
# ralbp1 ralbp1
# cdc37l1 cdc37l1
# cdc37l1 cdc37l1
# cdc37l1 cdc37l1
# farp2 farp2
# per2 per2
# per2 per2
# gpt2 gpt2
# abca4 abca4
# stard10 stard10
# stard10 stard10
# lrp6 lrp6
# b3gnt9 b3gnt9
# b3gnt9 b3gnt9
# dgka dgka
# dgka dgka
# 4833426j09rik 4833426j09rik
# atad4 atad4
# atad4 atad4
# c030027l06rik c030027l06rik
# llgl2 llgl2
# tle3 tle3
# tle3 tle3
# tle3 tle3
# tle3 tle3
# trp53inp1 trp53inp1
# myd116 myd116
# csnk1e csnk1e
# glul glul
# a130030m01rik a130030m01rik
# slc25a38 slc25a38
# slc35f3 slc35f3
# rusc2 rusc2
# 1300011l04rik 1300011l04rik
# loc100047712 loc100047712
# cdr2 cdr2
# tmem77 tmem77
# fkbp14 fkbp14
# angptl7 angptl7
# loc385279 loc385279
# dusp1 dusp1
# cyp2d10 cyp2d10
# aff1 aff1
# aff1 aff1
# fam129b fam129b
# tnfsf11 tnfsf11
# ogfrl1 ogfrl1
# mkx mkx
# il1rap il1rap
# lamc2 lamc2
# nde1 nde1
# nde1 nde1
# nde1 nde1
# nde1 nde1
# gpr65 gpr65
# ym24d07 ym24d07
# aldoc aldoc
# aldoc aldoc
# cdc45l cdc45l
# dlg5 dlg5
# klf7 klf7
# klf7 klf7
# mbd1 mbd1
# mbd1 mbd1
# mbd1 mbd1
# mbd1 mbd1
# papss2 papss2
# papss2 papss2
# mat2a mat2a
# mat2a mat2a
# mat2a mat2a
# prr5 prr5
# spag5 spag5
# eef1d eef1d
# eef1d eef1d
# ms4a6b ms4a6b
# abcb1b abcb1b
# angpt4 angpt4
# dync1li1 dync1li1
# a930023f05rik a930023f05rik
# b3gnt9 b3gnt9
# b3gnt9 b3gnt9
# xdh xdh
# depdc6 depdc6
# lifr lifr
# il11ra1 il11ra1
# ppard ppard
# omd omd
# nde1 nde1
# nde1 nde1
# nde1 nde1
# nde1 nde1
# ccng1 ccng1
# ccng1 ccng1
# irx2 irx2
# klf4 klf4
# klf4 klf4
# klf4 klf4
# hspb8 hspb8
# hspb8 hspb8
# phca phca
# phca phca
# slc2a3 slc2a3
# wwc2 wwc2
# ppapdc2 ppapdc2
# ppapdc2 ppapdc2
# usp2 usp2
# usp2 usp2
# usp2 usp2
# furin furin
# loc100047752 loc100047752
# adamts9 adamts9
# col4a1 col4a1
# acot11 acot11
# acot11 acot11
# acot11 acot11
# hepacam hepacam
# iqgap2 iqgap2
# iqgap2 iqgap2
# ppp1r9b ppp1r9b
# loc100048832 loc100048832
# loc382003 loc382003
# pla2g3 pla2g3
# loc666053 loc666053
# rasl11a rasl11a
# 8430403j19rik 8430403j19rik
# scrg1 scrg1
# hs3st1 hs3st1
# mertk mertk
# mertk mertk
# cyp2j9 cyp2j9
# wbscr17 wbscr17
# kcnn2 kcnn2
# 4933413j09rik 4933413j09rik

# %%
print(length)
# Out:
# 134
